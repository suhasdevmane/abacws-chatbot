# %%
pip install --user -r requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 32.8/32.8 MB 5.6 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 5.6 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 500.3/500.3 kB 4.9 MB/s eta 0:00:0000:0100:01
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 384.9/384.9 kB 6.6 MB/s eta 0:00:0000:01
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.4/99.4 kB 2.3 MB/s eta 0:00:00a 0:00:01
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.9/40.9 kB 1.6 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.6/158.6 kB 3.2 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.6/181.6 kB 3.9 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.1/67.1 kB 3.3 MB/s eta 0:00:00
# ...

# %%
# psycopg2-tutorial/main.py
import psycopg2
connection = psycopg2.connect(database='thingsboard',
                                 user="thingsboard",      # or thingsboard
                                 password="postgres",
                                 host= "host.docker.internal",        #host.docker.internal  worked
                                 port = 5432
                             )

print("Successfully connected to the database.")
# Out:
# Successfully connected to the database.

# %%
# Open a cursor to perform database operations
cursor = connection.cursor()

# Execute a query
cursor.execute("SELECT datname FROM pg_database;")
databases = cursor.fetchall()

for db in databases:
    print("Database:", db[0])
# Out:
# Database: postgres
# Database: thingsboard
# Database: template1
# Database: template0

# %%
# To list the tables within a specific database
# Replace 'your_database_name' with the name of the database you want to explore
database_name = 'thingsboard'

cursor.execute(f"SELECT table_name FROM information_schema.tables WHERE table_schema = 'public';")
tables = cursor.fetchall()

for table in tables:
    print("Table:", table[0])

# Close the cursor and the database connection
cursor.close()
connection.close()
# Out:
# Table: tb_schema_settings
# Table: admin_settings
# Table: audit_log
# Table: alarm_comment
# Table: alarm
# Table: entity_alarm
# Table: attribute_kv
# Table: component_descriptor
# Table: customer
# Table: rule_node
# Table: rule_node_state
# Table: queue
# Table: rule_chain
# Table: asset_profile
# Table: dashboard
# Table: asset
# Table: device_profile
# Table: ota_package
# Table: device
# Table: device_credentials
# Table: rule_node_debug_event
# Table: rule_chain_debug_event
# Table: error_event
# Table: relation
# Table: lc_event
# Table: stats_event
# Table: tenant_profile
# Table: tenant
# Table: user_credentials
# Table: widgets_bundle
# Table: widgets_bundle_widget
# Table: widget_type
# Table: entity_view
# Table: ts_kv_latest
# Table: ts_kv_dictionary
# Table: oauth2_params
# Table: oauth2_registration
# Table: oauth2_domain
# Table: oauth2_mobile
# Table: oauth2_client_registration_template
# Table: oauth2_client_registration_info
# Table: oauth2_client_registration
# ...

# %%
# psycopg2-tutorial/main.py
import psycopg2
connection = psycopg2.connect(database='thingsboard',
                                 user="thingsboard",      # or thingsboard
                                 password="postgres",
                                 host= "host.docker.internal",        #host.docker.internal  worked
                                 port = 5432
                             )

print("Successfully connected to the database.")
database_name = 'thingsboard'
cursor = connection.cursor()

cursor.execute(f"SELECT table_name FROM information_schema.tables WHERE table_schema = 'public';")
tables = cursor.fetchall()

for table in tables:
    print("Table:", table[0])

# Close the cursor and the database connection
cursor.close()
connection.close()
# Out:
# Successfully connected to the database.
# Table: tb_schema_settings
# Table: admin_settings
# Table: audit_log
# Table: alarm_comment
# Table: alarm
# Table: entity_alarm
# Table: attribute_kv
# Table: component_descriptor
# Table: customer
# Table: rule_node
# Table: rule_node_state
# Table: queue
# Table: rule_chain
# Table: asset_profile
# Table: dashboard
# Table: asset
# Table: device_profile
# Table: ota_package
# Table: device
# Table: device_credentials
# Table: rule_node_debug_event
# Table: rule_chain_debug_event
# Table: error_event
# Table: relation
# Table: lc_event
# Table: stats_event
# Table: tenant_profile
# Table: tenant
# Table: user_credentials
# Table: widgets_bundle
# Table: widgets_bundle_widget
# Table: widget_type
# Table: entity_view
# Table: ts_kv_latest
# Table: ts_kv_dictionary
# Table: oauth2_params
# Table: oauth2_registration
# Table: oauth2_domain
# Table: oauth2_mobile
# Table: oauth2_client_registration_template
# ...

# %%
# psycopg2-tutorial/main.py
import psycopg2
connection = psycopg2.connect(database='thingsboard',
                                 user="thingsboard",      # or thingsboard
                                 password="postgres",
                                 host= "host.docker.internal",        #host.docker.internal  worked
                                 port = 5432
                             )

print("Successfully connected to the database.")
database_name = 'thingsboard'
cursor = connection.cursor()
# =====
table_name = 'device'
cursor.execute(f"SELECT * FROM {table_name};")
table_data = cursor.fetchall()

for row in table_data:
    print(row)
# =====
# Close the cursor and the database connection
cursor.close()
connection.close()
# Out:
# Successfully connected to the database.
# ('c23fc120-6eb8-11ee-a986-db1792d27da0', 1697745030706, None, 'c1e85250-6eb8-11ee-a986-db1792d27da0', 'c149c860-6eb8-11ee-a986-db1792d27da0', {'configuration': {'type': 'DEFAULT'}, 'transportConfiguration': {'type': 'DEFAULT'}}, 'default', 'Test Device A1', None, 'c13a5f10-6eb8-11ee-a986-db1792d27da0', None, None, None)
# ('c2556c00-6eb8-11ee-a986-db1792d27da0', 1697745030848, None, 'c1e85250-6eb8-11ee-a986-db1792d27da0', 'c149c860-6eb8-11ee-a986-db1792d27da0', {'configuration': {'type': 'DEFAULT'}, 'transportConfiguration': {'type': 'DEFAULT'}}, 'default', 'Test Device A2', None, 'c13a5f10-6eb8-11ee-a986-db1792d27da0', None, None, None)
# ...

# %%
# psycopg2-tutorial/main.py
import psycopg2
connection = psycopg2.connect(database='thingsboard',
                                 user="thingsboard",      # or thingsboard
                                 password="postgres",
                                 host= "host.docker.internal",        #host.docker.internal  worked
                                 port = 5432
                             )

print("Successfully connected to the database.")
database_name = 'thingsboard'
cursor = connection.cursor()
# =====
table_name = 'device'
cursor.execute(f"SELECT * FROM ts_kv WHERE entity_id = '8f6fd960-6f21-11ee-acb9-cf4e84cef63d'")
table_data = cursor.fetchall()

for row in table_data:
    print(row)
# =====
# Close the cursor and the database connection
cursor.close()
connection.close()
# Out:
# Successfully connected to the database.
# ('8f6fd960-6f21-11ee-acb9-cf4e84cef63d', 29, 1697790178753, None, None, 25, None, None)
# ('8f6fd960-6f21-11ee-acb9-cf4e84cef63d', 29, 1697790180566, None, None, 25, None, None)
# ('8f6fd960-6f21-11ee-acb9-cf4e84cef63d', 29, 1697790181400, None, None, 25, None, None)
# ('8f6fd960-6f21-11ee-acb9-cf4e84cef63d', 29, 1697790182162, None, None, 25, None, None)
# ('8f6fd960-6f21-11ee-acb9-cf4e84cef63d', 29, 1697790182919, None, None, 25, None, None)
# ('8f6fd960-6f21-11ee-acb9-cf4e84cef63d', 29, 1697790183575, None, None, 25, None, None)
# ('8f6fd960-6f21-11ee-acb9-cf4e84cef63d', 29, 1697790184334, None, None, 25, None, None)
# ('8f6fd960-6f21-11ee-acb9-cf4e84cef63d', 29, 1697790185094, None, None, 25, None, None)
# ('8f6fd960-6f21-11ee-acb9-cf4e84cef63d', 54, 1697816322957, None, None, 2, None, None)
# ('8f6fd960-6f21-11ee-acb9-cf4e84cef63d', 55, 1697816322957, None, None, 3, None, None)
# ...

# %%
import os
print(os.getcwd())
# Out:
# /home/jovyan/work

# %%
mkdir -p /home/jovyan/work/exports/

# %%
query = """COPY (SELECT * FROM ts_kv WHERE entity_id = '8f6fd960-6f21-11ee-acb9-cf4e84cef63d') TO '/home/jovyan/work/exports/exported_data.csv' DELIMITER ',' CSV HEADER;"""
# psycopg2-tutorial/main.py
import psycopg2

import os

# Define the target directory path within the container
export_directory = '/home/jovyan/work/exports/'
export_file = 'exported_data.csv'
export_path = os.path.join(export_directory, export_file)

connection = psycopg2.connect(database='thingsboard',
                                 user="thingsboard",      # or thingsboard
                                 password="postgres",
                                 host= "host.docker.internal",        #host.docker.internal  worked
                                 port = 5432
                             )

print("Successfully connected to the database.")
database_name = 'thingsboard'
cursor = connection.cursor()
# =====
try:
    cursor.execute(query)
    connection.commit()
    print("Data exported successfully to", export_path)
except Exception as e:
    print("Error exporting data:", e)
finally:
    cursor.close()
    connection.close()
# Out:
# Successfully connected to the database.
# Error exporting data: could not open file "/home/jovyan/work/exports/exported_data.csv" for writing: No such file or directory
# HINT:  COPY TO instructs the PostgreSQL server process to write a file. You may want a client-side facility such as psql's \copy.

# %%
# schedular
