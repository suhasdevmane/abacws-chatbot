# %% [markdown]
# ## User input sensor data

# %%
sensor_nodes = [
    "node_5.01",
    "node_5.02",
    "node_5.03",
    "node_5.04",
    "node_5.05",
    "node_5.06",
    "node_5.07",
    "node_5.08",
    "node_5.09",
    "node_5.10",
    "node_5.11",
    "node_5.12",
    "node_5.13",
    "node_5.14",
    "node_5.15",
    "node_5.16",
    "node_5.17",
    "node_5.18",
    "node_5.19",
    "node_5.20",
    "node_5.21",
    "node_5.22",
    "node_5.23",
    "node_5.24",
    "node_5.25",
    "node_5.26",
    "node_5.27",
    "node_5.28",
    "node_5.29",
    "node_5.30",
    "node_5.31",
    "node_5.32",
    "node_5.33",
    "node_5.34",
]

data_to_fetch = [
    "airQualityValue",
    "c2h5ch",
    "co_gas",
    "co2value",
    "PM10Atmospheric",
    "hchoppmvalue",
    "humidity",
    "lux",
    "rsroratio5",
    "rsroratio9",
    "rsroratio3",
    "rsroratio2",
    "NO2",
    "o2per",
    "memsvalue",
    "tempreture",
    "VOC",
]

device_name_variable = input(f"What device do you see? ({', '.join(sensor_nodes)}): ")
user_input_key = input(
    f"What sensor readings do you need? ({', '.join(data_to_fetch)}): "
)


# device_name_variable = input("choose a device")  # "node_5.08"
# user_input_key = input("choose a sensor")  # "NO2"


import psycopg2
from psycopg2.extras import DictCursor
from prettytable import PrettyTable
from datetime import datetime

connection1 = psycopg2.connect(
    database="thingsboard",
    user="thingsboard",
    password="postgres",
    host="localhost",
    port=5432,
)
cursor1 = connection1.cursor(cursor_factory=DictCursor)
query1 = f"""
SELECT key_id FROM ts_kv_dictionary
WHERE key = '{user_input_key}';
"""
cursor1.execute(query1)
rows1 = cursor1.fetchall()
key_id_result = rows1[0]["key_id"] if rows1 else None
print("Key ID:", key_id_result)
cursor1.close()

# Mapping dictionary for device_name to entity_id
device_name_to_entity_id = {
    "node_5.01": "478abf30-7db2-11ee-b0f3-69bd975277c1",
    "node_5.02": "5306a860-7db2-11ee-b0f3-69bd975277c1",
    "node_5.03": "6b52c020-7db2-11ee-b0f3-69bd975277c1",
    "node_5.04": "725a3830-7db2-11ee-b0f3-69bd975277c1",
    "node_5.05": "78df12c0-7db2-11ee-b0f3-69bd975277c1",
    "node_5.06": "8084c6a0-7db2-11ee-b0f3-69bd975277c1",
    "node_5.07": "8c34df30-7db2-11ee-b0f3-69bd975277c1",
    "node_5.08": "93834b50-7db2-11ee-b0f3-69bd975277c1",
    "node_5.09": "997b9d50-7db2-11ee-b0f3-69bd975277c1",
    "node_5.10": "9f44f010-7db2-11ee-b0f3-69bd975277c1",
    "node_5.11": "a6250a00-7db2-11ee-b0f3-69bd975277c1",
    "node_5.12": "add0b150-7db2-11ee-b0f3-69bd975277c1",
    "node_5.13": "b4f415d0-7db2-11ee-b0f3-69bd975277c1",
    "node_5.14": "bad9ca30-7db2-11ee-b0f3-69bd975277c1",
    "node_5.15": "c0fe3540-7db2-11ee-b0f3-69bd975277c1",
    "node_5.16": "729855d0-7db6-11ee-b0f3-69bd975277c1",
    "node_5.17": "328afde0-83f5-11ee-a992-8978af4232d8",
    "node_5.18": "37c9eaf0-83f5-11ee-a992-8978af4232d8",
    "node_5.19": "3d369ec0-83f5-11ee-a992-8978af4232d8",
    "node_5.20": "4e709010-83f5-11ee-a992-8978af4232d8",
    "node_5.21": "53491a30-83f5-11ee-a992-8978af4232d8",
    "node_5.22": "58b83f00-83f5-11ee-a992-8978af4232d8",
    "node_5.23": "5d800040-83f5-11ee-a992-8978af4232d8",
    "node_5.24": "620958f0-83f5-11ee-a992-8978af4232d8",
    "node_5.25": "6694ad70-83f5-11ee-a992-8978af4232d8",
    "node_5.26": "6b6a7870-83f5-11ee-a992-8978af4232d8",
    "node_5.27": "7091e5e0-83f5-11ee-a992-8978af4232d8",
    "node_5.28": "759e7850-83f5-11ee-a992-8978af4232d8",
    "node_5.29": "7b537fc0-83f5-11ee-a992-8978af4232d8",
    "node_5.30": "7ffd58c0-83f5-11ee-a992-8978af4232d8",
    "node_5.31": "84bd51d0-83f5-11ee-a992-8978af4232d8",
    "node_5.32": "8afd3420-83f5-11ee-a992-8978af4232d8",
    "node_5.33": "90088e10-83f5-11ee-a992-8978af4232d8",
    "node_5.34": "9586a700-83f5-11ee-a992-8978af4232d8"
    # Add more mappings as needed
}


entity_id_variable = device_name_to_entity_id.get(device_name_variable, "")

if not entity_id_variable:
    print(f"Device with name '{device_name_variable}' not found in the mapping.")
    exit()

connection = psycopg2.connect(
    database="thingsboard",
    user="thingsboard",
    password="postgres",
    host="localhost",
    port=5432,
)

cursor2 = connection.cursor(cursor_factory=DictCursor)

query = f"""
SELECT 
  entity_id, 
  ts, 
  uuid, 
  COALESCE(bool_v::TEXT, str_v, long_v::TEXT, dbl_v::TEXT, json_v::TEXT) AS actual_value
FROM 
  ts_kv
WHERE
  entity_id = '{entity_id_variable}'
  AND key = {key_id_result}
ORDER BY 
  ts DESC
LIMIT 50
"""

cursor2.execute(query)
rows = cursor2.fetchall()

# Create a PrettyTable object
table = PrettyTable()
table.field_names = ["entity_id", "ts (formatted)", "uuid", "actual_value"]

# Add rows to the table
for row in rows:
    # Convert the timestamp to a formatted date and time
    formatted_ts = datetime.utcfromtimestamp(row["ts"] / 1000.0).strftime(
        "%Y-%m-%d %H:%M:%S"
    )
    # Add the row with the formatted timestamp
    table.add_row([row["entity_id"], formatted_ts, row["uuid"], row["actual_value"]])

# Print the table
print(table)

# Close the cursor and the database connection
cursor2.close()
connection.close()
# Out:
# Key ID: 130
# +--------------------------------------+---------------------+--------------------------------------+--------------+
# |              entity_id               |    ts (formatted)   |                 uuid                 | actual_value |
# +--------------------------------------+---------------------+--------------------------------------+--------------+
# | 8084c6a0-7db2-11ee-b0f3-69bd975277c1 | 2023-11-30 21:52:23 | a2961ebb-622b-4808-9c5c-f5d6284d5721 |     245      |
# | 8084c6a0-7db2-11ee-b0f3-69bd975277c1 | 2023-11-30 21:52:01 | 6a29d4b2-ac91-4a7e-9908-e5a27035f43a |     250      |
# | 8084c6a0-7db2-11ee-b0f3-69bd975277c1 | 2023-11-30 21:51:39 | b5c7b346-fb1c-45f2-91d7-6b4b1e811934 |     246      |
# | 8084c6a0-7db2-11ee-b0f3-69bd975277c1 | 2023-11-30 21:51:22 | 08579940-5c75-48cd-9d73-e4ec872bdc15 |     245      |
# | 8084c6a0-7db2-11ee-b0f3-69bd975277c1 | 2023-11-30 21:50:56 | cca055df-8088-4448-b395-f5f05dfd0f66 |     249      |
# | 8084c6a0-7db2-11ee-b0f3-69bd975277c1 | 2023-11-30 21:50:39 | 54b28940-87e0-48e1-bf37-a21749b31a64 |     245      |
# | 8084c6a0-7db2-11ee-b0f3-69bd975277c1 | 2023-11-30 21:50:08 | 193dfd05-ee99-4d0a-86c3-b6c6420933c8 |     250      |
# | 8084c6a0-7db2-11ee-b0f3-69bd975277c1 | 2023-11-30 21:49:45 | 165f7707-c0a0-4b80-889c-e290397cad3d |     251      |
# | 8084c6a0-7db2-11ee-b0f3-69bd975277c1 | 2023-11-30 21:49:18 | f3313f1f-f8a7-4493-aac7-4ba37be0e266 |     251      |
# | 8084c6a0-7db2-11ee-b0f3-69bd975277c1 | 2023-11-30 21:48:59 | d6faf775-ff23-4e55-83af-b1482acde0fe |     249      |
# | 8084c6a0-7db2-11ee-b0f3-69bd975277c1 | 2023-11-30 21:48:35 | 85aae1d1-0da3-44b8-b64b-0259e8bbb483 |     249      |
# | 8084c6a0-7db2-11ee-b0f3-69bd975277c1 | 2023-11-30 21:48:08 | 5815db73-b4bf-4818-b36c-e744909a2610 |     251      |
# | 8084c6a0-7db2-11ee-b0f3-69bd975277c1 | 2023-11-30 21:47:41 | 2305a0ac-43f5-448b-9401-a9e4a70f2b7e |     249      |
# | 8084c6a0-7db2-11ee-b0f3-69bd975277c1 | 2023-11-30 21:47:23 | ebb850dd-1b5d-4bfa-96e1-7358d39486a1 |     245      |
# | 8084c6a0-7db2-11ee-b0f3-69bd975277c1 | 2023-11-30 21:47:04 | 14182a81-38c9-4b05-bfb1-2a07f0fd0192 |     249      |
# | 8084c6a0-7db2-11ee-b0f3-69bd975277c1 | 2023-11-30 21:46:46 | 2dcd4872-e205-4438-8322-e2d569f1f274 |     248      |
# | 8084c6a0-7db2-11ee-b0f3-69bd975277c1 | 2023-11-30 21:46:21 | 4c730ec2-6b99-43ed-a3cd-2e1205c77ab9 |     246      |
# | 8084c6a0-7db2-11ee-b0f3-69bd975277c1 | 2023-11-30 21:45:50 | 6556de44-0083-4081-a545-e40a62a9055c |     248      |
# | 8084c6a0-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 19:04:53 | bf4e3973-f316-4d3c-9281-e80c08d5402b |     246      |
# | 8084c6a0-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 19:04:42 | 9e3547df-4703-41b9-840d-5d9016461423 |     251      |
# | 8084c6a0-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 19:04:31 | 72c31c7d-76a3-438d-ac77-6c9b58d61325 |     248      |
# | 8084c6a0-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 19:04:20 | 9706fef3-7e5f-438b-b0a6-64ec338cc996 |     245      |
# | 8084c6a0-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 19:04:08 | 0620d825-20aa-43b5-b593-09dbab0695d9 |     247      |
# | 8084c6a0-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 19:03:57 | e140be7b-6308-46ed-82ac-b21e179e9588 |     250      |
# | 8084c6a0-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 19:03:45 | 73833f64-792f-40dc-ac28-41a8b29567d5 |     251      |
# | 8084c6a0-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 19:03:34 | caafd788-2399-41a6-b039-a332271dee76 |     248      |
# | 8084c6a0-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 19:03:22 | d8b9c471-2015-42c6-88c6-1396366ea1b7 |     251      |
# | 8084c6a0-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 19:03:11 | 71b324b6-d68e-4bb6-929e-d80e20794a5f |     247      |
# | 8084c6a0-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 19:02:59 | e524c849-3155-4a4e-9af3-68a7b23e16a0 |     246      |
# | 8084c6a0-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 19:02:47 | c92eaf88-ef07-48ff-b85d-db978d3b144c |     251      |
# | 8084c6a0-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 19:02:36 | be7235ae-23c7-467f-848c-b0ed48ce6d65 |     247      |
# | 8084c6a0-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 19:02:24 | 9c7833d6-759b-46db-93cb-328b6b3adcbb |     250      |
# | 8084c6a0-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 19:02:12 | 03708d66-4d02-4964-8506-afd89f104980 |     245      |
# | 8084c6a0-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 19:02:00 | 2a177eb1-2d7e-4aea-b7d2-c7c2a37e538f |     250      |
# | 8084c6a0-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 19:01:49 | 18608d4c-ef4a-484d-b1a3-10773189f59f |     249      |
# | 8084c6a0-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 19:01:37 | 75be34f2-733d-4946-91bb-d87c17295ab6 |     245      |
# | 8084c6a0-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 19:01:26 | 744d0951-4cc0-45fa-9ebf-00ca6de66f38 |     246      |
# | 8084c6a0-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 19:01:14 | 08933969-63d7-4ae6-9a46-0de6d0dc2b4f |     246      |
# | 8084c6a0-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 19:01:02 | 9f9255a4-629f-45e4-9678-dc3881833a9f |     247      |
# | 8084c6a0-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 19:00:50 | 3eb1cfb9-6f77-4380-b1a6-e5155a1ab407 |     245      |
# | 8084c6a0-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 19:00:39 | 23a0ee15-3f63-4d4c-bbef-d7abde60521f |     250      |
# | 8084c6a0-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 19:00:28 | b40be4b3-f109-4565-9f79-a94c5325e7f2 |     247      |
# | 8084c6a0-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 19:00:17 | eb62c4f6-5746-454a-9ba5-72f2afb0a90f |     247      |
# | 8084c6a0-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 19:00:05 | e85cc1b5-3f86-4542-9e86-630ce06b20f8 |     250      |
# | 8084c6a0-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 18:59:54 | 19b530be-cea8-4923-ab30-9e3e1d5854b8 |     248      |
# | 8084c6a0-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 18:59:43 | c1e45037-7259-432d-8820-fe58958bdb27 |     247      |
# | 8084c6a0-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 18:59:32 | 63ac6ffe-5cdb-4067-b8e0-bb93aab58b4f |     245      |
# | 8084c6a0-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 18:59:21 | de7193e2-aa26-46a8-b66c-1d72240991ab |     245      |
# | 8084c6a0-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 18:59:10 | 508d3c56-eb1c-4560-a36a-d7fec07da072 |     247      |
# | 8084c6a0-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 18:58:58 | bf96bc9d-68cb-453a-84fc-fe5ca92e25f1 |     251      |
# +--------------------------------------+---------------------+--------------------------------------+--------------+
# C:\Users\c21054458\AppData\Local\Temp\ipykernel_13736\2743272812.py:173: DeprecationWarning: datetime.datetime.utcfromtimestamp() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.fromtimestamp(timestamp, datetime.UTC).
#   formatted_ts = datetime.utcfromtimestamp(row["ts"] / 1000.0).strftime(

# %% [markdown]
# ## Code to get final code

# %%
# pip install --user -r requirements.txt

# %%
# psycopg2-tutorial/main.py
import psycopg2

connection = psycopg2.connect(
    database="thingsboard",
    user="thingsboard",  # or thingsboard
    password="postgres",
    host="localhost",  # host.docker.internal  for jupyter notebook in docker
    port=5432,
)

print("Successfully connected to the database.")

# Open a cursor to perform database operations
cursor = connection.cursor()

# Execute a query
cursor.execute("SELECT datname FROM pg_database;")
databases = cursor.fetchall()

for db in databases:
    print("Database:", db[0])
# Out:
# Successfully connected to the database.
# Database: postgres
# Database: thingsboard
# Database: template1
# Database: template0

# %%
# psycopg2-tutorial/main.py
import psycopg2

connection = psycopg2.connect(
    database="thingsboard",
    user="thingsboard",  # or thingsboard
    password="postgres",
    host="localhost",  # host.docker.internal  for jupyter notebook in docker
    port=5432,
)

print("Successfully connected to the database.")


# To list the tables within a specific database
# Replace 'your_database_name' with the name of the database you want to explore
database_name = "thingsboard"

cursor.execute(
    f"SELECT table_name FROM information_schema.tables WHERE table_schema = 'public';"
)
tables = cursor.fetchall()

for table in tables:
    print("Table:", table[0])

# Close the cursor and the database connection
cursor.close()
connection.close()
# Out:
# Successfully connected to the database.
# Table: tb_schema_settings
# Table: admin_settings
# Table: audit_log
# Table: alarm_comment
# Table: alarm
# Table: entity_alarm
# Table: attribute_kv
# Table: component_descriptor
# Table: customer
# Table: rule_node
# Table: rule_node_state
# Table: queue
# Table: rule_chain
# Table: asset_profile
# Table: dashboard
# Table: asset
# Table: device_profile
# Table: ota_package
# Table: device
# Table: device_credentials
# Table: rule_node_debug_event
# Table: rule_chain_debug_event
# Table: error_event
# Table: relation
# Table: lc_event
# Table: stats_event
# Table: tenant_profile
# Table: tenant
# Table: user_credentials
# Table: widgets_bundle
# Table: widgets_bundle_widget
# Table: widget_type
# Table: entity_view
# Table: ts_kv_latest
# Table: ts_kv_dictionary
# Table: oauth2_params
# Table: oauth2_registration
# Table: oauth2_domain
# Table: oauth2_mobile
# Table: oauth2_client_registration_template
# Table: oauth2_client_registration_info
# Table: oauth2_client_registration
# Table: api_usage_state
# Table: resource
# Table: edge
# Table: edge_event
# Table: rpc
# Table: tb_user
# Table: user_auth_settings
# Table: notification_target
# Table: notification_template
# Table: notification_rule
# Table: notification_request
# Table: user_settings
# Table: alarm_types
# Table: notification
# Table: device_info_active_attribute_view
# Table: device_info_active_ts_view
# Table: alarm_info
# Table: device_info_view
# Table: ts_kv
# Table: ts_kv_indefinite
# Table: lc_event_1697673600000
# Table: stats_event_1697673600000
# Table: audit_log_1697673600000
# Table: lc_event_1698278400000
# Table: audit_log_1698278400000
# Table: stats_event_1698278400000
# Table: lc_event_1698883200000
# Table: audit_log_1698883200000
# Table: stats_event_1698883200000
# Table: lc_event_1699488000000
# Table: notification_1698883200000
# Table: stats_event_1699488000000
# Table: audit_log_1699488000000
# Table: notification_1699488000000
# Table: lc_event_1700092800000
# Table: stats_event_1700092800000
# Table: audit_log_1700092800000
# Table: notification_1700092800000
# Table: audit_log_1700697600000
# Table: lc_event_1700697600000
# Table: ts_kv_2023_10
# Table: ts_kv_2023_11
# Table: stats_event_1700697600000
# Table: lc_event_1701302400000
# Table: stats_event_1701302400000
# Table: audit_log_1701302400000

# %% [markdown]
# get list of entity_id which are actually device ids from thingsboard

# %%
import psycopg2
from psycopg2.extras import DictCursor
from prettytable import PrettyTable

connection = psycopg2.connect(
    database="thingsboard",
    user="thingsboard",
    password="postgres",
    host="localhost",
    port=5432,
)

print("Successfully connected to the database.")

cursor = connection.cursor(cursor_factory=DictCursor)

query = """
SELECT DISTINCT entity_id
FROM ts_kv;
"""

cursor.execute(query)
rows = cursor.fetchall()

# Create a PrettyTable object
table = PrettyTable()
table.field_names = rows[0].keys() if rows else []

# Add rows to the table
for row in rows:
    table.add_row(list(row.values()))

# Print the table
print(table)

# Close the cursor and the database connection
cursor.close()
connection.close()
# Out:
# Successfully connected to the database.
# +--------------------------------------+
# |              entity_id               |
# +--------------------------------------+
# | 02295090-6f21-11ee-acb9-cf4e84cef63d |
# | 1c2ccd00-8993-11ee-ab00-5153f1fedf71 |
# | 328afde0-83f5-11ee-a992-8978af4232d8 |
# | 33c6a0f0-854f-11ee-aed1-b920893f2f71 |
# | 349ecb90-6f21-11ee-acb9-cf4e84cef63d |
# | 37c9eaf0-83f5-11ee-a992-8978af4232d8 |
# | 3d369ec0-83f5-11ee-a992-8978af4232d8 |
# | 458e7340-6eba-11ee-b96f-a3213e882834 |
# | 478abf30-7db2-11ee-b0f3-69bd975277c1 |
# | 4e709010-83f5-11ee-a992-8978af4232d8 |
# | 5306a860-7db2-11ee-b0f3-69bd975277c1 |
# | 53491a30-83f5-11ee-a992-8978af4232d8 |
# | 58b83f00-83f5-11ee-a992-8978af4232d8 |
# | 5d800040-83f5-11ee-a992-8978af4232d8 |
# | 620958f0-83f5-11ee-a992-8978af4232d8 |
# | 6694ad70-83f5-11ee-a992-8978af4232d8 |
# | 6b52c020-7db2-11ee-b0f3-69bd975277c1 |
# | 6b6a7870-83f5-11ee-a992-8978af4232d8 |
# | 7091e5e0-83f5-11ee-a992-8978af4232d8 |
# | 725a3830-7db2-11ee-b0f3-69bd975277c1 |
# +--------------------------------------+

# %%
import psycopg2
from psycopg2.extras import DictCursor
from prettytable import PrettyTable

connection = psycopg2.connect(
    database="thingsboard",
    user="thingsboard",
    password="postgres",
    host="localhost",
    port=5432,
)

print("Successfully connected to the database.")

cursor = connection.cursor(cursor_factory=DictCursor)

query = """
SELECT entity_id, uuid, ts, key
FROM ts_kv
WHERE entity_id = 'b4f415d0-7db2-11ee-b0f3-69bd975277c1'
LIMIT 15;

"""

cursor.execute(query)
rows = cursor.fetchall()

# Create a PrettyTable object
table = PrettyTable()
table.field_names = rows[0].keys() if rows else []

# Add rows to the table
for row in rows:
    table.add_row(list(row.values()))

# Print the table
print(table)

# Close the cursor and the database connection
cursor.close()
connection.close()
# Out:
# Successfully connected to the database.
# +--------------------------------------+--------------------------------------+---------------+-----+
# |              entity_id               |                 uuid                 |       ts      | key |
# +--------------------------------------+--------------------------------------+---------------+-----+
# | b4f415d0-7db2-11ee-b0f3-69bd975277c1 | 54f310d5-f091-4c33-b703-543c39955840 | 1700080715645 |  73 |
# | b4f415d0-7db2-11ee-b0f3-69bd975277c1 | 19194c07-00dc-431d-897b-97096fc0a971 | 1700080715645 |  74 |
# | b4f415d0-7db2-11ee-b0f3-69bd975277c1 | 5e9d8acc-fe9c-43bd-ba61-8d5e93f9b2b5 | 1700080715645 |  75 |
# | b4f415d0-7db2-11ee-b0f3-69bd975277c1 | 3aaffcc5-4fa7-477b-b7dd-935873f0c2be | 1700080715645 |  76 |
# | b4f415d0-7db2-11ee-b0f3-69bd975277c1 | 8d499c66-c092-4e66-a6a1-41d0b718327c | 1700080715645 |  77 |
# | b4f415d0-7db2-11ee-b0f3-69bd975277c1 | 5e448538-9a84-4106-b7b6-dc80408cce4b | 1700080715645 |  78 |
# | b4f415d0-7db2-11ee-b0f3-69bd975277c1 | 09f018e0-1fc9-4fff-8caf-ef2a0ebb0be2 | 1700080715645 |  79 |
# | b4f415d0-7db2-11ee-b0f3-69bd975277c1 | 733ace1e-86d1-4fe6-9e5d-65794d519e0c | 1700080715645 |  80 |
# | b4f415d0-7db2-11ee-b0f3-69bd975277c1 | 1b4305df-c757-4b28-bef4-655f600e8cd6 | 1700080715645 |  81 |
# | b4f415d0-7db2-11ee-b0f3-69bd975277c1 | 888a861e-7204-4f43-925f-6103242c034e | 1700080715645 |  82 |
# | b4f415d0-7db2-11ee-b0f3-69bd975277c1 | ec88fb8c-2600-4d9d-8ee2-cb416667cfcf | 1700080715645 |  83 |
# | b4f415d0-7db2-11ee-b0f3-69bd975277c1 | 882f80ef-f8c9-4c69-9e81-001f85ea0d62 | 1700080715645 |  84 |
# | b4f415d0-7db2-11ee-b0f3-69bd975277c1 | 384cc5e4-165f-4459-be75-f2aee7fb2f6d | 1700080715645 |  85 |
# | b4f415d0-7db2-11ee-b0f3-69bd975277c1 | 135e23f5-2674-4bc7-8a98-cda1dbb96002 | 1700080715645 |  86 |
# | b4f415d0-7db2-11ee-b0f3-69bd975277c1 | 66583738-8978-4ab5-bcdd-4af5a1e6460b | 1700080715645 |  87 |
# +--------------------------------------+--------------------------------------+---------------+-----+

# %%
import psycopg2
from psycopg2.extras import DictCursor
from prettytable import PrettyTable
from datetime import datetime

connection = psycopg2.connect(
    database="thingsboard",
    user="thingsboard",
    password="postgres",
    host="localhost",
    port=5432,
)

print("Successfully connected to the database.")

cursor = connection.cursor(cursor_factory=DictCursor)

query = """
SELECT uuid, ts, key
FROM ts_kv
WHERE entity_id = 'b4f415d0-7db2-11ee-b0f3-69bd975277c1'
LIMIT 25;
"""

cursor.execute(query)
rows = cursor.fetchall()

# Create a PrettyTable object
table = PrettyTable()
table.field_names = ["uuid", "ts", "key"]

# Add rows to the table
for row in rows:
    # Convert the timestamp to a formatted date and time
    formatted_ts = datetime.utcfromtimestamp(row["ts"] / 1000.0).strftime(
        "%Y-%m-%d %H:%M:%S"
    )
    # Add the row with the formatted timestamp
    table.add_row([row["uuid"], formatted_ts, row["key"]])

# Print the table
print(table)

# Close the cursor and the database connection
cursor.close()
connection.close()
# Out:
# Successfully connected to the database.
# +--------------------------------------+---------------------+-----+
# |                 uuid                 |          ts         | key |
# +--------------------------------------+---------------------+-----+
# | 54f310d5-f091-4c33-b703-543c39955840 | 2023-11-15 20:38:35 |  73 |
# | 19194c07-00dc-431d-897b-97096fc0a971 | 2023-11-15 20:38:35 |  74 |
# | 5e9d8acc-fe9c-43bd-ba61-8d5e93f9b2b5 | 2023-11-15 20:38:35 |  75 |
# | 3aaffcc5-4fa7-477b-b7dd-935873f0c2be | 2023-11-15 20:38:35 |  76 |
# | 8d499c66-c092-4e66-a6a1-41d0b718327c | 2023-11-15 20:38:35 |  77 |
# | 5e448538-9a84-4106-b7b6-dc80408cce4b | 2023-11-15 20:38:35 |  78 |
# | 09f018e0-1fc9-4fff-8caf-ef2a0ebb0be2 | 2023-11-15 20:38:35 |  79 |
# | 733ace1e-86d1-4fe6-9e5d-65794d519e0c | 2023-11-15 20:38:35 |  80 |
# | 1b4305df-c757-4b28-bef4-655f600e8cd6 | 2023-11-15 20:38:35 |  81 |
# | 888a861e-7204-4f43-925f-6103242c034e | 2023-11-15 20:38:35 |  82 |
# | ec88fb8c-2600-4d9d-8ee2-cb416667cfcf | 2023-11-15 20:38:35 |  83 |
# | 882f80ef-f8c9-4c69-9e81-001f85ea0d62 | 2023-11-15 20:38:35 |  84 |
# | 384cc5e4-165f-4459-be75-f2aee7fb2f6d | 2023-11-15 20:38:35 |  85 |
# | 135e23f5-2674-4bc7-8a98-cda1dbb96002 | 2023-11-15 20:38:35 |  86 |
# | 66583738-8978-4ab5-bcdd-4af5a1e6460b | 2023-11-15 20:38:35 |  87 |
# | 3720e8a6-a096-48ce-b67b-6742ba9091b4 | 2023-11-15 20:38:35 |  88 |
# | 96890477-9c69-45d6-9a21-100bbe4cbde4 | 2023-11-15 20:38:35 |  89 |
# | a5d49ef4-ac3a-4d15-b77b-81bf8b5936c5 | 2023-11-15 20:38:35 |  90 |
# | 3c8eb713-ed98-43d0-bba4-af7d6caf3a4a | 2023-11-15 20:38:35 |  91 |
# | 37177e06-d785-494d-99e0-9d9b25dbc86d | 2023-11-15 20:38:35 |  92 |
# | c97b4d47-5534-43f1-8378-541a8b666698 | 2023-11-15 20:38:35 |  93 |
# | 8311f546-b50c-4d79-aed5-f808b5ae91be | 2023-11-15 20:38:35 |  94 |
# | 53b55bf3-e43c-4f3a-8989-d76ffc71b233 | 2023-11-15 20:38:35 |  95 |
# | a59b9f1f-5c87-4c5a-9cf7-7cf6e60eebc9 | 2023-11-15 20:38:35 |  96 |
# | e7287dd7-c2f5-4bd2-bc59-f199925ff887 | 2023-11-15 20:38:35 |  97 |
# +--------------------------------------+---------------------+-----+
# C:\Users\c21054458\AppData\Local\Temp\ipykernel_24188\3951891814.py:35: DeprecationWarning: datetime.datetime.utcfromtimestamp() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.fromtimestamp(timestamp, datetime.UTC).
#   formatted_ts = datetime.utcfromtimestamp(row["ts"] / 1000.0).strftime(

# %%
import psycopg2
from psycopg2.extras import DictCursor
from prettytable import PrettyTable
from datetime import datetime

# Define the entity_id variable
entity_id_variable = "b4f415d0-7db2-11ee-b0f3-69bd975277c1"

connection = psycopg2.connect(
    database="thingsboard",
    user="thingsboard",
    password="postgres",
    host="localhost",
    port=5432,
)

print("Successfully connected to the database.")

cursor = connection.cursor(cursor_factory=DictCursor)

query = f"""
SELECT entity_id, ts, key, uuid, dbl_v
FROM ts_kv
WHERE entity_id = '{entity_id_variable}'
  AND key = 120
ORDER BY ts DESC
LIMIT 50;
"""

cursor.execute(query)
rows = cursor.fetchall()

# Create a PrettyTable object
table = PrettyTable()
table.field_names = ["entity_id", "ts (formatted)", "key", "uuid", "dbl_v"]

# Add rows to the table
for row in rows:
    # Convert the timestamp to a formatted date and time
    formatted_ts = datetime.utcfromtimestamp(row["ts"] / 1000.0).strftime(
        "%Y-%m-%d %H:%M:%S"
    )
    # Add the row with the formatted timestamp
    table.add_row(
        [row["entity_id"], formatted_ts, row["key"], row["uuid"], row["dbl_v"]]
    )

# Print the table
print(table)

# Close the cursor and the database connection
cursor.close()
connection.close()
# Out:
# Successfully connected to the database.
# +--------------------------------------+---------------------+-----+--------------------------------------+--------+
# |              entity_id               |    ts (formatted)   | key |                 uuid                 | dbl_v  |
# +--------------------------------------+---------------------+-----+--------------------------------------+--------+
# | b4f415d0-7db2-11ee-b0f3-69bd975277c1 | 2023-11-30 21:52:24 | 120 | 1c440572-bddc-4c32-bdb0-b1850ae67b4d | 159.71 |
# | b4f415d0-7db2-11ee-b0f3-69bd975277c1 | 2023-11-30 21:52:02 | 120 | 753b1cd8-22a0-4f2e-8449-b0950d08ab12 | 159.88 |
# | b4f415d0-7db2-11ee-b0f3-69bd975277c1 | 2023-11-30 21:51:40 | 120 | 15adc1ee-c91f-4d6d-b80d-d3a019e031df | 152.74 |
# | b4f415d0-7db2-11ee-b0f3-69bd975277c1 | 2023-11-30 21:51:22 | 120 | 381f8ec6-4a92-4038-83da-2c1f3685e1d2 | 151.04 |
# | b4f415d0-7db2-11ee-b0f3-69bd975277c1 | 2023-11-30 21:50:57 | 120 | 6ddc0da9-0d2e-4791-8780-1f4101d81beb | 158.71 |
# | b4f415d0-7db2-11ee-b0f3-69bd975277c1 | 2023-11-30 21:50:39 | 120 | 707d3975-8d3e-47c3-8963-0939da221eb8 | 150.33 |
# | b4f415d0-7db2-11ee-b0f3-69bd975277c1 | 2023-11-30 21:50:13 | 120 | 65f24ed7-33d4-4902-8a4b-cfac9601c7e3 | 154.32 |
# | b4f415d0-7db2-11ee-b0f3-69bd975277c1 | 2023-11-30 21:49:46 | 120 | ed5d2b9c-7420-44e3-90e9-f4be6f0ab4b7 | 153.76 |
# | b4f415d0-7db2-11ee-b0f3-69bd975277c1 | 2023-11-30 21:49:19 | 120 | fd11f183-dfba-4276-8025-d2525302823b | 155.54 |
# | b4f415d0-7db2-11ee-b0f3-69bd975277c1 | 2023-11-30 21:48:59 | 120 | 26a4f75d-fa7a-4176-9bc6-2ae6402b1b81 | 152.8  |
# | b4f415d0-7db2-11ee-b0f3-69bd975277c1 | 2023-11-30 21:48:36 | 120 | d885ea50-480a-4e88-ba33-59f50d1751f2 | 153.24 |
# | b4f415d0-7db2-11ee-b0f3-69bd975277c1 | 2023-11-30 21:48:09 | 120 | 263c864e-46b0-4b9f-95d0-4a8f9758c171 | 157.17 |
# | b4f415d0-7db2-11ee-b0f3-69bd975277c1 | 2023-11-30 21:47:42 | 120 | bc8feafa-e939-4b38-8e5b-f92d8908e385 | 158.83 |
# | b4f415d0-7db2-11ee-b0f3-69bd975277c1 | 2023-11-30 21:47:24 | 120 | 08110b3e-0943-432f-9880-3020da390f03 | 157.52 |
# | b4f415d0-7db2-11ee-b0f3-69bd975277c1 | 2023-11-30 21:47:05 | 120 | 49ecf5c8-fc0c-4175-a4b3-69cb66d77a55 | 157.91 |
# | b4f415d0-7db2-11ee-b0f3-69bd975277c1 | 2023-11-30 21:46:47 | 120 | 4bb9703f-2784-4bb9-8c36-d6418115d1dd | 152.03 |
# | b4f415d0-7db2-11ee-b0f3-69bd975277c1 | 2023-11-30 21:46:22 | 120 | c02a4dc2-73fc-4d7e-bee8-ad9ddc386d1b | 150.19 |
# | b4f415d0-7db2-11ee-b0f3-69bd975277c1 | 2023-11-30 21:45:52 | 120 | 86af02ae-3d60-4afb-b82f-9d3505f5f21f | 153.77 |
# | b4f415d0-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 19:04:53 | 120 | 8aa224a3-9d92-4e29-9188-ab2a857a618c | 159.05 |
# | b4f415d0-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 19:04:42 | 120 | 2bfb439c-edbe-4551-9eea-a467b10b75fa | 154.75 |
# | b4f415d0-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 19:04:31 | 120 | 1c4a8079-224d-4915-aa9e-2f4184ef7d61 | 159.47 |
# | b4f415d0-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 19:04:20 | 120 | b2184e3d-c45d-4490-a47d-4fe1f41d738b | 154.18 |
# | b4f415d0-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 19:04:09 | 120 | 2ed97a9c-3217-42b6-ad9c-dc1b0ca3fc8c | 153.24 |
# | b4f415d0-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 19:03:57 | 120 | 47ef5164-f365-4f4e-a522-91b00e13d90b | 152.89 |
# | b4f415d0-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 19:03:45 | 120 | a79e1be8-27f6-4391-8074-5e75e4eea7a8 | 156.53 |
# | b4f415d0-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 19:03:34 | 120 | fa7d2a2e-8e69-475f-b929-9612337822fa | 152.99 |
# | b4f415d0-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 19:03:23 | 120 | fa38ce1f-1566-4103-93b9-5bd706874bfa | 157.5  |
# | b4f415d0-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 19:03:11 | 120 | b3b3a027-2dec-4244-bbb2-bf32304a22ee | 158.1  |
# | b4f415d0-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 19:02:59 | 120 | bfe6d02b-ac6f-4fbf-9685-047706ddea35 | 158.21 |
# | b4f415d0-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 19:02:48 | 120 | a293dbe1-bf38-4d2a-9648-2ef419bc75a5 | 151.75 |
# | b4f415d0-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 19:02:36 | 120 | 6ee466cd-ee5b-4f47-afbd-d0c7aea0ce42 | 154.19 |
# | b4f415d0-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 19:02:24 | 120 | 2da738dd-3932-4c05-ab5a-460e0efaa0b0 | 151.08 |
# | b4f415d0-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 19:02:12 | 120 | 2f424362-2e8f-4d15-9443-53a93014b376 | 151.72 |
# | b4f415d0-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 19:02:01 | 120 | 9e6ade72-5540-4595-a9bc-e8de5051aad5 | 155.85 |
# | b4f415d0-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 19:01:49 | 120 | 61e4f873-ec0c-4f02-a582-cc335482f10f | 150.87 |
# | b4f415d0-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 19:01:38 | 120 | 7ac27dcf-a550-4e58-8914-044aa8a3a262 | 154.06 |
# | b4f415d0-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 19:01:26 | 120 | eedc1e31-6a55-4052-9269-23116fb10345 | 150.48 |
# | b4f415d0-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 19:01:14 | 120 | a20ce74c-b35d-4b15-8e1c-311a3887ab8e | 156.62 |
# | b4f415d0-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 19:01:03 | 120 | 168d93bf-eedf-42b6-807f-be7ac82b75bb | 155.02 |
# | b4f415d0-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 19:00:51 | 120 | d12596fe-e836-458a-a003-df07471c3876 | 159.25 |
# | b4f415d0-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 19:00:39 | 120 | d791464e-a6f4-4809-8b8a-47759987cabf | 150.83 |
# | b4f415d0-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 19:00:28 | 120 | 411763fa-4b81-43e6-8656-d28db273fd9a | 157.14 |
# | b4f415d0-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 19:00:17 | 120 | 629ad1ae-fcce-442e-a482-68f0481206f4 | 158.35 |
# | b4f415d0-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 19:00:05 | 120 | e5522baa-24f1-4b92-80e6-6f27a1c7b27e | 157.29 |
# | b4f415d0-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 18:59:54 | 120 | 0ffc199e-a561-4881-a2c6-e35b4dd08aef | 152.25 |
# | b4f415d0-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 18:59:43 | 120 | ece2607a-d702-42b6-8c07-e4ea466cb9ee | 154.67 |
# | b4f415d0-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 18:59:32 | 120 | 07d00f90-4ac6-4e25-8a9c-2e1745a12ca3 | 153.13 |
# | b4f415d0-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 18:59:21 | 120 | a0f793ea-c5d3-4098-9758-5026fc83d622 | 151.22 |
# | b4f415d0-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 18:59:10 | 120 | 2442071c-2aed-4743-995a-8bf8c3f54124 | 153.79 |
# | b4f415d0-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 18:58:59 | 120 | e9bf7c2d-58a1-45bf-8c93-bea9882a49f2 | 158.77 |
# +--------------------------------------+---------------------+-----+--------------------------------------+--------+
# C:\Users\c21054458\AppData\Local\Temp\ipykernel_23312\257059410.py:40: DeprecationWarning: datetime.datetime.utcfromtimestamp() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.fromtimestamp(timestamp, datetime.UTC).
#   formatted_ts = datetime.utcfromtimestamp(row["ts"] / 1000.0).strftime(

# %%
import psycopg2
from psycopg2.extras import DictCursor
from prettytable import PrettyTable
from datetime import datetime

# Mapping dictionary for device_name to entity_id
device_name_to_entity_id = {
    "node_5.01": "b4f415d0-7db2-11ee-b0f3-69bd975277c1",
    # Add more mappings as needed
}

# Define the device_name variable
device_name_variable = "node_5.01"

# Get the corresponding entity_id from the mapping dictionary
entity_id_variable = device_name_to_entity_id.get(device_name_variable, "")

if not entity_id_variable:
    print(f"Device with name '{device_name_variable}' not found in the mapping.")
    exit()

connection = psycopg2.connect(
    database="thingsboard",
    user="thingsboard",
    password="postgres",
    host="localhost",
    port=5432,
)

print("Successfully connected to the database.")

cursor = connection.cursor(cursor_factory=DictCursor)

query = f"""
SELECT entity_id, key, ts, uuid, dbl_v
FROM ts_kv
WHERE entity_id = '{entity_id_variable}'
  AND key = 120
ORDER BY ts DESC
LIMIT 50;
"""

cursor.execute(query)
rows = cursor.fetchall()

# Create a PrettyTable object
table = PrettyTable()
table.field_names = ["entity_id", "key", "ts (formatted)", "uuid", "dbl_v"]

# Add rows to the table
for row in rows:
    # Convert the timestamp to a formatted date and time
    formatted_ts = datetime.utcfromtimestamp(row["ts"] / 1000.0).strftime(
        "%Y-%m-%d %H:%M:%S"
    )
    # Add the row with the formatted timestamp
    table.add_row(
        [row["entity_id"], row["key"], formatted_ts, row["uuid"], row["dbl_v"]]
    )

# Print the table
print(table)

# Close the cursor and the database connection
cursor.close()
connection.close()
# Out:
# Successfully connected to the database.
# +--------------------------------------+-----+---------------------+--------------------------------------+--------+
# |              entity_id               | key |    ts (formatted)   |                 uuid                 | dbl_v  |
# +--------------------------------------+-----+---------------------+--------------------------------------+--------+
# | b4f415d0-7db2-11ee-b0f3-69bd975277c1 | 120 | 2023-11-30 21:52:24 | 1c440572-bddc-4c32-bdb0-b1850ae67b4d | 159.71 |
# | b4f415d0-7db2-11ee-b0f3-69bd975277c1 | 120 | 2023-11-30 21:52:02 | 753b1cd8-22a0-4f2e-8449-b0950d08ab12 | 159.88 |
# | b4f415d0-7db2-11ee-b0f3-69bd975277c1 | 120 | 2023-11-30 21:51:40 | 15adc1ee-c91f-4d6d-b80d-d3a019e031df | 152.74 |
# | b4f415d0-7db2-11ee-b0f3-69bd975277c1 | 120 | 2023-11-30 21:51:22 | 381f8ec6-4a92-4038-83da-2c1f3685e1d2 | 151.04 |
# | b4f415d0-7db2-11ee-b0f3-69bd975277c1 | 120 | 2023-11-30 21:50:57 | 6ddc0da9-0d2e-4791-8780-1f4101d81beb | 158.71 |
# | b4f415d0-7db2-11ee-b0f3-69bd975277c1 | 120 | 2023-11-30 21:50:39 | 707d3975-8d3e-47c3-8963-0939da221eb8 | 150.33 |
# | b4f415d0-7db2-11ee-b0f3-69bd975277c1 | 120 | 2023-11-30 21:50:13 | 65f24ed7-33d4-4902-8a4b-cfac9601c7e3 | 154.32 |
# | b4f415d0-7db2-11ee-b0f3-69bd975277c1 | 120 | 2023-11-30 21:49:46 | ed5d2b9c-7420-44e3-90e9-f4be6f0ab4b7 | 153.76 |
# | b4f415d0-7db2-11ee-b0f3-69bd975277c1 | 120 | 2023-11-30 21:49:19 | fd11f183-dfba-4276-8025-d2525302823b | 155.54 |
# | b4f415d0-7db2-11ee-b0f3-69bd975277c1 | 120 | 2023-11-30 21:48:59 | 26a4f75d-fa7a-4176-9bc6-2ae6402b1b81 | 152.8  |
# | b4f415d0-7db2-11ee-b0f3-69bd975277c1 | 120 | 2023-11-30 21:48:36 | d885ea50-480a-4e88-ba33-59f50d1751f2 | 153.24 |
# | b4f415d0-7db2-11ee-b0f3-69bd975277c1 | 120 | 2023-11-30 21:48:09 | 263c864e-46b0-4b9f-95d0-4a8f9758c171 | 157.17 |
# | b4f415d0-7db2-11ee-b0f3-69bd975277c1 | 120 | 2023-11-30 21:47:42 | bc8feafa-e939-4b38-8e5b-f92d8908e385 | 158.83 |
# | b4f415d0-7db2-11ee-b0f3-69bd975277c1 | 120 | 2023-11-30 21:47:24 | 08110b3e-0943-432f-9880-3020da390f03 | 157.52 |
# | b4f415d0-7db2-11ee-b0f3-69bd975277c1 | 120 | 2023-11-30 21:47:05 | 49ecf5c8-fc0c-4175-a4b3-69cb66d77a55 | 157.91 |
# | b4f415d0-7db2-11ee-b0f3-69bd975277c1 | 120 | 2023-11-30 21:46:47 | 4bb9703f-2784-4bb9-8c36-d6418115d1dd | 152.03 |
# | b4f415d0-7db2-11ee-b0f3-69bd975277c1 | 120 | 2023-11-30 21:46:22 | c02a4dc2-73fc-4d7e-bee8-ad9ddc386d1b | 150.19 |
# | b4f415d0-7db2-11ee-b0f3-69bd975277c1 | 120 | 2023-11-30 21:45:52 | 86af02ae-3d60-4afb-b82f-9d3505f5f21f | 153.77 |
# | b4f415d0-7db2-11ee-b0f3-69bd975277c1 | 120 | 2023-11-29 19:04:53 | 8aa224a3-9d92-4e29-9188-ab2a857a618c | 159.05 |
# | b4f415d0-7db2-11ee-b0f3-69bd975277c1 | 120 | 2023-11-29 19:04:42 | 2bfb439c-edbe-4551-9eea-a467b10b75fa | 154.75 |
# | b4f415d0-7db2-11ee-b0f3-69bd975277c1 | 120 | 2023-11-29 19:04:31 | 1c4a8079-224d-4915-aa9e-2f4184ef7d61 | 159.47 |
# | b4f415d0-7db2-11ee-b0f3-69bd975277c1 | 120 | 2023-11-29 19:04:20 | b2184e3d-c45d-4490-a47d-4fe1f41d738b | 154.18 |
# | b4f415d0-7db2-11ee-b0f3-69bd975277c1 | 120 | 2023-11-29 19:04:09 | 2ed97a9c-3217-42b6-ad9c-dc1b0ca3fc8c | 153.24 |
# | b4f415d0-7db2-11ee-b0f3-69bd975277c1 | 120 | 2023-11-29 19:03:57 | 47ef5164-f365-4f4e-a522-91b00e13d90b | 152.89 |
# | b4f415d0-7db2-11ee-b0f3-69bd975277c1 | 120 | 2023-11-29 19:03:45 | a79e1be8-27f6-4391-8074-5e75e4eea7a8 | 156.53 |
# | b4f415d0-7db2-11ee-b0f3-69bd975277c1 | 120 | 2023-11-29 19:03:34 | fa7d2a2e-8e69-475f-b929-9612337822fa | 152.99 |
# | b4f415d0-7db2-11ee-b0f3-69bd975277c1 | 120 | 2023-11-29 19:03:23 | fa38ce1f-1566-4103-93b9-5bd706874bfa | 157.5  |
# | b4f415d0-7db2-11ee-b0f3-69bd975277c1 | 120 | 2023-11-29 19:03:11 | b3b3a027-2dec-4244-bbb2-bf32304a22ee | 158.1  |
# | b4f415d0-7db2-11ee-b0f3-69bd975277c1 | 120 | 2023-11-29 19:02:59 | bfe6d02b-ac6f-4fbf-9685-047706ddea35 | 158.21 |
# | b4f415d0-7db2-11ee-b0f3-69bd975277c1 | 120 | 2023-11-29 19:02:48 | a293dbe1-bf38-4d2a-9648-2ef419bc75a5 | 151.75 |
# | b4f415d0-7db2-11ee-b0f3-69bd975277c1 | 120 | 2023-11-29 19:02:36 | 6ee466cd-ee5b-4f47-afbd-d0c7aea0ce42 | 154.19 |
# | b4f415d0-7db2-11ee-b0f3-69bd975277c1 | 120 | 2023-11-29 19:02:24 | 2da738dd-3932-4c05-ab5a-460e0efaa0b0 | 151.08 |
# | b4f415d0-7db2-11ee-b0f3-69bd975277c1 | 120 | 2023-11-29 19:02:12 | 2f424362-2e8f-4d15-9443-53a93014b376 | 151.72 |
# | b4f415d0-7db2-11ee-b0f3-69bd975277c1 | 120 | 2023-11-29 19:02:01 | 9e6ade72-5540-4595-a9bc-e8de5051aad5 | 155.85 |
# | b4f415d0-7db2-11ee-b0f3-69bd975277c1 | 120 | 2023-11-29 19:01:49 | 61e4f873-ec0c-4f02-a582-cc335482f10f | 150.87 |
# | b4f415d0-7db2-11ee-b0f3-69bd975277c1 | 120 | 2023-11-29 19:01:38 | 7ac27dcf-a550-4e58-8914-044aa8a3a262 | 154.06 |
# | b4f415d0-7db2-11ee-b0f3-69bd975277c1 | 120 | 2023-11-29 19:01:26 | eedc1e31-6a55-4052-9269-23116fb10345 | 150.48 |
# | b4f415d0-7db2-11ee-b0f3-69bd975277c1 | 120 | 2023-11-29 19:01:14 | a20ce74c-b35d-4b15-8e1c-311a3887ab8e | 156.62 |
# | b4f415d0-7db2-11ee-b0f3-69bd975277c1 | 120 | 2023-11-29 19:01:03 | 168d93bf-eedf-42b6-807f-be7ac82b75bb | 155.02 |
# | b4f415d0-7db2-11ee-b0f3-69bd975277c1 | 120 | 2023-11-29 19:00:51 | d12596fe-e836-458a-a003-df07471c3876 | 159.25 |
# | b4f415d0-7db2-11ee-b0f3-69bd975277c1 | 120 | 2023-11-29 19:00:39 | d791464e-a6f4-4809-8b8a-47759987cabf | 150.83 |
# | b4f415d0-7db2-11ee-b0f3-69bd975277c1 | 120 | 2023-11-29 19:00:28 | 411763fa-4b81-43e6-8656-d28db273fd9a | 157.14 |
# | b4f415d0-7db2-11ee-b0f3-69bd975277c1 | 120 | 2023-11-29 19:00:17 | 629ad1ae-fcce-442e-a482-68f0481206f4 | 158.35 |
# | b4f415d0-7db2-11ee-b0f3-69bd975277c1 | 120 | 2023-11-29 19:00:05 | e5522baa-24f1-4b92-80e6-6f27a1c7b27e | 157.29 |
# | b4f415d0-7db2-11ee-b0f3-69bd975277c1 | 120 | 2023-11-29 18:59:54 | 0ffc199e-a561-4881-a2c6-e35b4dd08aef | 152.25 |
# | b4f415d0-7db2-11ee-b0f3-69bd975277c1 | 120 | 2023-11-29 18:59:43 | ece2607a-d702-42b6-8c07-e4ea466cb9ee | 154.67 |
# | b4f415d0-7db2-11ee-b0f3-69bd975277c1 | 120 | 2023-11-29 18:59:32 | 07d00f90-4ac6-4e25-8a9c-2e1745a12ca3 | 153.13 |
# | b4f415d0-7db2-11ee-b0f3-69bd975277c1 | 120 | 2023-11-29 18:59:21 | a0f793ea-c5d3-4098-9758-5026fc83d622 | 151.22 |
# | b4f415d0-7db2-11ee-b0f3-69bd975277c1 | 120 | 2023-11-29 18:59:10 | 2442071c-2aed-4743-995a-8bf8c3f54124 | 153.79 |
# | b4f415d0-7db2-11ee-b0f3-69bd975277c1 | 120 | 2023-11-29 18:58:59 | e9bf7c2d-58a1-45bf-8c93-bea9882a49f2 | 158.77 |
# +--------------------------------------+-----+---------------------+--------------------------------------+--------+
# C:\Users\c21054458\AppData\Local\Temp\ipykernel_23312\1345659968.py:53: DeprecationWarning: datetime.datetime.utcfromtimestamp() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.fromtimestamp(timestamp, datetime.UTC).
#   formatted_ts = datetime.utcfromtimestamp(row["ts"] / 1000.0).strftime(

# %%
import psycopg2
from psycopg2.extras import DictCursor
from prettytable import PrettyTable

connection = psycopg2.connect(
    database="thingsboard",
    user="thingsboard",
    password="postgres",
    host="localhost",
    port=5432,
)

print("Successfully connected to the database.")

cursor = connection.cursor(cursor_factory=DictCursor)

query = """
SELECT key, key_id FROM ts_kv_dictionary;

"""
cursor.execute(query)
rows = cursor.fetchall()

# Create a PrettyTable object
table = PrettyTable()
table.field_names = rows[0].keys() if rows else []

# Add rows to the table
for row in rows:
    table.add_row(list(row.values()))

# Print the table
print(table)

# Close the cursor and the database connection
cursor.close()
connection.close()
# Out:
# Successfully connected to the database.
# +--------------------------------+--------+
# |              key               | key_id |
# +--------------------------------+--------+
# |       transportApiState        |   1    |
# |           dbApiState           |   2    |
# |       ruleEngineApiState       |   3    |
# |      jsExecutionApiState       |   4    |
# |         emailApiState          |   5    |
# |          smsApiState           |   6    |
# |         alarmApiState          |   7    |
# |       transportMsgLimit        |   8    |
# |    transportDataPointsLimit    |   9    |
# |     storageDataPointsLimit     |   10   |
# |    ruleEngineExecutionLimit    |   11   |
# |        jsExecutionLimit        |   12   |
# |           emailLimit           |   13   |
# |            smsLimit            |   14   |
# |       createdAlarmsLimit       |   15   |
# |          clusterMode           |   16   |
# |            cpuUsage            |   17   |
# |          memoryUsage           |   18   |
# |           discUsage            |   19   |
# |            cpuCount            |   20   |
# |          totalMemory           |   21   |
# |         totalDiscSpace         |   22   |
# |       activeDevicesCount       |   23   |
# |    activeDevicesCountHourly    |   24   |
# |      inactiveDevicesCount      |   25   |
# |   inactiveDevicesCountHourly   |   26   |
# |    ruleEngineExecutionCount    |   27   |
# | ruleEngineExecutionCountHourly |   28   |
# |          temperature           |   29   |
# |            humidity            |   30   |
# |           totalMsgs            |   31   |
# |         successfulMsgs         |   32   |
# |           failedMsgs           |   33   |
# |           tmpFailed            |   34   |
# |           tmpTimeout           |   35   |
# |          timeoutMsgs           |   36   |
# |    transportMsgCountHourly     |   37   |
# |       transportMsgCount        |   38   |
# |        jsExecutionCount        |   39   |
# |           emailCount           |   40   |
# |            smsCount            |   41   |
# |       createdAlarmsCount       |   42   |
# |    transportDataPointsCount    |   43   |
# | transportDataPointsCountHourly |   44   |
# |     storageDataPointsCount     |   45   |
# |  storageDataPointsCountHourly  |   46   |
# |               A                |   47   |
# |               B                |   48   |
# |               C                |   49   |
# |               D                |   50   |
# |               E                |   51   |
# |               F                |   52   |
# |               G                |   53   |
# |               L                |   54   |
# |               M                |   55   |
# |               N                |   56   |
# |               O                |   57   |
# |               P                |   58   |
# |               Q                |   59   |
# |               R                |   60   |
# |               S                |   61   |
# |               T                |   62   |
# |               U                |   63   |
# |               V                |   64   |
# |               W                |   65   |
# |               X                |   66   |
# |               Y                |   67   |
# |               Z                |   68   |
# |               A1               |   69   |
# |               B1               |   70   |
# |               C1               |   71   |
# |               D1               |   72   |
# |            UV_light            |   73   |
# |            Loudness            |   74   |
# |        PM1.0Atmospheric        |   75   |
# |        PM2.5Atmospheric        |   76   |
# |        PM10Atmospheric         |   77   |
# |       tVOC_Concentration       |   78   |
# |      CO2eq_Concentration       |   79   |
# |       MQ2_sensor_voltage       |   80   |
# |          MQ2_Rs_ratio          |   81   |
# |        MQ2_Rs/R0_Ratio         |   82   |
# |       MQ3_sensor_voltage       |   83   |
# |          MQ3_Rs_ratio          |   84   |
# |        MQ3_Rs/R0_Ratio         |   85   |
# |            HCHO_ppm            |   86   |
# |          Air_Quality           |   87   |
# |          Light_value           |   88   |
# |         Visible_light          |   89   |
# |            IR_light            |   90   |
# |       MQ5_sensor_voltage       |   91   |
# |          MQ5_Rs_ratio          |   92   |
# |        MQ5_Rs/R0_Ratio         |   93   |
# |       MQ9_sensor_voltage       |   94   |
# |          MQ9_Rs_ratio          |   95   |
# |        MQ9_Rs/R0_Ratio         |   96   |
# |        O2_22.10_N2_gas         |   97   |
# |           C2H5CH_gas           |   98   |
# |            VOC_gas             |   99   |
# |             CO_gas             |  100   |
# |              Co2               |  101   |
# |          Temperature           |  102   |
# |            Humidity            |  103   |
# |           Luminance            |  104   |
# |           PIR_Status           |  105   |
# |               F1               |  106   |
# |               G1               |  107   |
# |               H1               |  108   |
# |               I1               |  109   |
# |              aqi               |  110   |
# |               J1               |  111   |
# |               K1               |  112   |
# |               L1               |  113   |
# |               H                |  114   |
# |               K                |  115   |
# |               I                |  116   |
# |               J                |  117   |
# |               E1               |  118   |
# |           memsvalue            |  119   |
# |           rsroratio2           |  120   |
# |           rsroratio3           |  121   |
# |          hchoppmvalue          |  122   |
# |            HCHO_RS             |  123   |
# |        Air_Quality_lev         |  124   |
# |        airQualityValue         |  125   |
# |           rsroratio5           |  126   |
# |           rsroratio9           |  127   |
# |              NO2               |  128   |
# |             c2h5ch             |  129   |
# |              VOC               |  130   |
# |             co_gas             |  131   |
# |            co2value            |  132   |
# |           tempreture           |  133   |
# |              lux               |  134   |
# |             o2per              |  135   |
# |          hchoRsValue           |  136   |
# |        airQualitylevel         |  137   |
# |          PM1Standard           |  138   |
# |          PM25Standard          |  139   |
# |          PM10Standard          |  140   |
# |         PM1Atmospheric         |  141   |
# |        PM25Atmospheric         |  142   |
# |            pirvalue            |  143   |
# |            voltage2            |  144   |
# |           mq2rsratio           |  145   |
# |            voltage3            |  146   |
# |           mq3rsratio           |  147   |
# |            voltage5            |  148   |
# |           mq5rsratio           |  149   |
# |            voltage9            |  150   |
# |           mq9rsratio           |  151   |
# +--------------------------------+--------+

# %%
device_name_variable = "node_5.08"
user_input_key = "NO2"


import psycopg2
from psycopg2.extras import DictCursor
from prettytable import PrettyTable
from datetime import datetime

connection1 = psycopg2.connect(
    database="thingsboard",
    user="thingsboard",
    password="postgres",
    host="localhost",
    port=5432,
)
cursor1 = connection1.cursor(cursor_factory=DictCursor)
query1 = f"""
SELECT key_id FROM ts_kv_dictionary
WHERE key = '{user_input_key}';
"""
cursor1.execute(query1)
rows1 = cursor1.fetchall()
key_id_result = rows1[0]["key_id"] if rows1 else None
print("Key ID:", key_id_result)

# Mapping dictionary for device_name to entity_id
device_name_to_entity_id = {
    "node_5.01": "478abf30-7db2-11ee-b0f3-69bd975277c1",
    "node_5.02": "5306a860-7db2-11ee-b0f3-69bd975277c1",
    "node_5.03": "6b52c020-7db2-11ee-b0f3-69bd975277c1",
    "node_5.04": "725a3830-7db2-11ee-b0f3-69bd975277c1",
    "node_5.05": "78df12c0-7db2-11ee-b0f3-69bd975277c1",
    "node_5.06": "8084c6a0-7db2-11ee-b0f3-69bd975277c1",
    "node_5.07": "8c34df30-7db2-11ee-b0f3-69bd975277c1",
    "node_5.08": "93834b50-7db2-11ee-b0f3-69bd975277c1",
    "node_5.09": "997b9d50-7db2-11ee-b0f3-69bd975277c1",
    "node_5.10": "9f44f010-7db2-11ee-b0f3-69bd975277c1",
    "node_5.11": "a6250a00-7db2-11ee-b0f3-69bd975277c1",
    "node_5.12": "add0b150-7db2-11ee-b0f3-69bd975277c1",
    "node_5.13": "b4f415d0-7db2-11ee-b0f3-69bd975277c1",
    "node_5.14": "bad9ca30-7db2-11ee-b0f3-69bd975277c1",
    "node_5.15": "c0fe3540-7db2-11ee-b0f3-69bd975277c1",
    "node_5.16": "729855d0-7db6-11ee-b0f3-69bd975277c1",
    "node_5.17": "328afde0-83f5-11ee-a992-8978af4232d8",
    "node_5.18": "37c9eaf0-83f5-11ee-a992-8978af4232d8",
    "node_5.19": "3d369ec0-83f5-11ee-a992-8978af4232d8",
    "node_5.20": "4e709010-83f5-11ee-a992-8978af4232d8",
    "node_5.21": "53491a30-83f5-11ee-a992-8978af4232d8",
    "node_5.22": "58b83f00-83f5-11ee-a992-8978af4232d8",
    "node_5.23": "5d800040-83f5-11ee-a992-8978af4232d8",
    "node_5.24": "620958f0-83f5-11ee-a992-8978af4232d8",
    "node_5.25": "6694ad70-83f5-11ee-a992-8978af4232d8",
    "node_5.26": "6b6a7870-83f5-11ee-a992-8978af4232d8",
    "node_5.27": "7091e5e0-83f5-11ee-a992-8978af4232d8",
    "node_5.28": "759e7850-83f5-11ee-a992-8978af4232d8",
    "node_5.29": "7b537fc0-83f5-11ee-a992-8978af4232d8",
    "node_5.30": "7ffd58c0-83f5-11ee-a992-8978af4232d8",
    "node_5.31": "84bd51d0-83f5-11ee-a992-8978af4232d8",
    "node_5.32": "8afd3420-83f5-11ee-a992-8978af4232d8",
    "node_5.33": "90088e10-83f5-11ee-a992-8978af4232d8",
    "node_5.34": "9586a700-83f5-11ee-a992-8978af4232d8"
    # Add more mappings as needed
}


entity_id_variable = device_name_to_entity_id.get(device_name_variable, "")

if not entity_id_variable:
    print(f"Device with name '{device_name_variable}' not found in the mapping.")
    exit()

connection = psycopg2.connect(
    database="thingsboard",
    user="thingsboard",
    password="postgres",
    host="localhost",
    port=5432,
)

cursor2 = connection.cursor(cursor_factory=DictCursor)

query = f"""
SELECT entity_id, ts, uuid, long_v
FROM ts_kv
WHERE entity_id = '{entity_id_variable}'
  AND key = {key_id_result}
ORDER BY ts DESC
LIMIT 50;
"""

cursor2.execute(query)
rows = cursor2.fetchall()

# Create a PrettyTable object
table = PrettyTable()
table.field_names = ["entity_id", "ts (formatted)", "uuid", "long_v"]

# Add rows to the table
for row in rows:
    # Convert the timestamp to a formatted date and time
    formatted_ts = datetime.utcfromtimestamp(row["ts"] / 1000.0).strftime(
        "%Y-%m-%d %H:%M:%S"
    )
    # Add the row with the formatted timestamp
    table.add_row([row["entity_id"], formatted_ts, row["uuid"], row["long_v"]])

# Print the table
print(table)

# Close the cursor and the database connection
cursor.close()
connection.close()
# Out:
# Key ID: 128
# +--------------------------------------+---------------------+--------------------------------------+--------+
# |              entity_id               |    ts (formatted)   |                 uuid                 | long_v |
# +--------------------------------------+---------------------+--------------------------------------+--------+
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-30 21:52:24 | ae940901-a9fe-4021-87d9-a021cdbabe4a |  192   |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-30 21:52:01 | d514b7eb-ea55-4ba0-8916-3609dc6824b0 |  195   |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-30 21:51:39 | ec532ebc-7e56-453c-b0cc-82741c271972 |  192   |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-30 21:51:22 | 93c04f5e-f1cb-447b-a698-63160ba6f290 |  195   |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-30 21:50:57 | d38dfc3c-7a5b-42ac-bbe2-c715cc21a679 |  194   |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-30 21:50:39 | ea012626-1fe0-4034-92cd-dc06a20e9e4e |  193   |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-30 21:50:08 | 09f25ddd-ba42-4b55-a64a-1c25c94c737b |  192   |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-30 21:49:45 | f9295f35-4e45-4346-ab08-504d2ccbd0e7 |  195   |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-30 21:49:18 | b3ff92c5-f0d4-455f-b743-7b89dbe68d83 |  193   |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-30 21:48:59 | 6c3f1eac-3de4-4c78-ae9a-49bad13c042f |  192   |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-30 21:48:35 | bd3ce96a-92d5-4b34-8686-4eb0f34c1eb8 |  194   |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-30 21:48:08 | 931ff350-7aca-4ae3-befc-c56cfde34058 |  193   |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-30 21:47:41 | 69955c4e-3708-4002-9ecb-4db4886eec4e |  196   |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-30 21:47:23 | df01867c-49b2-4645-ba44-f5c07cb7c9b6 |  195   |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-30 21:47:04 | a5677acc-68ef-46fe-ab16-ee6b983fe51a |  193   |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-30 21:46:46 | 03eb7eb3-6056-4ae6-b8c2-1422ce8ed1f7 |  193   |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-30 21:46:22 | fc24d2e2-8d46-4273-9bb1-15a699079c20 |  194   |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-30 21:45:50 | c04cea81-4365-4499-99c2-926f21500425 |  195   |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 19:04:53 | b0066c1e-cca6-4694-870b-d91679377467 |  196   |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 19:04:42 | 8b7ae23c-4399-4a41-9505-79392b1c6187 |  194   |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 19:04:31 | 5e211a51-0f2a-41c8-b024-da7d914e4645 |  194   |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 19:04:20 | df7f5839-086e-48f1-99ac-236780ad9ca6 |  195   |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 19:04:08 | 84fd5b80-892b-4ee4-869a-0e58a0307c2d |  192   |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 19:03:57 | 1b17bd21-7320-4eed-aaa7-69921091df93 |  193   |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 19:03:45 | 4fa322fa-4c48-4238-b1f3-afe207cd6aed |  196   |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 19:03:34 | bdc15ede-3801-409a-8380-bda125727895 |  196   |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 19:03:22 | 4f09d22d-6c21-4398-bcf5-cab61a4c6949 |  196   |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 19:03:11 | 4746dac3-644a-4a5d-a1a8-80ec683e6806 |  196   |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 19:02:59 | 17461d9f-2b70-4475-9d06-6b499a4e5cd0 |  196   |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 19:02:47 | 8937813b-602b-4559-8176-3a6177ef20f6 |  195   |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 19:02:36 | 557004ca-9329-4666-a620-116b82008732 |  195   |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 19:02:24 | 6fa3dbf3-5eba-48ed-900d-6e1f58097f0f |  193   |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 19:02:12 | e9c0c0e6-57fa-470c-8326-3b12886d4c78 |  193   |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 19:02:00 | 3ce54211-b32d-42fb-9990-1582f347fa48 |  193   |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 19:01:49 | 8050d3e3-820e-48e6-abc3-660b7fcb14e0 |  192   |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 19:01:37 | 5541d87c-661d-46c6-a074-05bd7cb600f4 |  195   |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 19:01:26 | 336cea41-d8a0-4b88-825e-da6c0165ce7a |  192   |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 19:01:14 | f8ba4073-eecd-481d-a2cb-151ef1a82f9a |  196   |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 19:01:02 | a292aceb-4f83-4bd8-98f5-557f21975d1a |  193   |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 19:00:51 | d8381af8-2380-41e8-af3d-295e0d3f4eaa |  194   |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 19:00:39 | 50b2665d-bd47-4ba6-ab9e-0c74366b430a |  194   |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 19:00:28 | 9cb47364-6c03-4df5-b726-91b817b8ec39 |  194   |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 19:00:17 | 901ea794-6ea8-4044-ad1b-837dd9c8d4f2 |  194   |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 19:00:05 | 8cc3989e-dbec-4feb-98ca-f03fa708f2ac |  196   |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 18:59:54 | 5c2cfe14-5a6d-4b88-8da6-3f7c3a45b0de |  193   |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 18:59:43 | ac20ce3d-b77b-4de4-9aca-c8fba11776d1 |  195   |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 18:59:32 | 0526cfc9-a2f1-4062-b582-02378fdad1a7 |  195   |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 18:59:21 | 99d78dd1-f81f-44aa-8d60-0d5be2612fb6 |  194   |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 18:59:10 | ce771328-c672-4de6-9dcc-79d1cb65ab09 |  193   |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 18:58:58 | 5a9609db-7313-4570-8004-c73826afedbd |  192   |
# +--------------------------------------+---------------------+--------------------------------------+--------+
# C:\Users\c21054458\AppData\Local\Temp\ipykernel_23312\421648289.py:102: DeprecationWarning: datetime.datetime.utcfromtimestamp() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.fromtimestamp(timestamp, datetime.UTC).
#   formatted_ts = datetime.utcfromtimestamp(row["ts"] / 1000.0).strftime(

# %% [markdown]
# Export your data

# %%
device_name_variable = "node_5.08"
user_input_key = "NO2"


import psycopg2
from psycopg2.extras import DictCursor
from prettytable import PrettyTable
from datetime import datetime
import os
import csv

connection1 = psycopg2.connect(
    database="thingsboard",
    user="thingsboard",
    password="postgres",
    host="localhost",
    port=5432,
)
cursor1 = connection1.cursor(cursor_factory=DictCursor)
query1 = f"""
SELECT key_id FROM ts_kv_dictionary
WHERE key = '{user_input_key}';
"""
cursor1.execute(query1)
rows1 = cursor1.fetchall()
key_id_result = rows1[0]["key_id"] if rows1 else None
print("Key ID:", key_id_result)

# Mapping dictionary for device_name to entity_id
device_name_to_entity_id = {
    "node_5.01": "478abf30-7db2-11ee-b0f3-69bd975277c1",
    "node_5.02": "5306a860-7db2-11ee-b0f3-69bd975277c1",
    "node_5.03": "6b52c020-7db2-11ee-b0f3-69bd975277c1",
    "node_5.04": "725a3830-7db2-11ee-b0f3-69bd975277c1",
    "node_5.05": "78df12c0-7db2-11ee-b0f3-69bd975277c1",
    "node_5.06": "8084c6a0-7db2-11ee-b0f3-69bd975277c1",
    "node_5.07": "8c34df30-7db2-11ee-b0f3-69bd975277c1",
    "node_5.08": "93834b50-7db2-11ee-b0f3-69bd975277c1",
    "node_5.09": "997b9d50-7db2-11ee-b0f3-69bd975277c1",
    "node_5.10": "9f44f010-7db2-11ee-b0f3-69bd975277c1",
    "node_5.11": "a6250a00-7db2-11ee-b0f3-69bd975277c1",
    "node_5.12": "add0b150-7db2-11ee-b0f3-69bd975277c1",
    "node_5.13": "b4f415d0-7db2-11ee-b0f3-69bd975277c1",
    "node_5.14": "bad9ca30-7db2-11ee-b0f3-69bd975277c1",
    "node_5.15": "c0fe3540-7db2-11ee-b0f3-69bd975277c1",
    "node_5.16": "729855d0-7db6-11ee-b0f3-69bd975277c1",
    "node_5.17": "328afde0-83f5-11ee-a992-8978af4232d8",
    "node_5.18": "37c9eaf0-83f5-11ee-a992-8978af4232d8",
    "node_5.19": "3d369ec0-83f5-11ee-a992-8978af4232d8",
    "node_5.20": "4e709010-83f5-11ee-a992-8978af4232d8",
    "node_5.21": "53491a30-83f5-11ee-a992-8978af4232d8",
    "node_5.22": "58b83f00-83f5-11ee-a992-8978af4232d8",
    "node_5.23": "5d800040-83f5-11ee-a992-8978af4232d8",
    "node_5.24": "620958f0-83f5-11ee-a992-8978af4232d8",
    "node_5.25": "6694ad70-83f5-11ee-a992-8978af4232d8",
    "node_5.26": "6b6a7870-83f5-11ee-a992-8978af4232d8",
    "node_5.27": "7091e5e0-83f5-11ee-a992-8978af4232d8",
    "node_5.28": "759e7850-83f5-11ee-a992-8978af4232d8",
    "node_5.29": "7b537fc0-83f5-11ee-a992-8978af4232d8",
    "node_5.30": "7ffd58c0-83f5-11ee-a992-8978af4232d8",
    "node_5.31": "84bd51d0-83f5-11ee-a992-8978af4232d8",
    "node_5.32": "8afd3420-83f5-11ee-a992-8978af4232d8",
    "node_5.33": "90088e10-83f5-11ee-a992-8978af4232d8",
    "node_5.34": "9586a700-83f5-11ee-a992-8978af4232d8"
    # Add more mappings as needed
}


entity_id_variable = device_name_to_entity_id.get(device_name_variable, "")

if not entity_id_variable:
    print(f"Device with name '{device_name_variable}' not found in the mapping.")
    exit()

connection = psycopg2.connect(
    database="thingsboard",
    user="thingsboard",
    password="postgres",
    host="localhost",
    port=5432,
)

cursor2 = connection.cursor(cursor_factory=DictCursor)

query = f"""
SELECT entity_id, ts, uuid, long_v
FROM ts_kv
WHERE entity_id = '{entity_id_variable}'
  AND key = {key_id_result}
ORDER BY ts DESC
LIMIT 15;
"""

cursor2.execute(query)
rows = cursor2.fetchall()

# Create a PrettyTable object
table = PrettyTable()
table.field_names = ["entity_id", "ts (formatted)", "uuid", "long_v"]

# Add rows to the table
for row in rows:
    # Convert the timestamp to a formatted date and time
    formatted_ts = datetime.utcfromtimestamp(row["ts"] / 1000.0).strftime(
        "%Y-%m-%d %H:%M:%S"
    )
    # Add the row with the formatted timestamp
    table.add_row([row["entity_id"], formatted_ts, row["uuid"], row["long_v"]])

# Print the table
print(table)

# Write the results to a CSV file
output_csv_path = "output.csv"
with open(output_csv_path, "w", newline="") as csv_file:
    csv_writer = csv.writer(csv_file)
    csv_writer.writerow(table.field_names)  # Write header
    csv_writer.writerows(table.get_string().splitlines()[2:])  # Write data rows

print(f"Results exported successfully to {output_csv_path}")
# Close the cursor and the database connection
cursor.close()
connection.close()
# Out:
# Key ID: 128
# +--------------------------------------+---------------------+--------------------------------------+--------+
# |              entity_id               |    ts (formatted)   |                 uuid                 | long_v |
# +--------------------------------------+---------------------+--------------------------------------+--------+
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-30 21:52:24 | ae940901-a9fe-4021-87d9-a021cdbabe4a |  192   |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-30 21:52:01 | d514b7eb-ea55-4ba0-8916-3609dc6824b0 |  195   |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-30 21:51:39 | ec532ebc-7e56-453c-b0cc-82741c271972 |  192   |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-30 21:51:22 | 93c04f5e-f1cb-447b-a698-63160ba6f290 |  195   |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-30 21:50:57 | d38dfc3c-7a5b-42ac-bbe2-c715cc21a679 |  194   |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-30 21:50:39 | ea012626-1fe0-4034-92cd-dc06a20e9e4e |  193   |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-30 21:50:08 | 09f25ddd-ba42-4b55-a64a-1c25c94c737b |  192   |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-30 21:49:45 | f9295f35-4e45-4346-ab08-504d2ccbd0e7 |  195   |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-30 21:49:18 | b3ff92c5-f0d4-455f-b743-7b89dbe68d83 |  193   |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-30 21:48:59 | 6c3f1eac-3de4-4c78-ae9a-49bad13c042f |  192   |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-30 21:48:35 | bd3ce96a-92d5-4b34-8686-4eb0f34c1eb8 |  194   |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-30 21:48:08 | 931ff350-7aca-4ae3-befc-c56cfde34058 |  193   |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-30 21:47:41 | 69955c4e-3708-4002-9ecb-4db4886eec4e |  196   |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-30 21:47:23 | df01867c-49b2-4645-ba44-f5c07cb7c9b6 |  195   |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-30 21:47:04 | a5677acc-68ef-46fe-ab16-ee6b983fe51a |  193   |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-30 21:46:46 | 03eb7eb3-6056-4ae6-b8c2-1422ce8ed1f7 |  193   |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-30 21:46:22 | fc24d2e2-8d46-4273-9bb1-15a699079c20 |  194   |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-30 21:45:50 | c04cea81-4365-4499-99c2-926f21500425 |  195   |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 19:04:53 | b0066c1e-cca6-4694-870b-d91679377467 |  196   |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 19:04:42 | 8b7ae23c-4399-4a41-9505-79392b1c6187 |  194   |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 19:04:31 | 5e211a51-0f2a-41c8-b024-da7d914e4645 |  194   |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 19:04:20 | df7f5839-086e-48f1-99ac-236780ad9ca6 |  195   |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 19:04:08 | 84fd5b80-892b-4ee4-869a-0e58a0307c2d |  192   |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 19:03:57 | 1b17bd21-7320-4eed-aaa7-69921091df93 |  193   |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 19:03:45 | 4fa322fa-4c48-4238-b1f3-afe207cd6aed |  196   |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 19:03:34 | bdc15ede-3801-409a-8380-bda125727895 |  196   |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 19:03:22 | 4f09d22d-6c21-4398-bcf5-cab61a4c6949 |  196   |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 19:03:11 | 4746dac3-644a-4a5d-a1a8-80ec683e6806 |  196   |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 19:02:59 | 17461d9f-2b70-4475-9d06-6b499a4e5cd0 |  196   |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 19:02:47 | 8937813b-602b-4559-8176-3a6177ef20f6 |  195   |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 19:02:36 | 557004ca-9329-4666-a620-116b82008732 |  195   |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 19:02:24 | 6fa3dbf3-5eba-48ed-900d-6e1f58097f0f |  193   |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 19:02:12 | e9c0c0e6-57fa-470c-8326-3b12886d4c78 |  193   |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 19:02:00 | 3ce54211-b32d-42fb-9990-1582f347fa48 |  193   |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 19:01:49 | 8050d3e3-820e-48e6-abc3-660b7fcb14e0 |  192   |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 19:01:37 | 5541d87c-661d-46c6-a074-05bd7cb600f4 |  195   |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 19:01:26 | 336cea41-d8a0-4b88-825e-da6c0165ce7a |  192   |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 19:01:14 | f8ba4073-eecd-481d-a2cb-151ef1a82f9a |  196   |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 19:01:02 | a292aceb-4f83-4bd8-98f5-557f21975d1a |  193   |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 19:00:51 | d8381af8-2380-41e8-af3d-295e0d3f4eaa |  194   |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 19:00:39 | 50b2665d-bd47-4ba6-ab9e-0c74366b430a |  194   |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 19:00:28 | 9cb47364-6c03-4df5-b726-91b817b8ec39 |  194   |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 19:00:17 | 901ea794-6ea8-4044-ad1b-837dd9c8d4f2 |  194   |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 19:00:05 | 8cc3989e-dbec-4feb-98ca-f03fa708f2ac |  196   |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 18:59:54 | 5c2cfe14-5a6d-4b88-8da6-3f7c3a45b0de |  193   |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 18:59:43 | ac20ce3d-b77b-4de4-9aca-c8fba11776d1 |  195   |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 18:59:32 | 0526cfc9-a2f1-4062-b582-02378fdad1a7 |  195   |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 18:59:21 | 99d78dd1-f81f-44aa-8d60-0d5be2612fb6 |  194   |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 18:59:10 | ce771328-c672-4de6-9dcc-79d1cb65ab09 |  193   |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 18:58:58 | 5a9609db-7313-4570-8004-c73826afedbd |  192   |
# +--------------------------------------+---------------------+--------------------------------------+--------+
# Results exported successfully to output.csv
# C:\Users\c21054458\AppData\Local\Temp\ipykernel_23312\946222530.py:104: DeprecationWarning: datetime.datetime.utcfromtimestamp() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.fromtimestamp(timestamp, datetime.UTC).
#   formatted_ts = datetime.utcfromtimestamp(row["ts"] / 1000.0).strftime(

# %% [markdown]
# # B

# %%
# schedular

# %% [markdown]
# ### this codes finds datatype

# %%
SELECT
    key,
    COUNT(bool_v) AS bool_count,
    COUNT(str_v) AS str_count,
    COUNT(long_v) AS long_count,
    COUNT(dbl_v) AS dbl_count,
    COUNT(json_v) AS json_count
FROM ts_kv
GROUP BY key;




SELECT 
  entity_id, 
  ts, 
  uuid, 
  CASE 
        WHEN bool_v IS NOT NULL THEN 'bool_v' 
        WHEN str_v IS NOT NULL THEN 'str_v'
        WHEN long_v IS NOT NULL THEN 'long_v'
        WHEN dbl_v IS NOT NULL THEN 'dbl_v'
        WHEN json_v IS NOT NULL THEN 'json_v'
FROM 
  ts_kv
WHERE
  entity_id = '93834b50-7db2-11ee-b0f3-69bd975277c1'
  AND key = 128
ORDER BY 
  ts DESC
LIMIT 50;








SELECT 
  entity_id, 
  ts, 
  uuid, 
  CASE 
    WHEN bool_v IS NOT NULL THEN 'bool_v' 
    WHEN str_v IS NOT NULL THEN 'str_v'
    WHEN long_v IS NOT NULL THEN 'long_v'
    WHEN dbl_v IS NOT NULL THEN 'dbl_v'
    WHEN json_v IS NOT NULL THEN 'json_v'
    ELSE 'Unknown' -- You can customize this based on your needs
  END AS data_type_column
FROM 
  ts_kv
WHERE
  entity_id = '93834b50-7db2-11ee-b0f3-69bd975277c1'
  AND key = 128
ORDER BY 
  ts DESC
LIMIT 50;







WORKING SQL query

SELECT 
  entity_id, 
  ts, 
  uuid, 
  COALESCE(bool_v::TEXT, str_v, long_v::TEXT, dbl_v::TEXT, json_v::TEXT) AS actual_value
FROM 
  ts_kv
WHERE
  entity_id = '93834b50-7db2-11ee-b0f3-69bd975277c1'
  AND key = 128
ORDER BY 
  ts DESC
LIMIT 50;

to see column types

SELECT column_name, data_type
FROM information_schema.columns
WHERE table_name = 'ts_kv';



to add new timestamp column

-- Add a new column with a default expression
ALTER TABLE ts_kv
ADD COLUMN new_timestamp_column TIMESTAMP DEFAULT TO_TIMESTAMP(ts);
# Out:
#   Cell In[28], line 2
#     key,
#     ^
# IndentationError: unexpected indent

# %% [markdown]
# ### working code

# %%
device_name_variable = "node_5.08"
user_input_key = "NO2"


import psycopg2
from psycopg2.extras import DictCursor
from prettytable import PrettyTable
from datetime import datetime

connection1 = psycopg2.connect(
    database="thingsboard",
    user="thingsboard",
    password="postgres",
    host="localhost",
    port=5432,
)
cursor1 = connection1.cursor(cursor_factory=DictCursor)
query1 = f"""
SELECT key_id FROM ts_kv_dictionary
WHERE key = '{user_input_key}';
"""
cursor1.execute(query1)
rows1 = cursor1.fetchall()
key_id_result = rows1[0]["key_id"] if rows1 else None
print("Key ID:", key_id_result)
cursor2.close()


# Mapping dictionary for device_name to entity_id
device_name_to_entity_id = {
    "node_5.01": "478abf30-7db2-11ee-b0f3-69bd975277c1",
    "node_5.02": "5306a860-7db2-11ee-b0f3-69bd975277c1",
    "node_5.03": "6b52c020-7db2-11ee-b0f3-69bd975277c1",
    "node_5.04": "725a3830-7db2-11ee-b0f3-69bd975277c1",
    "node_5.05": "78df12c0-7db2-11ee-b0f3-69bd975277c1",
    "node_5.06": "8084c6a0-7db2-11ee-b0f3-69bd975277c1",
    "node_5.07": "8c34df30-7db2-11ee-b0f3-69bd975277c1",
    "node_5.08": "93834b50-7db2-11ee-b0f3-69bd975277c1",
    "node_5.09": "997b9d50-7db2-11ee-b0f3-69bd975277c1",
    "node_5.10": "9f44f010-7db2-11ee-b0f3-69bd975277c1",
    "node_5.11": "a6250a00-7db2-11ee-b0f3-69bd975277c1",
    "node_5.12": "add0b150-7db2-11ee-b0f3-69bd975277c1",
    "node_5.13": "b4f415d0-7db2-11ee-b0f3-69bd975277c1",
    "node_5.14": "bad9ca30-7db2-11ee-b0f3-69bd975277c1",
    "node_5.15": "c0fe3540-7db2-11ee-b0f3-69bd975277c1",
    "node_5.16": "729855d0-7db6-11ee-b0f3-69bd975277c1",
    "node_5.17": "328afde0-83f5-11ee-a992-8978af4232d8",
    "node_5.18": "37c9eaf0-83f5-11ee-a992-8978af4232d8",
    "node_5.19": "3d369ec0-83f5-11ee-a992-8978af4232d8",
    "node_5.20": "4e709010-83f5-11ee-a992-8978af4232d8",
    "node_5.21": "53491a30-83f5-11ee-a992-8978af4232d8",
    "node_5.22": "58b83f00-83f5-11ee-a992-8978af4232d8",
    "node_5.23": "5d800040-83f5-11ee-a992-8978af4232d8",
    "node_5.24": "620958f0-83f5-11ee-a992-8978af4232d8",
    "node_5.25": "6694ad70-83f5-11ee-a992-8978af4232d8",
    "node_5.26": "6b6a7870-83f5-11ee-a992-8978af4232d8",
    "node_5.27": "7091e5e0-83f5-11ee-a992-8978af4232d8",
    "node_5.28": "759e7850-83f5-11ee-a992-8978af4232d8",
    "node_5.29": "7b537fc0-83f5-11ee-a992-8978af4232d8",
    "node_5.30": "7ffd58c0-83f5-11ee-a992-8978af4232d8",
    "node_5.31": "84bd51d0-83f5-11ee-a992-8978af4232d8",
    "node_5.32": "8afd3420-83f5-11ee-a992-8978af4232d8",
    "node_5.33": "90088e10-83f5-11ee-a992-8978af4232d8",
    "node_5.34": "9586a700-83f5-11ee-a992-8978af4232d8"
    # Add more mappings as needed
}


entity_id_variable = device_name_to_entity_id.get(device_name_variable, "")

if not entity_id_variable:
    print(f"Device with name '{device_name_variable}' not found in the mapping.")
    exit()

connection = psycopg2.connect(
    database="thingsboard",
    user="thingsboard",
    password="postgres",
    host="localhost",
    port=5432,
)

cursor2 = connection.cursor(cursor_factory=DictCursor)

query = f"""
SELECT 
  entity_id, 
  ts, 
  uuid, 
  COALESCE(bool_v::TEXT, str_v, long_v::TEXT, dbl_v::TEXT, json_v::TEXT) AS actual_value
FROM 
  ts_kv
WHERE
  entity_id = '{entity_id_variable}'
  AND key = {key_id_result}
ORDER BY 
  ts DESC
LIMIT 50
"""

cursor2.execute(query)
rows = cursor2.fetchall()

# Create a PrettyTable object
table = PrettyTable()
table.field_names = ["entity_id", "ts (formatted)", "uuid", "actual_value"]

# Add rows to the table
for row in rows:
    # Convert the timestamp to a formatted date and time
    formatted_ts = datetime.utcfromtimestamp(row["ts"] / 1000.0).strftime(
        "%Y-%m-%d %H:%M:%S"
    )
    # Add the row with the formatted timestamp
    table.add_row([row["entity_id"], formatted_ts, row["uuid"], row["actual_value"]])

# Print the table
print(table)

# Close the cursor and the database connection
cursor2.close()
connection.close()
# Out:
# Key ID: 128
# +--------------------------------------+---------------------+--------------------------------------+--------------+
# |              entity_id               |    ts (formatted)   |                 uuid                 | actual_value |
# +--------------------------------------+---------------------+--------------------------------------+--------------+
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 12:49:40 | 1721fe7e-61c2-42d8-acdf-6126fb6c31fe |     196      |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 12:49:18 | d8cd0e25-8623-4c5e-a7d6-038d904711b4 |     195      |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 12:48:56 | a4340e06-e3df-4474-90ce-d71ef5796ae3 |     193      |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 12:48:34 | 3f363ea8-7965-4072-b322-140df95e8b9c |     192      |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 12:48:13 | 0580f741-7343-4cce-9cce-6ea1892c0742 |     194      |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 12:47:51 | a05f4d4b-f6d3-4808-a488-e0b201bbd709 |     196      |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 12:47:29 | 1b22d341-4b13-4b98-baeb-01ff52ce1abe |     195      |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 12:47:08 | 59d5db6b-4c5b-4a8d-858d-a19efcec248b |     195      |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 12:46:46 | 23f6518c-797a-408c-864e-857f2e7281c4 |     195      |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 12:46:24 | 182dd999-3852-4cff-8668-897415f99828 |     194      |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 12:46:02 | b3426e2e-7154-4c36-b5c5-1267a2f898ac |     194      |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 12:45:40 | 8d8dd2e1-e0c4-4859-bd57-8f2f99aca5f7 |     193      |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 12:45:19 | 6693ce66-188b-4da9-a968-4e7ce389e797 |     195      |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 12:44:57 | 49f9776d-392b-4221-a748-a1a9ce58974a |     193      |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 12:44:36 | c9eedf06-835f-456e-9dfb-54538487b3a8 |     192      |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 12:44:14 | d69c5b03-5f61-4b72-a7c9-a0281e726e15 |     193      |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 12:43:51 | f4556592-b94e-478a-8264-e9ccd9bea364 |     196      |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 12:43:29 | 6af41d5b-9914-4f5c-9f9f-9acae2efbeec |     193      |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 12:43:08 | 63551336-cd0c-4b2a-864b-4f2f9bfc3c50 |     194      |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 12:42:47 | b8978451-e396-479f-9d58-dcfc58567bf4 |     196      |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 12:42:25 | a4a980fc-76f8-4783-9017-9421cefe032c |     193      |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 12:42:03 | 8e4298b8-a3ca-4d1b-aa4e-b56041bfd03f |     192      |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 12:41:42 | f5cf20ed-76a5-4fae-ac34-9eb8935ab119 |     196      |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 12:41:20 | 4835e60e-5988-4a08-b869-4f09e0a4286e |     193      |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 12:40:58 | 601cf74f-8bc9-4dd1-9124-b937f882aff3 |     194      |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 12:40:36 | f835afa2-55cc-4fb9-a58d-01fcd53ad824 |     193      |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 12:40:14 | 4ddf0f1d-8f9d-41bd-aa35-d6a4017fd8e5 |     196      |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 12:39:52 | 2db8548e-e638-4bfb-ad0f-422ba8c088b2 |     193      |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 12:39:30 | 06058c42-bc2c-4923-8ce4-039321498aab |     194      |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 12:39:08 | 2f848fb7-47b9-4017-96ce-858a6ecb7ac6 |     193      |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 12:38:47 | 84f26667-6c53-4644-a68b-d27772aeeb62 |     192      |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 12:38:25 | 7a0e4300-5478-4014-8ba0-5e6d17a0abff |     192      |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 12:38:04 | 0a958999-7fc0-4947-bfe4-6a1370dd5648 |     196      |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 12:37:42 | 977f15a5-6a05-4ac1-ba25-872acd6635cc |     195      |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 12:37:21 | c45f822c-8eab-4065-9e6c-f2504c868f5c |     192      |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 12:36:59 | ed5bd701-1723-4bee-a127-a210c661db9b |     194      |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 12:36:38 | afb3c11a-e1e1-48b7-82d7-4c52576bde40 |     193      |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 12:36:16 | b750d177-666f-48e7-a669-6ed3d0db0ecb |     192      |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 12:35:55 | 9a6309da-557f-4111-8eb8-f07eaf3c6556 |     195      |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 12:35:34 | 3d9f3dc4-2753-4d19-a5a7-e1f9f03d20db |     195      |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 12:35:12 | a41ebbef-c592-4b77-8dde-f68bc880bd49 |     193      |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 12:34:50 | 5274ceeb-f13c-431f-baab-c1f268a7b558 |     196      |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 12:34:28 | e4e0782a-6cd8-4a55-ab30-91f2db070cd1 |     195      |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 12:34:07 | 5010bbb9-18e5-4bf2-b783-38789eb2c6a9 |     195      |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 12:33:45 | e164cd0f-0b1b-4bf0-8861-4d015dff8d3b |     194      |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 12:33:24 | c8aa04a3-449d-424e-a612-f1e75f15f98d |     192      |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 12:33:01 | 7c0731ac-1626-4fb3-9220-33c51fddb3f2 |     194      |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 12:32:40 | aedd6cda-31bc-4a09-a4b7-e7cfa048d451 |     195      |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 12:32:18 | b49de292-21ca-4dbb-8075-b937c0cdaf0a |     195      |
# | 93834b50-7db2-11ee-b0f3-69bd975277c1 | 2023-11-29 12:31:56 | 95ea7778-bf66-4f9c-adb8-dc54d268013c |     193      |
# +--------------------------------------+---------------------+--------------------------------------+--------------+
# C:\Users\c21054458\AppData\Local\Temp\ipykernel_27716\4217028209.py:111: DeprecationWarning: datetime.datetime.utcfromtimestamp() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.fromtimestamp(timestamp, datetime.UTC).
#   formatted_ts = datetime.utcfromtimestamp(row["ts"] / 1000.0).strftime(

# %% [markdown]
# ## working code with User Input

# %%
sensor_nodes = [
    "node_5.01",
    "node_5.02",
    "node_5.03",
    "node_5.04",
    "node_5.05",
    "node_5.06",
    "node_5.07",
    "node_5.08",
    "node_5.09",
    "node_5.10",
    "node_5.11",
    "node_5.12",
    "node_5.13",
    "node_5.14",
    "node_5.15",
    "node_5.16",
    "node_5.17",
    "node_5.18",
    "node_5.19",
    "node_5.20",
    "node_5.21",
    "node_5.22",
    "node_5.23",
    "node_5.24",
    "node_5.25",
    "node_5.26",
    "node_5.27",
    "node_5.28",
    "node_5.29",
    "node_5.30",
    "node_5.31",
    "node_5.32",
    "node_5.33",
    "node_5.34",
]

data_to_fetch = [
    "airQualityValue",
    "c2h5ch",
    "co_gas",
    "co2value",
    "PM10Atmospheric",
    "hchoppmvalue",
    "humidity",
    "lux",
    "rsroratio5",
    "rsroratio9",
    "rsroratio3",
    "rsroratio2",
    "NO2",
    "o2per",
    "memsvalue",
    "tempreture",
    "VOC",
]

device_name_variable = input(f"What device do you see? ({', '.join(sensor_nodes)}): ")
user_input_key = input(
    f"What sensor readings do you need? ({', '.join(data_to_fetch)}): "
)


# device_name_variable = input("choose a device")  # "node_5.08"
# user_input_key = input("choose a sensor")  # "NO2"


import psycopg2
from psycopg2.extras import DictCursor
from prettytable import PrettyTable
from datetime import datetime

connection1 = psycopg2.connect(
    database="thingsboard",
    user="thingsboard",
    password="postgres",
    host="localhost",
    port=5432,
)
cursor1 = connection1.cursor(cursor_factory=DictCursor)
query1 = f"""
SELECT key_id FROM ts_kv_dictionary
WHERE key = '{user_input_key}';
"""
cursor1.execute(query1)
rows1 = cursor1.fetchall()
key_id_result = rows1[0]["key_id"] if rows1 else None
print("Key ID:", key_id_result)
cursor1.close()

# Mapping dictionary for device_name to entity_id
device_name_to_entity_id = {
    "node_5.01": "478abf30-7db2-11ee-b0f3-69bd975277c1",
    "node_5.02": "5306a860-7db2-11ee-b0f3-69bd975277c1",
    "node_5.03": "6b52c020-7db2-11ee-b0f3-69bd975277c1",
    "node_5.04": "725a3830-7db2-11ee-b0f3-69bd975277c1",
    "node_5.05": "78df12c0-7db2-11ee-b0f3-69bd975277c1",
    "node_5.06": "8084c6a0-7db2-11ee-b0f3-69bd975277c1",
    "node_5.07": "8c34df30-7db2-11ee-b0f3-69bd975277c1",
    "node_5.08": "93834b50-7db2-11ee-b0f3-69bd975277c1",
    "node_5.09": "997b9d50-7db2-11ee-b0f3-69bd975277c1",
    "node_5.10": "9f44f010-7db2-11ee-b0f3-69bd975277c1",
    "node_5.11": "a6250a00-7db2-11ee-b0f3-69bd975277c1",
    "node_5.12": "add0b150-7db2-11ee-b0f3-69bd975277c1",
    "node_5.13": "b4f415d0-7db2-11ee-b0f3-69bd975277c1",
    "node_5.14": "bad9ca30-7db2-11ee-b0f3-69bd975277c1",
    "node_5.15": "c0fe3540-7db2-11ee-b0f3-69bd975277c1",
    "node_5.16": "729855d0-7db6-11ee-b0f3-69bd975277c1",
    "node_5.17": "328afde0-83f5-11ee-a992-8978af4232d8",
    "node_5.18": "37c9eaf0-83f5-11ee-a992-8978af4232d8",
    "node_5.19": "3d369ec0-83f5-11ee-a992-8978af4232d8",
    "node_5.20": "4e709010-83f5-11ee-a992-8978af4232d8",
    "node_5.21": "53491a30-83f5-11ee-a992-8978af4232d8",
    "node_5.22": "58b83f00-83f5-11ee-a992-8978af4232d8",
    "node_5.23": "5d800040-83f5-11ee-a992-8978af4232d8",
    "node_5.24": "620958f0-83f5-11ee-a992-8978af4232d8",
    "node_5.25": "6694ad70-83f5-11ee-a992-8978af4232d8",
    "node_5.26": "6b6a7870-83f5-11ee-a992-8978af4232d8",
    "node_5.27": "7091e5e0-83f5-11ee-a992-8978af4232d8",
    "node_5.28": "759e7850-83f5-11ee-a992-8978af4232d8",
    "node_5.29": "7b537fc0-83f5-11ee-a992-8978af4232d8",
    "node_5.30": "7ffd58c0-83f5-11ee-a992-8978af4232d8",
    "node_5.31": "84bd51d0-83f5-11ee-a992-8978af4232d8",
    "node_5.32": "8afd3420-83f5-11ee-a992-8978af4232d8",
    "node_5.33": "90088e10-83f5-11ee-a992-8978af4232d8",
    "node_5.34": "9586a700-83f5-11ee-a992-8978af4232d8"
    # Add more mappings as needed
}


entity_id_variable = device_name_to_entity_id.get(device_name_variable, "")

if not entity_id_variable:
    print(f"Device with name '{device_name_variable}' not found in the mapping.")
    exit()

connection = psycopg2.connect(
    database="thingsboard",
    user="thingsboard",
    password="postgres",
    host="localhost",
    port=5432,
)

cursor2 = connection.cursor(cursor_factory=DictCursor)

query = f"""
SELECT 
  entity_id, 
  ts, 
  uuid, 
  COALESCE(bool_v::TEXT, str_v, long_v::TEXT, dbl_v::TEXT, json_v::TEXT) AS actual_value
FROM 
  ts_kv
WHERE
  entity_id = '{entity_id_variable}'
  AND key = {key_id_result}
ORDER BY 
  ts DESC
LIMIT 50
"""

cursor2.execute(query)
rows = cursor2.fetchall()

# Create a PrettyTable object
table = PrettyTable()
table.field_names = ["entity_id", "ts (formatted)", "uuid", "actual_value"]

# Add rows to the table
for row in rows:
    # Convert the timestamp to a formatted date and time
    formatted_ts = datetime.utcfromtimestamp(row["ts"] / 1000.0).strftime(
        "%Y-%m-%d %H:%M:%S"
    )
    # Add the row with the formatted timestamp
    table.add_row([row["entity_id"], formatted_ts, row["uuid"], row["actual_value"]])

# Print the table
print(table)

# Close the cursor and the database connection
cursor2.close()
connection.close()
# Out:
# Key ID: 131
# +--------------------------------------+---------------------+--------------------------------------+--------------+
# |              entity_id               |    ts (formatted)   |                 uuid                 | actual_value |
# +--------------------------------------+---------------------+--------------------------------------+--------------+
# | 5306a860-7db2-11ee-b0f3-69bd975277c1 | 2023-12-05 21:51:56 | f4e4cd6a-befd-45f8-b64e-59b5b09e5bce |     181      |
# | 5306a860-7db2-11ee-b0f3-69bd975277c1 | 2023-12-05 21:51:08 | 1cb4552e-e9ee-406b-82aa-70d4e27471e4 |     181      |
# | 5306a860-7db2-11ee-b0f3-69bd975277c1 | 2023-12-05 21:50:24 | 38f7afd9-ee42-4ae2-a8f4-06c209c396ec |     177      |
# | 5306a860-7db2-11ee-b0f3-69bd975277c1 | 2023-12-05 21:49:36 | 342874e3-52e6-48fe-9f83-2384a4ec81bb |     182      |
# | 5306a860-7db2-11ee-b0f3-69bd975277c1 | 2023-12-05 21:48:53 | 1e36a675-60c6-464e-9dbf-40326fdcbf4a |     182      |
# | 5306a860-7db2-11ee-b0f3-69bd975277c1 | 2023-12-05 21:47:57 | ab7d7d82-84b4-4b1a-a7bc-1c8a7ca2d6dc |     181      |
# | 5306a860-7db2-11ee-b0f3-69bd975277c1 | 2023-12-05 21:41:29 | 133e8381-03dd-4a7d-a315-fa9d77b0ea9f |     182      |
# | 5306a860-7db2-11ee-b0f3-69bd975277c1 | 2023-12-05 21:40:42 | 2de0709f-e541-44e8-9e30-08ab3bf6acb4 |     179      |
# | 5306a860-7db2-11ee-b0f3-69bd975277c1 | 2023-12-05 21:39:57 | cf512194-ea37-4e31-be0d-1222d12d5544 |     178      |
# | 5306a860-7db2-11ee-b0f3-69bd975277c1 | 2023-12-05 21:39:10 | 7748199c-3ad3-4396-93da-89cb10bf932d |     177      |
# | 5306a860-7db2-11ee-b0f3-69bd975277c1 | 2023-12-05 21:38:22 | 64c6ad29-d6e3-45f6-ae42-209f2a536a4e |     177      |
# | 5306a860-7db2-11ee-b0f3-69bd975277c1 | 2023-12-05 20:24:07 | 5eec01a6-1786-4a98-b4f5-d8eb7753e623 |     178      |
# | 5306a860-7db2-11ee-b0f3-69bd975277c1 | 2023-12-05 20:23:23 | a33098e5-71c7-4379-9ef7-bd13c3b24b7e |     178      |
# | 5306a860-7db2-11ee-b0f3-69bd975277c1 | 2023-12-05 20:22:42 | cc2e5cb9-4a00-4dd7-90ae-7e0a2b79b118 |     176      |
# | 5306a860-7db2-11ee-b0f3-69bd975277c1 | 2023-12-05 20:22:00 | 3654085e-c829-4b98-97f9-7d8d58a93ca2 |     182      |
# | 5306a860-7db2-11ee-b0f3-69bd975277c1 | 2023-12-05 20:21:18 | 33bf5011-ff13-47ac-baa7-89c77157332d |     182      |
# | 5306a860-7db2-11ee-b0f3-69bd975277c1 | 2023-12-05 20:20:36 | a1554fc3-0129-4500-9b60-f200e914b774 |     178      |
# | 5306a860-7db2-11ee-b0f3-69bd975277c1 | 2023-12-05 20:19:53 | d4171ae1-e39d-441a-8c80-341316a4ab53 |     180      |
# | 5306a860-7db2-11ee-b0f3-69bd975277c1 | 2023-12-05 20:19:10 | 40a13da9-7121-4873-b559-02e307822a5c |     180      |
# | 5306a860-7db2-11ee-b0f3-69bd975277c1 | 2023-12-05 20:18:26 | 8034ae40-6f54-4164-b7f0-4d8ea3925947 |     177      |
# | 5306a860-7db2-11ee-b0f3-69bd975277c1 | 2023-12-05 20:17:43 | 9399564d-febf-4e96-b1a1-eece230f5409 |     182      |
# | 5306a860-7db2-11ee-b0f3-69bd975277c1 | 2023-12-05 20:17:01 | 4a3ac502-bb59-4daf-8c11-3bec7e50c55d |     177      |
# | 5306a860-7db2-11ee-b0f3-69bd975277c1 | 2023-12-05 20:16:16 | e9ffeb24-ec9d-469f-a13c-a974b1f81b5f |     179      |
# | 5306a860-7db2-11ee-b0f3-69bd975277c1 | 2023-12-05 20:15:31 | dd3ac15d-1c96-40b8-b1bb-56df9f989527 |     176      |
# | 5306a860-7db2-11ee-b0f3-69bd975277c1 | 2023-12-05 20:14:46 | a6a37d65-411c-409a-8abb-b1b2ede8ec6c |     178      |
# | 5306a860-7db2-11ee-b0f3-69bd975277c1 | 2023-12-05 20:14:03 | b051bcad-8c67-40c0-bbb1-963b2cc6afc0 |     176      |
# | 5306a860-7db2-11ee-b0f3-69bd975277c1 | 2023-12-05 20:13:17 | 4fcbca3c-1eba-4afb-8984-7f06f9d97b58 |     179      |
# | 5306a860-7db2-11ee-b0f3-69bd975277c1 | 2023-12-05 20:12:31 | e2a6b2bc-b786-4564-ae79-e9518dd17367 |     177      |
# | 5306a860-7db2-11ee-b0f3-69bd975277c1 | 2023-12-05 20:11:46 | 6712f1e2-a705-469e-aa56-4d15f9b2c567 |     178      |
# | 5306a860-7db2-11ee-b0f3-69bd975277c1 | 2023-12-05 20:11:01 | 6868fb90-3166-437a-9abb-303a9a3c4ac8 |     179      |
# | 5306a860-7db2-11ee-b0f3-69bd975277c1 | 2023-12-05 20:10:15 | 187f1a1c-b295-4a72-9246-9b9e7b70160f |     182      |
# | 5306a860-7db2-11ee-b0f3-69bd975277c1 | 2023-12-05 20:09:26 | 8535efb7-4d5d-4e9c-91f1-8e76a6d250fa |     179      |
# | 5306a860-7db2-11ee-b0f3-69bd975277c1 | 2023-12-01 19:34:29 | 9ace1732-73e4-40c8-9a6c-522e2b182a32 |     176      |
# | 5306a860-7db2-11ee-b0f3-69bd975277c1 | 2023-12-01 19:34:03 | 695d311b-eb88-4225-b29b-0359cbefea18 |     179      |
# | 5306a860-7db2-11ee-b0f3-69bd975277c1 | 2023-12-01 19:33:42 | 790f8822-1694-49dd-b261-f0d2e4fe8532 |     177      |
# | 5306a860-7db2-11ee-b0f3-69bd975277c1 | 2023-12-01 19:33:23 | 9d084bda-2882-4b40-a728-fb8b4cfcf24c |     176      |
# | 5306a860-7db2-11ee-b0f3-69bd975277c1 | 2023-12-01 19:33:07 | 1128480b-61ac-4423-ba1c-b1b1bb320c32 |     182      |
# | 5306a860-7db2-11ee-b0f3-69bd975277c1 | 2023-12-01 19:32:41 | 92f9de93-39ff-4489-9bc9-71872136b5ec |     177      |
# | 5306a860-7db2-11ee-b0f3-69bd975277c1 | 2023-12-01 19:32:21 | f00fdaad-aef6-4c59-8afb-935c5431d661 |     182      |
# | 5306a860-7db2-11ee-b0f3-69bd975277c1 | 2023-12-01 19:31:56 | d8ac68a6-a0ef-4595-99df-29d6e7960e62 |     176      |
# | 5306a860-7db2-11ee-b0f3-69bd975277c1 | 2023-12-01 19:31:32 | 19df9c01-f7a7-4561-a922-a5b8b2a2b09c |     180      |
# | 5306a860-7db2-11ee-b0f3-69bd975277c1 | 2023-12-01 19:31:16 | 33583232-e00c-46ad-a1dd-22d8e5800a68 |     181      |
# | 5306a860-7db2-11ee-b0f3-69bd975277c1 | 2023-12-01 19:30:53 | 3d48f75c-b4f1-45e5-8290-46ca75cad23f |     179      |
# | 5306a860-7db2-11ee-b0f3-69bd975277c1 | 2023-12-01 19:30:28 | a9a78e02-1a1f-4da9-a7a2-5420dafcb413 |     180      |
# | 5306a860-7db2-11ee-b0f3-69bd975277c1 | 2023-12-01 19:30:03 | 2103f2ec-ef16-4110-9a2c-1035cf626ad3 |     179      |
# | 5306a860-7db2-11ee-b0f3-69bd975277c1 | 2023-12-01 19:29:38 | c455226e-e304-49ab-b6d0-1b2765e33bc9 |     178      |
# | 5306a860-7db2-11ee-b0f3-69bd975277c1 | 2023-12-01 19:29:21 | c2f1672b-a054-4823-8ff8-d16dee1cd00c |     178      |
# | 5306a860-7db2-11ee-b0f3-69bd975277c1 | 2023-12-01 19:28:57 | 04cf82c4-6279-4b86-b99c-9c98d6aa41be |     179      |
# | 5306a860-7db2-11ee-b0f3-69bd975277c1 | 2023-12-01 19:28:36 | 57c42a70-d994-417a-ae23-752b209dd40d |     181      |
# | 5306a860-7db2-11ee-b0f3-69bd975277c1 | 2023-12-01 19:28:12 | 690e6028-b7ce-48d8-b1ef-7961da5329fe |     178      |
# +--------------------------------------+---------------------+--------------------------------------+--------------+
# C:\Users\c21054458\AppData\Local\Temp\ipykernel_11904\2743272812.py:173: DeprecationWarning: datetime.datetime.utcfromtimestamp() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.fromtimestamp(timestamp, datetime.UTC).
#   formatted_ts = datetime.utcfromtimestamp(row["ts"] / 1000.0).strftime(

# %% [markdown]
# code for rasa

# %%
sensor_nodes = [
    "node_5.01",
    "node_5.02",
    "node_5.03",
    "node_5.04",
    "node_5.05",
    "node_5.06",
    "node_5.07",
    "node_5.08",
    "node_5.09",
    "node_5.10",
    "node_5.11",
    "node_5.12",
    "node_5.13",
    "node_5.14",
    "node_5.15",
    "node_5.16",
    "node_5.17",
    "node_5.18",
    "node_5.19",
    "node_5.20",
    "node_5.21",
    "node_5.22",
    "node_5.23",
    "node_5.24",
    "node_5.25",
    "node_5.26",
    "node_5.27",
    "node_5.28",
    "node_5.29",
    "node_5.30",
    "node_5.31",
    "node_5.32",
    "node_5.33",
    "node_5.34",
]

data_to_fetch = [
    "airQualityValue",
    "c2h5ch",
    "co_gas",
    "co2value",
    "PM10Atmospheric",
    "hchoppmvalue",
    "humidity",
    "lux",
    "rsroratio5",
    "rsroratio9",
    "rsroratio3",
    "rsroratio2",
    "NO2",
    "o2per",
    "memsvalue",
    "tempreture",
    "VOC",
]

device_name_variable = input(f"What device do you see? ({', '.join(sensor_nodes)}): ")
user_input_key = input(
    f"What sensor readings do you need? ({', '.join(data_to_fetch)}): "
)


# device_name_variable = input("choose a device")  # "node_5.08"
# user_input_key = input("choose a sensor")  # "NO2"


import psycopg2
from psycopg2.extras import DictCursor
from prettytable import PrettyTable
from datetime import datetime

connection1 = psycopg2.connect(
    database="thingsboard",
    user="thingsboard",
    password="postgres",
    host="localhost",
    port=5432,
)
cursor1 = connection1.cursor(cursor_factory=DictCursor)
query1 = f"""
SELECT key_id FROM ts_kv_dictionary
WHERE key = '{user_input_key}';
"""
cursor1.execute(query1)
rows1 = cursor1.fetchall()
key_id_result = rows1[0]["key_id"] if rows1 else None
print("Key ID:", key_id_result)
cursor1.close()

# Mapping dictionary for device_name to entity_id
device_name_to_entity_id = {
    "node_5.01": "478abf30-7db2-11ee-b0f3-69bd975277c1",
    "node_5.02": "5306a860-7db2-11ee-b0f3-69bd975277c1",
    "node_5.03": "6b52c020-7db2-11ee-b0f3-69bd975277c1",
    "node_5.04": "725a3830-7db2-11ee-b0f3-69bd975277c1",
    "node_5.05": "78df12c0-7db2-11ee-b0f3-69bd975277c1",
    "node_5.06": "8084c6a0-7db2-11ee-b0f3-69bd975277c1",
    "node_5.07": "8c34df30-7db2-11ee-b0f3-69bd975277c1",
    "node_5.08": "93834b50-7db2-11ee-b0f3-69bd975277c1",
    "node_5.09": "997b9d50-7db2-11ee-b0f3-69bd975277c1",
    "node_5.10": "9f44f010-7db2-11ee-b0f3-69bd975277c1",
    "node_5.11": "a6250a00-7db2-11ee-b0f3-69bd975277c1",
    "node_5.12": "add0b150-7db2-11ee-b0f3-69bd975277c1",
    "node_5.13": "b4f415d0-7db2-11ee-b0f3-69bd975277c1",
    "node_5.14": "bad9ca30-7db2-11ee-b0f3-69bd975277c1",
    "node_5.15": "c0fe3540-7db2-11ee-b0f3-69bd975277c1",
    "node_5.16": "729855d0-7db6-11ee-b0f3-69bd975277c1",
    "node_5.17": "328afde0-83f5-11ee-a992-8978af4232d8",
    "node_5.18": "37c9eaf0-83f5-11ee-a992-8978af4232d8",
    "node_5.19": "3d369ec0-83f5-11ee-a992-8978af4232d8",
    "node_5.20": "4e709010-83f5-11ee-a992-8978af4232d8",
    "node_5.21": "53491a30-83f5-11ee-a992-8978af4232d8",
    "node_5.22": "58b83f00-83f5-11ee-a992-8978af4232d8",
    "node_5.23": "5d800040-83f5-11ee-a992-8978af4232d8",
    "node_5.24": "620958f0-83f5-11ee-a992-8978af4232d8",
    "node_5.25": "6694ad70-83f5-11ee-a992-8978af4232d8",
    "node_5.26": "6b6a7870-83f5-11ee-a992-8978af4232d8",
    "node_5.27": "7091e5e0-83f5-11ee-a992-8978af4232d8",
    "node_5.28": "759e7850-83f5-11ee-a992-8978af4232d8",
    "node_5.29": "7b537fc0-83f5-11ee-a992-8978af4232d8",
    "node_5.30": "7ffd58c0-83f5-11ee-a992-8978af4232d8",
    "node_5.31": "84bd51d0-83f5-11ee-a992-8978af4232d8",
    "node_5.32": "8afd3420-83f5-11ee-a992-8978af4232d8",
    "node_5.33": "90088e10-83f5-11ee-a992-8978af4232d8",
    "node_5.34": "9586a700-83f5-11ee-a992-8978af4232d8"
    # Add more mappings as needed
}


entity_id_variable = device_name_to_entity_id.get(device_name_variable, "")

if not entity_id_variable:
    print(f"Device with name '{device_name_variable}' not found in the mapping.")
    exit()

connection = psycopg2.connect(
    database="thingsboard",
    user="thingsboard",
    password="postgres",
    host="localhost",
    port=5432,
)

cursor2 = connection.cursor(cursor_factory=DictCursor)

query = f"""
SELECT 
  entity_id, 
  ts, 
  uuid, 
  COALESCE(bool_v::TEXT, str_v, long_v::TEXT, dbl_v::TEXT, json_v::TEXT) AS actual_value
FROM 
  ts_kv
WHERE
  entity_id = '{entity_id_variable}'
  AND key = {key_id_result}
ORDER BY 
  ts DESC
LIMIT 1
"""

cursor2.execute(query)
rows = cursor2.fetchall()
if rows:
    last_value = rows[0]["actual_value"]
    print("Latest Reading:", last_value)
else:
    print("No data found for the specified device and sensor.")

# Close the cursor and the database connection
cursor2.close()
connection.close()
# Out:
# Key ID: 134
# Latest Reading: 639.49

# %%
import itertools
import random

# Define the sensor_nodes and data_to_fetch lists
sensor_nodes = [
    "node_5.01",
    "node_5.02",
    "node_5.03",
    "node_5.04",
    "node_5.05",
    "node_5.06",
    "node_5.07",
    "node_5.08",
    "node_5.09",
    "node_5.10",
    "node_5.11",
    "node_5.12",
    "node_5.13",
    "node_5.14",
    "node_5.15",
    "node_5.16",
    "node_5.17",
    "node_5.18",
    "node_5.19",
    "node_5.20",
    "node_5.21",
    "node_5.22",
    "node_5.23",
    "node_5.24",
    "node_5.25",
    "node_5.26",
    "node_5.27",
    "node_5.28",
    "node_5.29",
    "node_5.30",
    "node_5.31",
    "node_5.32",
    "node_5.33",
    "node_5.34",
]

data_to_fetch = [
    "airQualityValue",
    "c2h5ch",
    "co_gas",
    "co2value",
    "PM10Atmospheric",
    "hchoppmvalue",
    "humidity",
    "lux",
    "rsroratio5",
    "rsroratio9",
    "rsroratio3",
    "rsroratio2",
    "NO2",
    "o2per",
    "memsvalue",
    "tempreture",
    "VOC",
]

random_sentences = [
    "please tell me",
    "tell me readings for",
    "what is the",
    "can you provide",
    "give me",
    "share the",
    "provide the",
]

# Generate all possible combinations with random sentences
combinations = list(itertools.product(sensor_nodes, data_to_fetch))
random.shuffle(combinations)

# Print the generated patterns with random sentences
for node, data in combinations:
    sentence = random.choice(random_sentences)
    print(f"- {sentence} [{node}](sensor_nodes) [{data}](data_to_fetch)?")

# Optionally, you can save the patterns to a file
# with open("generated_patterns.txt", "w") as file:
#     for node, data in combinations:
#         sentence = random.choice(random_sentences)
#         file.write(f"- {sentence} [{node}](sensor_nodes) [{data}](data_to_fetch)?\n")
# Out:
# - please tell me [node_5.03](sensor_nodes) [o2per](data_to_fetch)?
# - tell me readings for [node_5.12](sensor_nodes) [rsroratio2](data_to_fetch)?
# - please tell me [node_5.13](sensor_nodes) [rsroratio5](data_to_fetch)?
# - please tell me [node_5.30](sensor_nodes) [VOC](data_to_fetch)?
# - give me [node_5.07](sensor_nodes) [humidity](data_to_fetch)?
# - tell me readings for [node_5.31](sensor_nodes) [c2h5ch](data_to_fetch)?
# - share the [node_5.07](sensor_nodes) [c2h5ch](data_to_fetch)?
# - tell me readings for [node_5.27](sensor_nodes) [tempreture](data_to_fetch)?
# - give me [node_5.17](sensor_nodes) [memsvalue](data_to_fetch)?
# - provide the [node_5.03](sensor_nodes) [airQualityValue](data_to_fetch)?
# - provide the [node_5.18](sensor_nodes) [rsroratio5](data_to_fetch)?
# - can you provide [node_5.19](sensor_nodes) [c2h5ch](data_to_fetch)?
# - share the [node_5.31](sensor_nodes) [NO2](data_to_fetch)?
# - share the [node_5.02](sensor_nodes) [rsroratio3](data_to_fetch)?
# - what is the [node_5.30](sensor_nodes) [rsroratio9](data_to_fetch)?
# - provide the [node_5.28](sensor_nodes) [lux](data_to_fetch)?
# - what is the [node_5.34](sensor_nodes) [airQualityValue](data_to_fetch)?
# - share the [node_5.33](sensor_nodes) [c2h5ch](data_to_fetch)?
# - share the [node_5.07](sensor_nodes) [PM10Atmospheric](data_to_fetch)?
# - can you provide [node_5.21](sensor_nodes) [rsroratio2](data_to_fetch)?
# - share the [node_5.20](sensor_nodes) [co_gas](data_to_fetch)?
# - what is the [node_5.28](sensor_nodes) [PM10Atmospheric](data_to_fetch)?
# - tell me readings for [node_5.04](sensor_nodes) [rsroratio3](data_to_fetch)?
# - can you provide [node_5.21](sensor_nodes) [VOC](data_to_fetch)?
# - give me [node_5.20](sensor_nodes) [PM10Atmospheric](data_to_fetch)?
# - provide the [node_5.10](sensor_nodes) [hchoppmvalue](data_to_fetch)?
# - please tell me [node_5.02](sensor_nodes) [PM10Atmospheric](data_to_fetch)?
# - share the [node_5.23](sensor_nodes) [NO2](data_to_fetch)?
# - can you provide [node_5.29](sensor_nodes) [c2h5ch](data_to_fetch)?
# - share the [node_5.08](sensor_nodes) [tempreture](data_to_fetch)?
# - tell me readings for [node_5.18](sensor_nodes) [rsroratio9](data_to_fetch)?
# - what is the [node_5.29](sensor_nodes) [rsroratio2](data_to_fetch)?
# - give me [node_5.29](sensor_nodes) [tempreture](data_to_fetch)?
# - give me [node_5.28](sensor_nodes) [rsroratio2](data_to_fetch)?
# - can you provide [node_5.31](sensor_nodes) [airQualityValue](data_to_fetch)?
# - can you provide [node_5.24](sensor_nodes) [rsroratio3](data_to_fetch)?
# - tell me readings for [node_5.34](sensor_nodes) [tempreture](data_to_fetch)?
# - what is the [node_5.11](sensor_nodes) [PM10Atmospheric](data_to_fetch)?
# - share the [node_5.20](sensor_nodes) [co2value](data_to_fetch)?
# - tell me readings for [node_5.06](sensor_nodes) [rsroratio3](data_to_fetch)?
# - what is the [node_5.07](sensor_nodes) [memsvalue](data_to_fetch)?
# - please tell me [node_5.20](sensor_nodes) [VOC](data_to_fetch)?
# - provide the [node_5.05](sensor_nodes) [tempreture](data_to_fetch)?
# - please tell me [node_5.04](sensor_nodes) [memsvalue](data_to_fetch)?
# - give me [node_5.14](sensor_nodes) [co_gas](data_to_fetch)?
# - can you provide [node_5.18](sensor_nodes) [o2per](data_to_fetch)?
# - what is the [node_5.07](sensor_nodes) [rsroratio5](data_to_fetch)?
# - tell me readings for [node_5.25](sensor_nodes) [NO2](data_to_fetch)?
# - can you provide [node_5.06](sensor_nodes) [VOC](data_to_fetch)?
# - provide the [node_5.26](sensor_nodes) [tempreture](data_to_fetch)?
# - can you provide [node_5.23](sensor_nodes) [rsroratio5](data_to_fetch)?
# - please tell me [node_5.22](sensor_nodes) [hchoppmvalue](data_to_fetch)?
# - share the [node_5.07](sensor_nodes) [VOC](data_to_fetch)?
# - please tell me [node_5.02](sensor_nodes) [NO2](data_to_fetch)?
# - can you provide [node_5.13](sensor_nodes) [humidity](data_to_fetch)?
# - can you provide [node_5.31](sensor_nodes) [tempreture](data_to_fetch)?
# - give me [node_5.17](sensor_nodes) [humidity](data_to_fetch)?
# - give me [node_5.10](sensor_nodes) [tempreture](data_to_fetch)?
# - tell me readings for [node_5.24](sensor_nodes) [humidity](data_to_fetch)?
# - what is the [node_5.30](sensor_nodes) [airQualityValue](data_to_fetch)?
# - give me [node_5.13](sensor_nodes) [lux](data_to_fetch)?
# - please tell me [node_5.08](sensor_nodes) [co2value](data_to_fetch)?
# - please tell me [node_5.15](sensor_nodes) [NO2](data_to_fetch)?
# - tell me readings for [node_5.12](sensor_nodes) [airQualityValue](data_to_fetch)?
# - what is the [node_5.22](sensor_nodes) [airQualityValue](data_to_fetch)?
# - give me [node_5.33](sensor_nodes) [rsroratio3](data_to_fetch)?
# - give me [node_5.28](sensor_nodes) [NO2](data_to_fetch)?
# - give me [node_5.06](sensor_nodes) [memsvalue](data_to_fetch)?
# - tell me readings for [node_5.26](sensor_nodes) [humidity](data_to_fetch)?
# - what is the [node_5.21](sensor_nodes) [NO2](data_to_fetch)?
# - share the [node_5.16](sensor_nodes) [NO2](data_to_fetch)?
# - provide the [node_5.05](sensor_nodes) [o2per](data_to_fetch)?
# - please tell me [node_5.01](sensor_nodes) [rsroratio2](data_to_fetch)?
# - tell me readings for [node_5.05](sensor_nodes) [rsroratio9](data_to_fetch)?
# - provide the [node_5.32](sensor_nodes) [co2value](data_to_fetch)?
# - what is the [node_5.11](sensor_nodes) [rsroratio9](data_to_fetch)?
# - what is the [node_5.20](sensor_nodes) [hchoppmvalue](data_to_fetch)?
# - give me [node_5.08](sensor_nodes) [rsroratio3](data_to_fetch)?
# - share the [node_5.34](sensor_nodes) [NO2](data_to_fetch)?
# - share the [node_5.24](sensor_nodes) [rsroratio5](data_to_fetch)?
# - tell me readings for [node_5.24](sensor_nodes) [tempreture](data_to_fetch)?
# - what is the [node_5.08](sensor_nodes) [VOC](data_to_fetch)?
# - tell me readings for [node_5.23](sensor_nodes) [hchoppmvalue](data_to_fetch)?
# - give me [node_5.20](sensor_nodes) [rsroratio3](data_to_fetch)?
# - please tell me [node_5.23](sensor_nodes) [co_gas](data_to_fetch)?
# - share the [node_5.05](sensor_nodes) [c2h5ch](data_to_fetch)?
# - share the [node_5.11](sensor_nodes) [c2h5ch](data_to_fetch)?
# - give me [node_5.29](sensor_nodes) [PM10Atmospheric](data_to_fetch)?
# - please tell me [node_5.18](sensor_nodes) [hchoppmvalue](data_to_fetch)?
# - can you provide [node_5.09](sensor_nodes) [memsvalue](data_to_fetch)?
# - what is the [node_5.19](sensor_nodes) [hchoppmvalue](data_to_fetch)?
# - what is the [node_5.03](sensor_nodes) [PM10Atmospheric](data_to_fetch)?
# - can you provide [node_5.34](sensor_nodes) [rsroratio5](data_to_fetch)?
# - share the [node_5.07](sensor_nodes) [co_gas](data_to_fetch)?
# - what is the [node_5.02](sensor_nodes) [memsvalue](data_to_fetch)?
# - please tell me [node_5.03](sensor_nodes) [rsroratio3](data_to_fetch)?
# - what is the [node_5.14](sensor_nodes) [PM10Atmospheric](data_to_fetch)?
# - give me [node_5.24](sensor_nodes) [VOC](data_to_fetch)?
# - tell me readings for [node_5.28](sensor_nodes) [hchoppmvalue](data_to_fetch)?
# - give me [node_5.20](sensor_nodes) [NO2](data_to_fetch)?
# - tell me readings for [node_5.07](sensor_nodes) [rsroratio9](data_to_fetch)?
# - tell me readings for [node_5.31](sensor_nodes) [rsroratio2](data_to_fetch)?
# - can you provide [node_5.01](sensor_nodes) [co_gas](data_to_fetch)?
# - share the [node_5.24](sensor_nodes) [c2h5ch](data_to_fetch)?
# - give me [node_5.17](sensor_nodes) [c2h5ch](data_to_fetch)?
# - what is the [node_5.07](sensor_nodes) [lux](data_to_fetch)?
# - please tell me [node_5.26](sensor_nodes) [co_gas](data_to_fetch)?
# - give me [node_5.24](sensor_nodes) [rsroratio2](data_to_fetch)?
# - share the [node_5.01](sensor_nodes) [NO2](data_to_fetch)?
# - what is the [node_5.24](sensor_nodes) [co2value](data_to_fetch)?
# - what is the [node_5.32](sensor_nodes) [rsroratio5](data_to_fetch)?
# - share the [node_5.06](sensor_nodes) [c2h5ch](data_to_fetch)?
# - can you provide [node_5.18](sensor_nodes) [humidity](data_to_fetch)?
# - provide the [node_5.29](sensor_nodes) [humidity](data_to_fetch)?
# - what is the [node_5.06](sensor_nodes) [rsroratio9](data_to_fetch)?
# - what is the [node_5.33](sensor_nodes) [tempreture](data_to_fetch)?
# - tell me readings for [node_5.15](sensor_nodes) [memsvalue](data_to_fetch)?
# - share the [node_5.12](sensor_nodes) [co_gas](data_to_fetch)?
# - what is the [node_5.29](sensor_nodes) [rsroratio3](data_to_fetch)?
# - give me [node_5.32](sensor_nodes) [tempreture](data_to_fetch)?
# - please tell me [node_5.09](sensor_nodes) [tempreture](data_to_fetch)?
# - tell me readings for [node_5.20](sensor_nodes) [rsroratio9](data_to_fetch)?
# - provide the [node_5.26](sensor_nodes) [VOC](data_to_fetch)?
# - can you provide [node_5.15](sensor_nodes) [tempreture](data_to_fetch)?
# - can you provide [node_5.32](sensor_nodes) [lux](data_to_fetch)?
# - provide the [node_5.09](sensor_nodes) [c2h5ch](data_to_fetch)?
# - share the [node_5.23](sensor_nodes) [o2per](data_to_fetch)?
# - share the [node_5.08](sensor_nodes) [memsvalue](data_to_fetch)?
# - give me [node_5.20](sensor_nodes) [rsroratio5](data_to_fetch)?
# - tell me readings for [node_5.05](sensor_nodes) [lux](data_to_fetch)?
# - can you provide [node_5.12](sensor_nodes) [NO2](data_to_fetch)?
# - share the [node_5.03](sensor_nodes) [NO2](data_to_fetch)?
# - give me [node_5.02](sensor_nodes) [hchoppmvalue](data_to_fetch)?
# - share the [node_5.25](sensor_nodes) [c2h5ch](data_to_fetch)?
# - please tell me [node_5.12](sensor_nodes) [rsroratio5](data_to_fetch)?
# - give me [node_5.05](sensor_nodes) [rsroratio5](data_to_fetch)?
# - share the [node_5.27](sensor_nodes) [airQualityValue](data_to_fetch)?
# - tell me readings for [node_5.32](sensor_nodes) [humidity](data_to_fetch)?
# - give me [node_5.34](sensor_nodes) [rsroratio3](data_to_fetch)?
# - share the [node_5.30](sensor_nodes) [co2value](data_to_fetch)?
# - give me [node_5.01](sensor_nodes) [humidity](data_to_fetch)?
# - please tell me [node_5.20](sensor_nodes) [tempreture](data_to_fetch)?
# - share the [node_5.28](sensor_nodes) [airQualityValue](data_to_fetch)?
# - what is the [node_5.08](sensor_nodes) [rsroratio5](data_to_fetch)?
# - provide the [node_5.08](sensor_nodes) [PM10Atmospheric](data_to_fetch)?
# - give me [node_5.23](sensor_nodes) [rsroratio3](data_to_fetch)?
# - share the [node_5.16](sensor_nodes) [rsroratio5](data_to_fetch)?
# - share the [node_5.33](sensor_nodes) [airQualityValue](data_to_fetch)?
# - please tell me [node_5.22](sensor_nodes) [c2h5ch](data_to_fetch)?
# - what is the [node_5.24](sensor_nodes) [rsroratio9](data_to_fetch)?
# - what is the [node_5.18](sensor_nodes) [airQualityValue](data_to_fetch)?
# - share the [node_5.03](sensor_nodes) [hchoppmvalue](data_to_fetch)?
# - can you provide [node_5.20](sensor_nodes) [rsroratio2](data_to_fetch)?
# - can you provide [node_5.04](sensor_nodes) [rsroratio5](data_to_fetch)?
# - give me [node_5.11](sensor_nodes) [lux](data_to_fetch)?
# - provide the [node_5.29](sensor_nodes) [lux](data_to_fetch)?
# - what is the [node_5.12](sensor_nodes) [VOC](data_to_fetch)?
# - can you provide [node_5.16](sensor_nodes) [memsvalue](data_to_fetch)?
# - give me [node_5.07](sensor_nodes) [NO2](data_to_fetch)?
# - provide the [node_5.22](sensor_nodes) [rsroratio2](data_to_fetch)?
# - tell me readings for [node_5.33](sensor_nodes) [NO2](data_to_fetch)?
# - share the [node_5.27](sensor_nodes) [PM10Atmospheric](data_to_fetch)?
# - please tell me [node_5.21](sensor_nodes) [memsvalue](data_to_fetch)?
# - share the [node_5.27](sensor_nodes) [memsvalue](data_to_fetch)?
# - provide the [node_5.08](sensor_nodes) [humidity](data_to_fetch)?
# - can you provide [node_5.17](sensor_nodes) [VOC](data_to_fetch)?
# - tell me readings for [node_5.31](sensor_nodes) [o2per](data_to_fetch)?
# - what is the [node_5.29](sensor_nodes) [hchoppmvalue](data_to_fetch)?
# - can you provide [node_5.19](sensor_nodes) [rsroratio5](data_to_fetch)?
# - provide the [node_5.26](sensor_nodes) [o2per](data_to_fetch)?
# - can you provide [node_5.31](sensor_nodes) [rsroratio9](data_to_fetch)?
# - can you provide [node_5.14](sensor_nodes) [rsroratio3](data_to_fetch)?
# - tell me readings for [node_5.15](sensor_nodes) [c2h5ch](data_to_fetch)?
# - tell me readings for [node_5.19](sensor_nodes) [PM10Atmospheric](data_to_fetch)?
# - tell me readings for [node_5.03](sensor_nodes) [c2h5ch](data_to_fetch)?
# - give me [node_5.01](sensor_nodes) [rsroratio9](data_to_fetch)?
# - please tell me [node_5.25](sensor_nodes) [PM10Atmospheric](data_to_fetch)?
# - what is the [node_5.28](sensor_nodes) [c2h5ch](data_to_fetch)?
# - provide the [node_5.09](sensor_nodes) [rsroratio9](data_to_fetch)?
# - please tell me [node_5.29](sensor_nodes) [VOC](data_to_fetch)?
# - share the [node_5.18](sensor_nodes) [memsvalue](data_to_fetch)?
# - please tell me [node_5.25](sensor_nodes) [co_gas](data_to_fetch)?
# - please tell me [node_5.27](sensor_nodes) [rsroratio5](data_to_fetch)?
# - provide the [node_5.18](sensor_nodes) [lux](data_to_fetch)?
# - provide the [node_5.32](sensor_nodes) [memsvalue](data_to_fetch)?
# - tell me readings for [node_5.33](sensor_nodes) [VOC](data_to_fetch)?
# - can you provide [node_5.22](sensor_nodes) [tempreture](data_to_fetch)?
# - tell me readings for [node_5.08](sensor_nodes) [lux](data_to_fetch)?
# - what is the [node_5.26](sensor_nodes) [c2h5ch](data_to_fetch)?
# - what is the [node_5.01](sensor_nodes) [memsvalue](data_to_fetch)?
# - can you provide [node_5.12](sensor_nodes) [hchoppmvalue](data_to_fetch)?
# - share the [node_5.15](sensor_nodes) [o2per](data_to_fetch)?
# - provide the [node_5.25](sensor_nodes) [rsroratio2](data_to_fetch)?
# - provide the [node_5.28](sensor_nodes) [VOC](data_to_fetch)?
# - provide the [node_5.08](sensor_nodes) [hchoppmvalue](data_to_fetch)?
# - tell me readings for [node_5.20](sensor_nodes) [humidity](data_to_fetch)?
# - give me [node_5.34](sensor_nodes) [hchoppmvalue](data_to_fetch)?
# - what is the [node_5.29](sensor_nodes) [co_gas](data_to_fetch)?
# - what is the [node_5.21](sensor_nodes) [airQualityValue](data_to_fetch)?
# - can you provide [node_5.05](sensor_nodes) [memsvalue](data_to_fetch)?
# - can you provide [node_5.23](sensor_nodes) [PM10Atmospheric](data_to_fetch)?
# - what is the [node_5.30](sensor_nodes) [c2h5ch](data_to_fetch)?
# - share the [node_5.02](sensor_nodes) [rsroratio2](data_to_fetch)?
# - can you provide [node_5.05](sensor_nodes) [airQualityValue](data_to_fetch)?
# - share the [node_5.17](sensor_nodes) [NO2](data_to_fetch)?
# - what is the [node_5.29](sensor_nodes) [rsroratio5](data_to_fetch)?
# - tell me readings for [node_5.26](sensor_nodes) [PM10Atmospheric](data_to_fetch)?
# - please tell me [node_5.11](sensor_nodes) [memsvalue](data_to_fetch)?
# - what is the [node_5.34](sensor_nodes) [PM10Atmospheric](data_to_fetch)?
# - give me [node_5.17](sensor_nodes) [rsroratio9](data_to_fetch)?
# - can you provide [node_5.10](sensor_nodes) [rsroratio2](data_to_fetch)?
# - tell me readings for [node_5.14](sensor_nodes) [memsvalue](data_to_fetch)?
# - provide the [node_5.17](sensor_nodes) [co2value](data_to_fetch)?
# - give me [node_5.11](sensor_nodes) [rsroratio2](data_to_fetch)?
# - can you provide [node_5.33](sensor_nodes) [PM10Atmospheric](data_to_fetch)?
# - share the [node_5.32](sensor_nodes) [rsroratio2](data_to_fetch)?
# - what is the [node_5.33](sensor_nodes) [humidity](data_to_fetch)?
# - can you provide [node_5.34](sensor_nodes) [c2h5ch](data_to_fetch)?
# - please tell me [node_5.30](sensor_nodes) [rsroratio2](data_to_fetch)?
# - please tell me [node_5.15](sensor_nodes) [rsroratio5](data_to_fetch)?
# - tell me readings for [node_5.29](sensor_nodes) [airQualityValue](data_to_fetch)?
# - share the [node_5.19](sensor_nodes) [rsroratio9](data_to_fetch)?
# - provide the [node_5.13](sensor_nodes) [rsroratio2](data_to_fetch)?
# - tell me readings for [node_5.12](sensor_nodes) [rsroratio9](data_to_fetch)?
# - share the [node_5.08](sensor_nodes) [NO2](data_to_fetch)?
# - provide the [node_5.19](sensor_nodes) [NO2](data_to_fetch)?
# - give me [node_5.13](sensor_nodes) [PM10Atmospheric](data_to_fetch)?
# - tell me readings for [node_5.07](sensor_nodes) [co2value](data_to_fetch)?
# - can you provide [node_5.18](sensor_nodes) [co2value](data_to_fetch)?
# - share the [node_5.10](sensor_nodes) [airQualityValue](data_to_fetch)?
# - share the [node_5.32](sensor_nodes) [VOC](data_to_fetch)?
# - please tell me [node_5.15](sensor_nodes) [co_gas](data_to_fetch)?
# - tell me readings for [node_5.18](sensor_nodes) [PM10Atmospheric](data_to_fetch)?
# - share the [node_5.22](sensor_nodes) [lux](data_to_fetch)?
# - give me [node_5.30](sensor_nodes) [lux](data_to_fetch)?
# - share the [node_5.04](sensor_nodes) [VOC](data_to_fetch)?
# - share the [node_5.25](sensor_nodes) [co2value](data_to_fetch)?
# - what is the [node_5.09](sensor_nodes) [hchoppmvalue](data_to_fetch)?
# - can you provide [node_5.32](sensor_nodes) [rsroratio9](data_to_fetch)?
# - share the [node_5.16](sensor_nodes) [lux](data_to_fetch)?
# - what is the [node_5.22](sensor_nodes) [co2value](data_to_fetch)?
# - tell me readings for [node_5.33](sensor_nodes) [co2value](data_to_fetch)?
# - give me [node_5.26](sensor_nodes) [rsroratio3](data_to_fetch)?
# - share the [node_5.34](sensor_nodes) [co_gas](data_to_fetch)?
# - provide the [node_5.11](sensor_nodes) [co_gas](data_to_fetch)?
# - provide the [node_5.30](sensor_nodes) [rsroratio3](data_to_fetch)?
# - can you provide [node_5.11](sensor_nodes) [tempreture](data_to_fetch)?
# - give me [node_5.11](sensor_nodes) [rsroratio5](data_to_fetch)?
# - share the [node_5.07](sensor_nodes) [rsroratio2](data_to_fetch)?
# - please tell me [node_5.15](sensor_nodes) [VOC](data_to_fetch)?
# - tell me readings for [node_5.25](sensor_nodes) [hchoppmvalue](data_to_fetch)?
# - give me [node_5.31](sensor_nodes) [VOC](data_to_fetch)?
# - give me [node_5.30](sensor_nodes) [rsroratio5](data_to_fetch)?
# - please tell me [node_5.13](sensor_nodes) [c2h5ch](data_to_fetch)?
# - provide the [node_5.06](sensor_nodes) [rsroratio2](data_to_fetch)?
# - can you provide [node_5.23](sensor_nodes) [airQualityValue](data_to_fetch)?
# - tell me readings for [node_5.03](sensor_nodes) [rsroratio5](data_to_fetch)?
# - can you provide [node_5.15](sensor_nodes) [co2value](data_to_fetch)?
# - give me [node_5.30](sensor_nodes) [PM10Atmospheric](data_to_fetch)?
# - what is the [node_5.17](sensor_nodes) [rsroratio3](data_to_fetch)?
# - can you provide [node_5.06](sensor_nodes) [tempreture](data_to_fetch)?
# - give me [node_5.05](sensor_nodes) [NO2](data_to_fetch)?
# - share the [node_5.25](sensor_nodes) [rsroratio9](data_to_fetch)?
# - tell me readings for [node_5.26](sensor_nodes) [rsroratio5](data_to_fetch)?
# - provide the [node_5.28](sensor_nodes) [o2per](data_to_fetch)?
# - please tell me [node_5.26](sensor_nodes) [NO2](data_to_fetch)?
# - can you provide [node_5.11](sensor_nodes) [airQualityValue](data_to_fetch)?
# - share the [node_5.21](sensor_nodes) [c2h5ch](data_to_fetch)?
# - give me [node_5.09](sensor_nodes) [rsroratio2](data_to_fetch)?
# - provide the [node_5.23](sensor_nodes) [lux](data_to_fetch)?
# - share the [node_5.19](sensor_nodes) [co_gas](data_to_fetch)?
# - share the [node_5.23](sensor_nodes) [c2h5ch](data_to_fetch)?
# - can you provide [node_5.25](sensor_nodes) [airQualityValue](data_to_fetch)?
# - tell me readings for [node_5.34](sensor_nodes) [memsvalue](data_to_fetch)?
# - give me [node_5.05](sensor_nodes) [rsroratio2](data_to_fetch)?
# - share the [node_5.27](sensor_nodes) [rsroratio2](data_to_fetch)?
# - tell me readings for [node_5.09](sensor_nodes) [co2value](data_to_fetch)?
# - what is the [node_5.22](sensor_nodes) [humidity](data_to_fetch)?
# - what is the [node_5.23](sensor_nodes) [VOC](data_to_fetch)?
# - what is the [node_5.16](sensor_nodes) [rsroratio2](data_to_fetch)?
# - share the [node_5.04](sensor_nodes) [hchoppmvalue](data_to_fetch)?
# - can you provide [node_5.11](sensor_nodes) [hchoppmvalue](data_to_fetch)?
# - give me [node_5.08](sensor_nodes) [airQualityValue](data_to_fetch)?
# - share the [node_5.16](sensor_nodes) [rsroratio3](data_to_fetch)?
# - tell me readings for [node_5.30](sensor_nodes) [o2per](data_to_fetch)?
# - provide the [node_5.34](sensor_nodes) [VOC](data_to_fetch)?
# - please tell me [node_5.26](sensor_nodes) [airQualityValue](data_to_fetch)?
# - give me [node_5.12](sensor_nodes) [lux](data_to_fetch)?
# - please tell me [node_5.14](sensor_nodes) [NO2](data_to_fetch)?
# - please tell me [node_5.13](sensor_nodes) [o2per](data_to_fetch)?
# - can you provide [node_5.16](sensor_nodes) [hchoppmvalue](data_to_fetch)?
# - please tell me [node_5.25](sensor_nodes) [VOC](data_to_fetch)?
# - tell me readings for [node_5.27](sensor_nodes) [o2per](data_to_fetch)?
# - provide the [node_5.05](sensor_nodes) [rsroratio3](data_to_fetch)?
# - please tell me [node_5.08](sensor_nodes) [co_gas](data_to_fetch)?
# - tell me readings for [node_5.04](sensor_nodes) [tempreture](data_to_fetch)?
# - what is the [node_5.10](sensor_nodes) [lux](data_to_fetch)?
# - what is the [node_5.30](sensor_nodes) [memsvalue](data_to_fetch)?
# - give me [node_5.10](sensor_nodes) [humidity](data_to_fetch)?
# - share the [node_5.04](sensor_nodes) [c2h5ch](data_to_fetch)?
# - please tell me [node_5.26](sensor_nodes) [lux](data_to_fetch)?
# - give me [node_5.30](sensor_nodes) [NO2](data_to_fetch)?
# - please tell me [node_5.27](sensor_nodes) [c2h5ch](data_to_fetch)?
# - give me [node_5.32](sensor_nodes) [PM10Atmospheric](data_to_fetch)?
# - can you provide [node_5.25](sensor_nodes) [lux](data_to_fetch)?
# - provide the [node_5.33](sensor_nodes) [rsroratio2](data_to_fetch)?
# - provide the [node_5.11](sensor_nodes) [VOC](data_to_fetch)?
# - what is the [node_5.03](sensor_nodes) [VOC](data_to_fetch)?
# - please tell me [node_5.03](sensor_nodes) [memsvalue](data_to_fetch)?
# - give me [node_5.20](sensor_nodes) [c2h5ch](data_to_fetch)?
# - can you provide [node_5.24](sensor_nodes) [memsvalue](data_to_fetch)?
# - what is the [node_5.22](sensor_nodes) [memsvalue](data_to_fetch)?
# - what is the [node_5.02](sensor_nodes) [tempreture](data_to_fetch)?
# - give me [node_5.34](sensor_nodes) [rsroratio2](data_to_fetch)?
# - please tell me [node_5.25](sensor_nodes) [memsvalue](data_to_fetch)?
# - tell me readings for [node_5.28](sensor_nodes) [memsvalue](data_to_fetch)?
# - give me [node_5.17](sensor_nodes) [lux](data_to_fetch)?
# - tell me readings for [node_5.18](sensor_nodes) [rsroratio3](data_to_fetch)?
# - give me [node_5.06](sensor_nodes) [airQualityValue](data_to_fetch)?
# - can you provide [node_5.29](sensor_nodes) [o2per](data_to_fetch)?
# - provide the [node_5.28](sensor_nodes) [rsroratio3](data_to_fetch)?
# - share the [node_5.14](sensor_nodes) [VOC](data_to_fetch)?
# - provide the [node_5.15](sensor_nodes) [rsroratio2](data_to_fetch)?
# - share the [node_5.06](sensor_nodes) [PM10Atmospheric](data_to_fetch)?
# - tell me readings for [node_5.01](sensor_nodes) [tempreture](data_to_fetch)?
# - what is the [node_5.25](sensor_nodes) [rsroratio3](data_to_fetch)?
# - provide the [node_5.28](sensor_nodes) [rsroratio9](data_to_fetch)?
# - tell me readings for [node_5.09](sensor_nodes) [rsroratio3](data_to_fetch)?
# - tell me readings for [node_5.18](sensor_nodes) [tempreture](data_to_fetch)?
# - give me [node_5.28](sensor_nodes) [tempreture](data_to_fetch)?
# - please tell me [node_5.16](sensor_nodes) [rsroratio9](data_to_fetch)?
# - give me [node_5.27](sensor_nodes) [co_gas](data_to_fetch)?
# - share the [node_5.08](sensor_nodes) [o2per](data_to_fetch)?
# - tell me readings for [node_5.28](sensor_nodes) [rsroratio5](data_to_fetch)?
# - what is the [node_5.17](sensor_nodes) [o2per](data_to_fetch)?
# - what is the [node_5.31](sensor_nodes) [memsvalue](data_to_fetch)?
# - tell me readings for [node_5.06](sensor_nodes) [NO2](data_to_fetch)?
# - what is the [node_5.22](sensor_nodes) [PM10Atmospheric](data_to_fetch)?
# - what is the [node_5.15](sensor_nodes) [PM10Atmospheric](data_to_fetch)?
# - give me [node_5.03](sensor_nodes) [rsroratio2](data_to_fetch)?
# - share the [node_5.04](sensor_nodes) [NO2](data_to_fetch)?
# - please tell me [node_5.02](sensor_nodes) [lux](data_to_fetch)?
# - what is the [node_5.21](sensor_nodes) [co2value](data_to_fetch)?
# - share the [node_5.14](sensor_nodes) [co2value](data_to_fetch)?
# - share the [node_5.27](sensor_nodes) [rsroratio9](data_to_fetch)?
# - please tell me [node_5.02](sensor_nodes) [co_gas](data_to_fetch)?
# - what is the [node_5.19](sensor_nodes) [co2value](data_to_fetch)?
# - can you provide [node_5.14](sensor_nodes) [lux](data_to_fetch)?
# - please tell me [node_5.13](sensor_nodes) [airQualityValue](data_to_fetch)?
# - tell me readings for [node_5.19](sensor_nodes) [VOC](data_to_fetch)?
# - tell me readings for [node_5.21](sensor_nodes) [rsroratio9](data_to_fetch)?
# - can you provide [node_5.32](sensor_nodes) [rsroratio3](data_to_fetch)?
# - please tell me [node_5.21](sensor_nodes) [lux](data_to_fetch)?
# - provide the [node_5.12](sensor_nodes) [c2h5ch](data_to_fetch)?
# - what is the [node_5.15](sensor_nodes) [humidity](data_to_fetch)?
# - what is the [node_5.21](sensor_nodes) [humidity](data_to_fetch)?
# - please tell me [node_5.14](sensor_nodes) [hchoppmvalue](data_to_fetch)?
# - share the [node_5.15](sensor_nodes) [rsroratio9](data_to_fetch)?
# - tell me readings for [node_5.26](sensor_nodes) [co2value](data_to_fetch)?
# - provide the [node_5.33](sensor_nodes) [rsroratio5](data_to_fetch)?
# - can you provide [node_5.12](sensor_nodes) [humidity](data_to_fetch)?
# - what is the [node_5.31](sensor_nodes) [co_gas](data_to_fetch)?
# - can you provide [node_5.31](sensor_nodes) [PM10Atmospheric](data_to_fetch)?
# - please tell me [node_5.33](sensor_nodes) [rsroratio9](data_to_fetch)?
# - provide the [node_5.16](sensor_nodes) [co_gas](data_to_fetch)?
# - give me [node_5.31](sensor_nodes) [rsroratio3](data_to_fetch)?
# - can you provide [node_5.01](sensor_nodes) [VOC](data_to_fetch)?
# - please tell me [node_5.02](sensor_nodes) [rsroratio5](data_to_fetch)?
# - tell me readings for [node_5.21](sensor_nodes) [rsroratio5](data_to_fetch)?
# - can you provide [node_5.12](sensor_nodes) [memsvalue](data_to_fetch)?
# - share the [node_5.16](sensor_nodes) [PM10Atmospheric](data_to_fetch)?
# - can you provide [node_5.34](sensor_nodes) [o2per](data_to_fetch)?
# - what is the [node_5.01](sensor_nodes) [o2per](data_to_fetch)?
# - provide the [node_5.29](sensor_nodes) [rsroratio9](data_to_fetch)?
# - can you provide [node_5.21](sensor_nodes) [co_gas](data_to_fetch)?
# - share the [node_5.09](sensor_nodes) [co_gas](data_to_fetch)?
# - give me [node_5.28](sensor_nodes) [co_gas](data_to_fetch)?
# - give me [node_5.09](sensor_nodes) [NO2](data_to_fetch)?
# - give me [node_5.11](sensor_nodes) [rsroratio3](data_to_fetch)?
# - tell me readings for [node_5.02](sensor_nodes) [humidity](data_to_fetch)?
# - can you provide [node_5.05](sensor_nodes) [hchoppmvalue](data_to_fetch)?
# - can you provide [node_5.29](sensor_nodes) [NO2](data_to_fetch)?
# - please tell me [node_5.27](sensor_nodes) [humidity](data_to_fetch)?
# - what is the [node_5.04](sensor_nodes) [airQualityValue](data_to_fetch)?
# - tell me readings for [node_5.13](sensor_nodes) [co2value](data_to_fetch)?
# - give me [node_5.14](sensor_nodes) [humidity](data_to_fetch)?
# - provide the [node_5.14](sensor_nodes) [c2h5ch](data_to_fetch)?
# - can you provide [node_5.10](sensor_nodes) [rsroratio3](data_to_fetch)?
# - please tell me [node_5.24](sensor_nodes) [airQualityValue](data_to_fetch)?
# - please tell me [node_5.27](sensor_nodes) [co2value](data_to_fetch)?
# - tell me readings for [node_5.27](sensor_nodes) [rsroratio3](data_to_fetch)?
# - can you provide [node_5.14](sensor_nodes) [rsroratio2](data_to_fetch)?
# - what is the [node_5.23](sensor_nodes) [humidity](data_to_fetch)?
# - please tell me [node_5.32](sensor_nodes) [hchoppmvalue](data_to_fetch)?
# - please tell me [node_5.18](sensor_nodes) [rsroratio2](data_to_fetch)?
# - tell me readings for [node_5.26](sensor_nodes) [hchoppmvalue](data_to_fetch)?
# - what is the [node_5.34](sensor_nodes) [co2value](data_to_fetch)?
# - share the [node_5.08](sensor_nodes) [c2h5ch](data_to_fetch)?
# - provide the [node_5.16](sensor_nodes) [tempreture](data_to_fetch)?
# - give me [node_5.10](sensor_nodes) [o2per](data_to_fetch)?
# - please tell me [node_5.18](sensor_nodes) [c2h5ch](data_to_fetch)?
# - please tell me [node_5.27](sensor_nodes) [lux](data_to_fetch)?
# - tell me readings for [node_5.13](sensor_nodes) [rsroratio3](data_to_fetch)?
# - please tell me [node_5.24](sensor_nodes) [NO2](data_to_fetch)?
# - what is the [node_5.34](sensor_nodes) [rsroratio9](data_to_fetch)?
# - tell me readings for [node_5.31](sensor_nodes) [lux](data_to_fetch)?
# - what is the [node_5.10](sensor_nodes) [c2h5ch](data_to_fetch)?
# - give me [node_5.10](sensor_nodes) [rsroratio5](data_to_fetch)?
# - provide the [node_5.32](sensor_nodes) [o2per](data_to_fetch)?
# - what is the [node_5.01](sensor_nodes) [c2h5ch](data_to_fetch)?
# - provide the [node_5.16](sensor_nodes) [c2h5ch](data_to_fetch)?
# - provide the [node_5.17](sensor_nodes) [rsroratio2](data_to_fetch)?
# - share the [node_5.24](sensor_nodes) [lux](data_to_fetch)?
# - please tell me [node_5.01](sensor_nodes) [rsroratio3](data_to_fetch)?
# - provide the [node_5.02](sensor_nodes) [airQualityValue](data_to_fetch)?
# - please tell me [node_5.30](sensor_nodes) [co_gas](data_to_fetch)?
# - give me [node_5.33](sensor_nodes) [lux](data_to_fetch)?
# - give me [node_5.12](sensor_nodes) [rsroratio3](data_to_fetch)?
# - please tell me [node_5.09](sensor_nodes) [lux](data_to_fetch)?
# - please tell me [node_5.25](sensor_nodes) [tempreture](data_to_fetch)?
# - can you provide [node_5.33](sensor_nodes) [memsvalue](data_to_fetch)?
# - provide the [node_5.04](sensor_nodes) [rsroratio2](data_to_fetch)?
# - can you provide [node_5.19](sensor_nodes) [humidity](data_to_fetch)?
# - can you provide [node_5.05](sensor_nodes) [VOC](data_to_fetch)?
# - share the [node_5.06](sensor_nodes) [hchoppmvalue](data_to_fetch)?
# - provide the [node_5.02](sensor_nodes) [rsroratio9](data_to_fetch)?
# - tell me readings for [node_5.17](sensor_nodes) [airQualityValue](data_to_fetch)?
# - give me [node_5.12](sensor_nodes) [o2per](data_to_fetch)?
# - please tell me [node_5.31](sensor_nodes) [co2value](data_to_fetch)?
# - tell me readings for [node_5.15](sensor_nodes) [hchoppmvalue](data_to_fetch)?
# - can you provide [node_5.05](sensor_nodes) [co_gas](data_to_fetch)?
# - share the [node_5.15](sensor_nodes) [lux](data_to_fetch)?
# - please tell me [node_5.19](sensor_nodes) [memsvalue](data_to_fetch)?
# - what is the [node_5.19](sensor_nodes) [tempreture](data_to_fetch)?
# - tell me readings for [node_5.22](sensor_nodes) [co_gas](data_to_fetch)?
# - provide the [node_5.10](sensor_nodes) [rsroratio9](data_to_fetch)?
# - share the [node_5.19](sensor_nodes) [lux](data_to_fetch)?
# - provide the [node_5.21](sensor_nodes) [tempreture](data_to_fetch)?
# - what is the [node_5.08](sensor_nodes) [rsroratio2](data_to_fetch)?
# - share the [node_5.22](sensor_nodes) [rsroratio3](data_to_fetch)?
# - can you provide [node_5.21](sensor_nodes) [o2per](data_to_fetch)?
# - please tell me [node_5.09](sensor_nodes) [VOC](data_to_fetch)?
# - tell me readings for [node_5.17](sensor_nodes) [rsroratio5](data_to_fetch)?
# - what is the [node_5.13](sensor_nodes) [tempreture](data_to_fetch)?
# - give me [node_5.16](sensor_nodes) [o2per](data_to_fetch)?
# - tell me readings for [node_5.01](sensor_nodes) [hchoppmvalue](data_to_fetch)?
# - share the [node_5.01](sensor_nodes) [PM10Atmospheric](data_to_fetch)?
# - please tell me [node_5.01](sensor_nodes) [co2value](data_to_fetch)?
# - tell me readings for [node_5.25](sensor_nodes) [o2per](data_to_fetch)?
# - can you provide [node_5.12](sensor_nodes) [PM10Atmospheric](data_to_fetch)?
# - what is the [node_5.01](sensor_nodes) [lux](data_to_fetch)?
# - tell me readings for [node_5.01](sensor_nodes) [rsroratio5](data_to_fetch)?
# - what is the [node_5.02](sensor_nodes) [VOC](data_to_fetch)?
# - tell me readings for [node_5.14](sensor_nodes) [airQualityValue](data_to_fetch)?
# - provide the [node_5.31](sensor_nodes) [humidity](data_to_fetch)?
# - what is the [node_5.32](sensor_nodes) [NO2](data_to_fetch)?
# - tell me readings for [node_5.12](sensor_nodes) [co2value](data_to_fetch)?
# - what is the [node_5.12](sensor_nodes) [tempreture](data_to_fetch)?
# - provide the [node_5.09](sensor_nodes) [airQualityValue](data_to_fetch)?
# - provide the [node_5.22](sensor_nodes) [rsroratio5](data_to_fetch)?
# - please tell me [node_5.14](sensor_nodes) [rsroratio9](data_to_fetch)?
# - tell me readings for [node_5.07](sensor_nodes) [rsroratio3](data_to_fetch)?
# - give me [node_5.20](sensor_nodes) [lux](data_to_fetch)?
# - tell me readings for [node_5.29](sensor_nodes) [memsvalue](data_to_fetch)?
# - give me [node_5.13](sensor_nodes) [memsvalue](data_to_fetch)?
# - tell me readings for [node_5.23](sensor_nodes) [memsvalue](data_to_fetch)?
# - tell me readings for [node_5.10](sensor_nodes) [memsvalue](data_to_fetch)?
# - give me [node_5.11](sensor_nodes) [o2per](data_to_fetch)?
# - provide the [node_5.21](sensor_nodes) [hchoppmvalue](data_to_fetch)?
# - please tell me [node_5.16](sensor_nodes) [airQualityValue](data_to_fetch)?
# - give me [node_5.31](sensor_nodes) [hchoppmvalue](data_to_fetch)?
# - share the [node_5.29](sensor_nodes) [co2value](data_to_fetch)?
# - tell me readings for [node_5.27](sensor_nodes) [hchoppmvalue](data_to_fetch)?
# - please tell me [node_5.30](sensor_nodes) [tempreture](data_to_fetch)?
# - share the [node_5.10](sensor_nodes) [NO2](data_to_fetch)?
# - what is the [node_5.13](sensor_nodes) [NO2](data_to_fetch)?
# - what is the [node_5.07](sensor_nodes) [airQualityValue](data_to_fetch)?
# - what is the [node_5.22](sensor_nodes) [VOC](data_to_fetch)?
# - share the [node_5.03](sensor_nodes) [co_gas](data_to_fetch)?
# - can you provide [node_5.05](sensor_nodes) [PM10Atmospheric](data_to_fetch)?
# - share the [node_5.30](sensor_nodes) [humidity](data_to_fetch)?
# - what is the [node_5.08](sensor_nodes) [rsroratio9](data_to_fetch)?
# - share the [node_5.21](sensor_nodes) [PM10Atmospheric](data_to_fetch)?
# - share the [node_5.33](sensor_nodes) [hchoppmvalue](data_to_fetch)?
# - please tell me [node_5.17](sensor_nodes) [tempreture](data_to_fetch)?
# - give me [node_5.16](sensor_nodes) [humidity](data_to_fetch)?
# - what is the [node_5.26](sensor_nodes) [rsroratio2](data_to_fetch)?
# - what is the [node_5.24](sensor_nodes) [co_gas](data_to_fetch)?
# - tell me readings for [node_5.14](sensor_nodes) [tempreture](data_to_fetch)?
# - tell me readings for [node_5.28](sensor_nodes) [co2value](data_to_fetch)?
# - please tell me [node_5.10](sensor_nodes) [PM10Atmospheric](data_to_fetch)?
# - please tell me [node_5.04](sensor_nodes) [lux](data_to_fetch)?
# - tell me readings for [node_5.32](sensor_nodes) [co_gas](data_to_fetch)?
# - can you provide [node_5.11](sensor_nodes) [co2value](data_to_fetch)?
# - can you provide [node_5.23](sensor_nodes) [tempreture](data_to_fetch)?
# - what is the [node_5.17](sensor_nodes) [co_gas](data_to_fetch)?
# - give me [node_5.20](sensor_nodes) [airQualityValue](data_to_fetch)?
# - please tell me [node_5.05](sensor_nodes) [humidity](data_to_fetch)?
# - provide the [node_5.09](sensor_nodes) [PM10Atmospheric](data_to_fetch)?
# - tell me readings for [node_5.02](sensor_nodes) [c2h5ch](data_to_fetch)?
# - what is the [node_5.19](sensor_nodes) [airQualityValue](data_to_fetch)?
# - share the [node_5.03](sensor_nodes) [rsroratio9](data_to_fetch)?
# - what is the [node_5.17](sensor_nodes) [PM10Atmospheric](data_to_fetch)?
# - please tell me [node_5.14](sensor_nodes) [o2per](data_to_fetch)?
# - can you provide [node_5.24](sensor_nodes) [hchoppmvalue](data_to_fetch)?
# - what is the [node_5.19](sensor_nodes) [rsroratio3](data_to_fetch)?
# - can you provide [node_5.10](sensor_nodes) [VOC](data_to_fetch)?
# - tell me readings for [node_5.24](sensor_nodes) [PM10Atmospheric](data_to_fetch)?
# - share the [node_5.33](sensor_nodes) [co_gas](data_to_fetch)?
# - can you provide [node_5.19](sensor_nodes) [rsroratio2](data_to_fetch)?
# - what is the [node_5.28](sensor_nodes) [humidity](data_to_fetch)?
# - share the [node_5.06](sensor_nodes) [co_gas](data_to_fetch)?
# - give me [node_5.06](sensor_nodes) [o2per](data_to_fetch)?
# - can you provide [node_5.33](sensor_nodes) [o2per](data_to_fetch)?
# - give me [node_5.26](sensor_nodes) [rsroratio9](data_to_fetch)?
# - give me [node_5.19](sensor_nodes) [o2per](data_to_fetch)?
# - what is the [node_5.11](sensor_nodes) [humidity](data_to_fetch)?
# - please tell me [node_5.06](sensor_nodes) [rsroratio5](data_to_fetch)?
# - please tell me [node_5.18](sensor_nodes) [VOC](data_to_fetch)?
# - can you provide [node_5.02](sensor_nodes) [co2value](data_to_fetch)?
# - please tell me [node_5.03](sensor_nodes) [lux](data_to_fetch)?
# - please tell me [node_5.23](sensor_nodes) [rsroratio2](data_to_fetch)?
# - please tell me [node_5.25](sensor_nodes) [humidity](data_to_fetch)?
# - give me [node_5.03](sensor_nodes) [tempreture](data_to_fetch)?
# - provide the [node_5.04](sensor_nodes) [PM10Atmospheric](data_to_fetch)?
# - tell me readings for [node_5.20](sensor_nodes) [memsvalue](data_to_fetch)?
# - please tell me [node_5.10](sensor_nodes) [co_gas](data_to_fetch)?
# - share the [node_5.22](sensor_nodes) [rsroratio9](data_to_fetch)?
# - can you provide [node_5.34](sensor_nodes) [humidity](data_to_fetch)?
# - tell me readings for [node_5.06](sensor_nodes) [co2value](data_to_fetch)?
# - give me [node_5.21](sensor_nodes) [rsroratio3](data_to_fetch)?
# - give me [node_5.26](sensor_nodes) [memsvalue](data_to_fetch)?
# - what is the [node_5.07](sensor_nodes) [hchoppmvalue](data_to_fetch)?
# - share the [node_5.22](sensor_nodes) [NO2](data_to_fetch)?
# - can you provide [node_5.23](sensor_nodes) [rsroratio9](data_to_fetch)?
# - what is the [node_5.24](sensor_nodes) [o2per](data_to_fetch)?
# - please tell me [node_5.17](sensor_nodes) [hchoppmvalue](data_to_fetch)?
# - give me [node_5.09](sensor_nodes) [o2per](data_to_fetch)?
# - please tell me [node_5.06](sensor_nodes) [humidity](data_to_fetch)?
# - provide the [node_5.15](sensor_nodes) [rsroratio3](data_to_fetch)?
# - provide the [node_5.04](sensor_nodes) [rsroratio9](data_to_fetch)?
# - give me [node_5.09](sensor_nodes) [humidity](data_to_fetch)?
# - share the [node_5.34](sensor_nodes) [lux](data_to_fetch)?
# - can you provide [node_5.30](sensor_nodes) [hchoppmvalue](data_to_fetch)?
# - what is the [node_5.25](sensor_nodes) [rsroratio5](data_to_fetch)?
# - please tell me [node_5.09](sensor_nodes) [rsroratio5](data_to_fetch)?
# - can you provide [node_5.15](sensor_nodes) [airQualityValue](data_to_fetch)?
# - provide the [node_5.16](sensor_nodes) [VOC](data_to_fetch)?
# - what is the [node_5.27](sensor_nodes) [VOC](data_to_fetch)?
# - give me [node_5.02](sensor_nodes) [o2per](data_to_fetch)?
# - share the [node_5.13](sensor_nodes) [VOC](data_to_fetch)?
# - share the [node_5.13](sensor_nodes) [hchoppmvalue](data_to_fetch)?
# - share the [node_5.31](sensor_nodes) [rsroratio5](data_to_fetch)?
# - provide the [node_5.20](sensor_nodes) [o2per](data_to_fetch)?
# - provide the [node_5.22](sensor_nodes) [o2per](data_to_fetch)?
# - tell me readings for [node_5.11](sensor_nodes) [NO2](data_to_fetch)?
# - give me [node_5.07](sensor_nodes) [tempreture](data_to_fetch)?
# - tell me readings for [node_5.18](sensor_nodes) [NO2](data_to_fetch)?
# - please tell me [node_5.23](sensor_nodes) [co2value](data_to_fetch)?
# - can you provide [node_5.04](sensor_nodes) [o2per](data_to_fetch)?
# - please tell me [node_5.04](sensor_nodes) [co2value](data_to_fetch)?
# - give me [node_5.05](sensor_nodes) [co2value](data_to_fetch)?
# - what is the [node_5.04](sensor_nodes) [co_gas](data_to_fetch)?
# - share the [node_5.06](sensor_nodes) [lux](data_to_fetch)?
# - tell me readings for [node_5.27](sensor_nodes) [NO2](data_to_fetch)?
# - what is the [node_5.01](sensor_nodes) [airQualityValue](data_to_fetch)?
# - can you provide [node_5.14](sensor_nodes) [rsroratio5](data_to_fetch)?
# - provide the [node_5.03](sensor_nodes) [co2value](data_to_fetch)?
# - tell me readings for [node_5.32](sensor_nodes) [airQualityValue](data_to_fetch)?
# - tell me readings for [node_5.13](sensor_nodes) [co_gas](data_to_fetch)?
# - can you provide [node_5.32](sensor_nodes) [c2h5ch](data_to_fetch)?
# - what is the [node_5.07](sensor_nodes) [o2per](data_to_fetch)?
# - please tell me [node_5.18](sensor_nodes) [co_gas](data_to_fetch)?
# - please tell me [node_5.04](sensor_nodes) [humidity](data_to_fetch)?
# - share the [node_5.10](sensor_nodes) [co2value](data_to_fetch)?
# - give me [node_5.13](sensor_nodes) [rsroratio9](data_to_fetch)?
# - share the [node_5.03](sensor_nodes) [humidity](data_to_fetch)?
# - please tell me [node_5.16](sensor_nodes) [co2value](data_to_fetch)?
