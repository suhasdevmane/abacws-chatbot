# %% [markdown]
# A] Get from Postgress

# %%
import requests

url = "https://thingsboard.cs.cf.ac.uk/api/auth/login"
headers = {"Content-Type": "application/json"}

payload = {
    "username": "SuhasAbacwsLivingLab@cardiff.ac.uk",
    "password": "SuhasDevmane"
}

response = requests.post(url, json=payload, headers=headers)

if response.status_code == 200:
    # Authentication successful
    token = response.json().get("token")
    print("JWT_Token:", token)
else:
    print("Authentication failed. Status Code:", response.status_code)
    print("Response:", response.text)
# Out:
# JWT_Token: eyJhbGciOiJIUzUxMiJ9.....1XphsGNHpDWj9kuXb_cT4nxTLPEmRz1YLiR7i7QIA2jI6aw66aIm7J_OIu8d4PmopYO-WqAqOBSeAx2CBxwdfw

# %%
import requests
import json

device_id = 'f57a1560-7cf3-11ee-94bc-d389020903a3'
access_token = token  
keys_to_fetch = [
    "UV_light", "Loudness", "PM1.0Atmospheric", "PM2.5Atmospheric", "PM10Atmospheric", 
    "PIR_Status", "tVOC_Concentration", "CO2eq_Concentration", "MQ2_sensor_voltage", 
    "MQ2_Rs_ratio", "MQ2_Rs/R0_Ratio", "MQ3_sensor_voltage", "MQ3_Rs_ratio", 
    "MQ3_Rs/R0_Ratio", "HCHO_ppm", "Air_Quality", "Light_value", "Visible_light", 
    "IR_light", "MQ5_sensor_voltage", "MQ5_Rs_ratio", "MQ5_Rs/R0_Ratio", 
    "MQ9_sensor_voltage", "MQ9_Rs_ratio", "MQ9_Rs/R0_Ratio", "O2_22.10_N2_gas", 
    "C2H5CH_gas", "VOC_gas", "CO_gas", "Co2", "Temperature", "Humidity", "Luminance"
]
url = f"https://thingsboard.cs.cf.ac.uk/api/plugins/telemetry/DEVICE/{device_id}/values/timeseries?keys={','.join(keys_to_fetch)}"

headers = {
    'Content-Type': 'application/json',
    'X-Authorization': f'Bearer {access_token}'
}

response = requests.get(url, headers=headers)

if response.status_code == 200:
    data = response.json()
    print("Received data:")
    print(json.dumps(data, indent=2))
else:
    print(f"Failed to get data. Status Code: {response.status_code}")
    print(response.text)
# Out:
# Received data:
# {
#   "UV_light": [
#     {
#       "ts": 1699405164422,
#       "value": "0.1"
#     }
#   ],
#   "Loudness": [
#     {
#       "ts": 1699405164422,
#       "value": "341"
#     }
#   ],
#   "PM1.0Atmospheric": [
#     {
#       "ts": 1699405164422,
#       "value": "9"
#     }
#   ],
#   "PM2.5Atmospheric": [
#     {
#       "ts": 1699405164422,
#       "value": "12"
#     }
#   ],
#   "PM10Atmospheric": [
#     {
#       "ts": 1699405164422,
#       "value": "14"
#     }
#   ],
#   "PIR_Status": [
#     {
#       "ts": 1699405164422,
#       "value": "No Motion Detected"
#     }
#   ],
#   "tVOC_Concentration": [
#     {
#       "ts": 1699405164422,
#       "value": "20"
#     }
#   ],
#   "CO2eq_Concentration": [
#     {
#       "ts": 1699405164422,
#       "value": "408"
#     }
#   ],
#   "MQ2_sensor_voltage": [
#     {
#       "ts": 1699405164422,
#       "value": "0.32"
#     }
#   ],
#   "MQ2_Rs_ratio": [
#     {
#       "ts": 1699405164422,
#       "value": "15.15"
#     }
#   ],
#   "MQ2_Rs/R0_Ratio": [
#     {
#       "ts": 1699405164422,
#       "value": "158.87"
#     }
#   ],
#   "MQ3_sensor_voltage": [
#     {
#       "ts": 1699405164422,
#       "value": "0.35"
#     }
#   ],
#   "MQ3_Rs_ratio": [
#     {
#       "ts": 1699405164422,
#       "value": "15.99"
#     }
#   ],
#   "MQ3_Rs/R0_Ratio": [
#     {
#       "ts": 1699405164422,
#       "value": "753.97"
#     }
#   ],
#   "HCHO_ppm": [
#     {
#       "ts": 1699405164422,
#       "value": "0.01"
#     }
#   ],
#   "Air_Quality": [
#     {
#       "ts": 1699405164422,
#       "value": "Fresh air"
#     }
#   ],
#   "Light_value": [
#     {
#       "ts": 1699405164422,
#       "value": "170"
#     }
#   ],
#   "Visible_light": [
#     {
#       "ts": 1699405164422,
#       "value": "264"
#     }
#   ],
#   "IR_light": [
#     {
#       "ts": 1699405164422,
#       "value": "270"
#     }
#   ],
#   "MQ5_sensor_voltage": [
#     {
#       "ts": 1699405164422,
#       "value": "0.7"
#     }
#   ],
#   "MQ5_Rs_ratio": [
#     {
#       "ts": 1699405164422,
#       "value": "6.09"
#     }
#   ],
#   "MQ5_Rs/R0_Ratio": [
#     {
#       "ts": 1699405164422,
#       "value": "41.5"
#     }
#   ],
#   "MQ9_sensor_voltage": [
#     {
#       "ts": 1699405164422,
#       "value": "0.36"
#     }
#   ],
#   "MQ9_Rs_ratio": [
#     {
#       "ts": 1699405164422,
#       "value": "12.83"
#     }
#   ],
#   "MQ9_Rs/R0_Ratio": [
#     {
#       "ts": 1699405164422,
#       "value": "83.93"
#     }
#   ],
#   "O2_22.10_N2_gas": [
#     {
#       "ts": 1699405164422,
#       "value": "193"
#     }
#   ],
#   "C2H5CH_gas": [
#     {
#       "ts": 1699405164422,
#       "value": "290"
#     }
#   ],
#   "VOC_gas": [
#     {
#       "ts": 1699405164422,
#       "value": "249"
#     }
#   ],
#   "CO_gas": [
#     {
#       "ts": 1699405164422,
#       "value": "176"
#     }
#   ],
#   "Co2": [
#     {
#       "ts": 1699405164422,
#       "value": "601"
#     }
#   ],
#   "Temperature": [
#     {
#       "ts": 1699405164422,
#       "value": "31.73"
#     }
#   ],
#   "Humidity": [
#     {
#       "ts": 1699405164422,
#       "value": "17.74"
#     }
#   ],
#   "Luminance": [
#     {
#       "ts": 1699405164422,
#       "value": "31.89"
#     }
#   ]
# }

# %% [markdown]
# # Add units to received data

# %%
import requests
import json

device_id = 'f57a1560-7cf3-11ee-94bc-d389020903a3'
access_token = token  
keys_to_fetch = [
    "UV_light", "Loudness", "PM1.0Atmospheric", "PM2.5Atmospheric", "PM10Atmospheric", 
    "PIR_Status", "tVOC_Concentration", "CO2eq_Concentration", "MQ2_sensor_voltage", 
    "MQ2_Rs_ratio", "MQ2_Rs/R0_Ratio", "MQ3_sensor_voltage", "MQ3_Rs_ratio", 
    "MQ3_Rs/R0_Ratio", "HCHO_ppm", "Air_Quality", "Light_value", "Visible_light", 
    "IR_light", "MQ5_sensor_voltage", "MQ5_Rs_ratio", "MQ5_Rs/R0_Ratio", 
    "MQ9_sensor_voltage", "MQ9_Rs_ratio", "MQ9_Rs/R0_Ratio", "O2_22.10_N2_gas", 
    "C2H5CH_gas", "VOC_gas", "CO_gas", "Co2", "Temperature", "Humidity", "Luminance"
]

units = {
    "UV_light": "UV Index",
    "Loudness": "dB",
    "PM1.0Atmospheric": "µg/m³",
    "PM2.5Atmospheric": "µg/m³",
    "PM10Atmospheric": "µg/m³",
    "PIR_Status": "",  # Assuming it's a status indicator with no specific unit
    "tVOC_Concentration": "ppb",
    "CO2eq_Concentration": "ppm",
    "MQ2_sensor_voltage": "Volts",
    "MQ2_Rs_ratio": "",
    "MQ2_Rs/R0_Ratio": "",
    "MQ3_sensor_voltage": "Volts",
    "MQ3_Rs_ratio": "",
    "MQ3_Rs/R0_Ratio": "",
    "HCHO_ppm": "ppm",
    "Air_Quality": "",  # Assuming it's a qualitative measure with no specific unit
    "Light_value": "Lux",
    "Visible_light": "Lux",
    "IR_light": "Lux",
    "MQ5_sensor_voltage": "Volts",
    "MQ5_Rs_ratio": "",
    "MQ5_Rs/R0_Ratio": "",
    "MQ9_sensor_voltage": "Volts",
    "MQ9_Rs_ratio": "",
    "MQ9_Rs/R0_Ratio": "",
    "O2_22.10_N2_gas": "",  # Assuming it's a gas measurement with no specific unit
    "C2H5CH_gas": "",  # Assuming it's a gas measurement with no specific unit
    "VOC_gas": "",  # Assuming it's a gas measurement with no specific unit
    "CO_gas": "",  # Assuming it's a gas measurement with no specific unit
    "Co2": "",  # Assuming it's a gas measurement with no specific unit
    "Temperature": "°C",
    "Humidity": "%",
    "Luminance": "cd/m²"
}

url = f"https://thingsboard.cs.cf.ac.uk/api/plugins/telemetry/DEVICE/{device_id}/values/timeseries?keys={','.join(keys_to_fetch)}"

headers = {
    'Content-Type': 'application/json',
    'X-Authorization': f'Bearer {access_token}'
}
response = requests.get(url, headers=headers)

if response.status_code == 200:
    data = response.json()
    
    # Add units to the values
    for key in data:
        if key in units:
            for entry in data[key]:
                entry["unit"] = units[key]
    
    print("Received data:")
    print(json.dumps(data, indent=2))
else:
    print(f"Failed to get data. Status Code: {response.status_code}")
    print(response.text)
# Out:
# Received data:
# {
#   "UV_light": [
#     {
#       "ts": 1699405171360,
#       "value": "0.09",
#       "unit": "UV Index"
#     }
#   ],
#   "Loudness": [
#     {
#       "ts": 1699405171360,
#       "value": "394",
#       "unit": "dB"
#     }
#   ],
#   "PM1.0Atmospheric": [
#     {
#       "ts": 1699405171360,
#       "value": "10",
#       "unit": "\u00b5g/m\u00b3"
#     }
#   ],
#   "PM2.5Atmospheric": [
#     {
#       "ts": 1699405171360,
#       "value": "14",
#       "unit": "\u00b5g/m\u00b3"
#     }
#   ],
#   "PM10Atmospheric": [
#     {
#       "ts": 1699405171360,
#       "value": "13",
#       "unit": "\u00b5g/m\u00b3"
#     }
#   ],
#   "PIR_Status": [
#     {
#       "ts": 1699405171360,
#       "value": "No Motion Detected",
#       "unit": ""
#     }
#   ],
#   "tVOC_Concentration": [
#     {
#       "ts": 1699405171360,
#       "value": "19",
#       "unit": "ppb"
#     }
#   ],
#   "CO2eq_Concentration": [
#     {
#       "ts": 1699405171360,
#       "value": "392",
#       "unit": "ppm"
#     }
#   ],
#   "MQ2_sensor_voltage": [
#     {
#       "ts": 1699405171360,
#       "value": "0.31",
#       "unit": "Volts"
#     }
#   ],
#   "MQ2_Rs_ratio": [
#     {
#       "ts": 1699405171360,
#       "value": "15.25",
#       "unit": ""
#     }
#   ],
#   "MQ2_Rs/R0_Ratio": [
#     {
#       "ts": 1699405171360,
#       "value": "159.17",
#       "unit": ""
#     }
#   ],
#   "MQ3_sensor_voltage": [
#     {
#       "ts": 1699405171360,
#       "value": "0.33",
#       "unit": "Volts"
#     }
#   ],
#   "MQ3_Rs_ratio": [
#     {
#       "ts": 1699405171360,
#       "value": "15.04",
#       "unit": ""
#     }
#   ],
#   "MQ3_Rs/R0_Ratio": [
#     {
#       "ts": 1699405171360,
#       "value": "765.08",
#       "unit": ""
#     }
#   ],
#   "HCHO_ppm": [
#     {
#       "ts": 1699405171360,
#       "value": "0.01",
#       "unit": "ppm"
#     }
#   ],
#   "Air_Quality": [
#     {
#       "ts": 1699405171360,
#       "value": "Fresh air",
#       "unit": ""
#     }
#   ],
#   "Light_value": [
#     {
#       "ts": 1699405171360,
#       "value": "175",
#       "unit": "Lux"
#     }
#   ],
#   "Visible_light": [
#     {
#       "ts": 1699405171360,
#       "value": "262",
#       "unit": "Lux"
#     }
#   ],
#   "IR_light": [
#     {
#       "ts": 1699405171360,
#       "value": "277",
#       "unit": "Lux"
#     }
#   ],
#   "MQ5_sensor_voltage": [
#     {
#       "ts": 1699405171360,
#       "value": "0.66",
#       "unit": "Volts"
#     }
#   ],
#   "MQ5_Rs_ratio": [
#     {
#       "ts": 1699405171360,
#       "value": "5.98",
#       "unit": ""
#     }
#   ],
#   "MQ5_Rs/R0_Ratio": [
#     {
#       "ts": 1699405171360,
#       "value": "40.88",
#       "unit": ""
#     }
#   ],
#   "MQ9_sensor_voltage": [
#     {
#       "ts": 1699405171360,
#       "value": "0.36",
#       "unit": "Volts"
#     }
#   ],
#   "MQ9_Rs_ratio": [
#     {
#       "ts": 1699405171360,
#       "value": "12.46",
#       "unit": ""
#     }
#   ],
#   "MQ9_Rs/R0_Ratio": [
#     {
#       "ts": 1699405171360,
#       "value": "82.97",
#       "unit": ""
#     }
#   ],
#   "O2_22.10_N2_gas": [
#     {
#       "ts": 1699405171360,
#       "value": "195",
#       "unit": ""
#     }
#   ],
#   "C2H5CH_gas": [
#     {
#       "ts": 1699405171360,
#       "value": "288",
#       "unit": ""
#     }
#   ],
#   "VOC_gas": [
#     {
#       "ts": 1699405171360,
#       "value": "246",
#       "unit": ""
#     }
#   ],
#   "CO_gas": [
#     {
#       "ts": 1699405171360,
#       "value": "179",
#       "unit": ""
#     }
#   ],
#   "Co2": [
#     {
#       "ts": 1699405171360,
#       "value": "601",
#       "unit": ""
#     }
#   ],
#   "Temperature": [
#     {
#       "ts": 1699405171360,
#       "value": "31.17",
#       "unit": "\u00b0C"
#     }
#   ],
#   "Humidity": [
#     {
#       "ts": 1699405171360,
#       "value": "17.61",
#       "unit": "%"
#     }
#   ],
#   "Luminance": [
#     {
#       "ts": 1699405171360,
#       "value": "30.35",
#       "unit": "cd/m\u00b2"
#     }
#   ]
# }

# %% [markdown]
# # trial code

# %%
import requests
import json
last_ts = None
url0 = "https://thingsboard.cs.cf.ac.uk/api/auth/login"
headers = {"Content-Type": "application/json"}

payload = {
    "username": "SuhasAbacwsLivingLab@cardiff.ac.uk",
    "password": "SuhasDevmane"
}

response = requests.post(url0, json=payload, headers=headers)

if response.status_code == 200:
    # Authentication successful
    token = response.json().get("token")
    print("JWT_Token:", token)
else:
    print("Authentication failed. Status Code:", response.status_code)
    print("Response:", response.text)

device_id = 'f57a1560-7cf3-11ee-94bc-d389020903a3'
node_name = "node_5.14"

last_ts = None
access_token = token  
keys_to_fetch = [
    "UV_light", "Loudness", "PM1.0Atmospheric", "PM2.5Atmospheric", "PM10Atmospheric", 
    "PIR_Status", "tVOC_Concentration", "CO2eq_Concentration", "MQ2_sensor_voltage", 
    "MQ2_Rs_ratio", "MQ2_Rs/R0_Ratio", "MQ3_sensor_voltage", "MQ3_Rs_ratio", 
    "MQ3_Rs/R0_Ratio", "HCHO_ppm", "Air_Quality", "Light_value", "Visible_light", 
    "IR_light", "MQ5_sensor_voltage", "MQ5_Rs_ratio", "MQ5_Rs/R0_Ratio", 
    "MQ9_sensor_voltage", "MQ9_Rs_ratio", "MQ9_Rs/R0_Ratio", "O2_22.10_N2_gas", 
    "C2H5CH_gas", "VOC_gas", "CO_gas", "Co2", "Temperature", "Humidity", "Luminance"
]

units = {
    "UV_light": "UV Index",
    "Loudness": "dB",
    "PM1.0Atmospheric": "µg/m³",
    "PM2.5Atmospheric": "µg/m³",
    "PM10Atmospheric": "µg/m³",
    "PIR_Status": "",  # Assuming it's a status indicator with no specific unit
    "tVOC_Concentration": "ppb",
    "CO2eq_Concentration": "ppm",
    "MQ2_sensor_voltage": "Volts",
    "MQ2_Rs_ratio": "",
    "MQ2_Rs/R0_Ratio": "",
    "MQ3_sensor_voltage": "Volts",
    "MQ3_Rs_ratio": "",
    "MQ3_Rs/R0_Ratio": "",
    "HCHO_ppm": "ppm",
    "Air_Quality": "",  # Assuming it's a qualitative measure with no specific unit
    "Light_value": "Lux",
    "Visible_light": "Lux",
    "IR_light": "Lux",
    "MQ5_sensor_voltage": "Volts",
    "MQ5_Rs_ratio": "",
    "MQ5_Rs/R0_Ratio": "",
    "MQ9_sensor_voltage": "Volts",
    "MQ9_Rs_ratio": "",
    "MQ9_Rs/R0_Ratio": "",
    "O2_22.10_N2_gas": "",  # Assuming it's a gas measurement with no specific unit
    "C2H5CH_gas": "",  # Assuming it's a gas measurement with no specific unit
    "VOC_gas": "",  # Assuming it's a gas measurement with no specific unit
    "CO_gas": "",  # Assuming it's a gas measurement with no specific unit
    "Co2": "",  # Assuming it's a gas measurement with no specific unit
    "Temperature": "°C",
    "Humidity": "%",
    "Luminance": "cd/m²"
}


url1 = f"https://thingsboard.cs.cf.ac.uk/api/plugins/telemetry/DEVICE/{device_id}/values/timeseries?keys={','.join(keys_to_fetch)}"

headers = {
    'Content-Type': 'application/json',
    'X-Authorization': f'Bearer {access_token}'
}

response = requests.get(url1, headers=headers)

if response.status_code == 200:
    data = response.json()
    
    # Remove the extra brackets and format the data
    formatted_data = {}
    for key in data:
        if key in units:
            try:
                value = float(data[key][0]["value"])
            except ValueError:
                value = data[key][0]["value"]  # If not numeric, keep the original value
            
            formatted_data[key.lower()] = {
                "value": value,
                "units": units[key]
            }
    
    print("Received data:")
    print(json.dumps(formatted_data, indent=2))
else:
    print(f"Failed to get data. Status Code: {response.status_code}")
    print(response.text)

# ... (your code for sending data)

try:
    url2 = f'http://visualiser:80/api/devices/{node_name}/data'
    response = requests.put(url2, headers=headers, data=json.dumps(formatted_data))

    if response.status_code == 200:
        json_data = response.json()
        # Process the JSON data as needed
        print(json_data)
    else:
        print(f"Error: {response.status_code}")
        print(response.text)

except requests.exceptions.RequestException as e:
    print(f"Request error: {e}")
# Out:
# JWT_Token: eyJhbGciOiJIUzUxMiJ9.....AwBaya1p7_WltjiNceNXARCjjRikAIIe5d88KTQ6VOCub-3v33TFXIowhlI-4YUUgQVYsyuyjS6jMGbs--AZOA
# Received data:
# {
#   "uv_light": {
#     "value": 0.0,
#     "units": "UV Index"
#   },
#   "loudness": {
#     "value": 366.0,
#     "units": "dB"
#   },
#   "pm1.0atmospheric": {
#     "value": 9.0,
#     "units": "\u00b5g/m\u00b3"
#   },
#   "pm2.5atmospheric": {
#     "value": 12.0,
#     "units": "\u00b5g/m\u00b3"
#   },
#   "pm10atmospheric": {
#     "value": 13.0,
#     "units": "\u00b5g/m\u00b3"
#   },
#   "pir_status": {
#     "value": "No Motion Detected",
#     "units": ""
#   },
#   "tvoc_concentration": {
#     "value": 20.0,
#     "units": "ppb"
#   },
#   "co2eq_concentration": {
#     "value": 399.0,
#     "units": "ppm"
#   },
#   "mq2_sensor_voltage": {
#     "value": 0.32,
#     "units": "Volts"
#   },
#   "mq2_rs_ratio": {
#     "value": 15.73,
#     "units": ""
#   },
#   "mq2_rs/r0_ratio": {
#     "value": 150.25,
#     "units": ""
#   },
#   "mq3_sensor_voltage": {
#     "value": 0.31,
#     "units": "Volts"
#   },
#   "mq3_rs_ratio": {
#     "value": 15.59,
#     "units": ""
#   },
#   "mq3_rs/r0_ratio": {
#     "value": 757.18,
#     "units": ""
#   },
#   "hcho_ppm": {
#     "value": 0.0,
#     "units": "ppm"
#   },
#   "air_quality": {
#     "value": "Fresh air",
#     "units": ""
#   },
#   "light_value": {
#     "value": 171.0,
#     "units": "Lux"
#   },
#   "visible_light": {
#     "value": 263.0,
#     "units": "Lux"
#   },
#   "ir_light": {
#     "value": 273.0,
#     "units": "Lux"
#   },
#   "mq5_sensor_voltage": {
#     "value": 0.67,
#     "units": "Volts"
#   },
#   "mq5_rs_ratio": {
#     "value": 6.17,
#     "units": ""
#   },
#   "mq5_rs/r0_ratio": {
#     "value": 41.31,
#     "units": ""
#   },
#   "mq9_sensor_voltage": {
#     "value": 0.38,
#     "units": "Volts"
#   },
#   "mq9_rs_ratio": {
#     "value": 12.33,
#     "units": ""
#   },
#   "mq9_rs/r0_ratio": {
#     "value": 82.79,
#     "units": ""
#   },
#   "o2_22.10_n2_gas": {
#     "value": 195.0,
#     "units": ""
#   },
#   "c2h5ch_gas": {
#     "value": 288.0,
#     "units": ""
#   },
#   "voc_gas": {
#     "value": 251.0,
#     "units": ""
#   },
#   "co_gas": {
#     "value": 179.0,
#     "units": ""
#   },
#   "co2": {
#     "value": 606.0,
#     "units": ""
#   },
#   "temperature": {
#     "value": 30.54,
#     "units": "\u00b0C"
#   },
#   "humidity": {
#     "value": 17.11,
#     "units": "%"
#   },
#   "luminance": {
#     "value": 30.21,
#     "units": "cd/m\u00b2"
#   }
# }
# Error: 202

# %% [markdown]
# AVOID DUPLICATES

# %%
import requests
import json

url0 = "https://thingsboard.cs.cf.ac.uk/api/auth/login"
headers = {"Content-Type": "application/json"}

payload = {
    "username": "SuhasAbacwsLivingLab@cardiff.ac.uk",
    "password": "SuhasDevmane"
}

response = requests.post(url0, json=payload, headers=headers)

if response.status_code == 200:
    # Authentication successful
    token = response.json().get("token")
    print("JWT_Token:", token)
else:
    print("Authentication failed. Status Code:", response.status_code)
    print("Response:", response.text)

device_id = 'f57a1560-7cf3-11ee-94bc-d389020903a3'
node_name = "node_5.14"
last_ts = None
access_token = token  
keys_to_fetch = [
    "UV_light", "Loudness", "PM1.0Atmospheric", "PM2.5Atmospheric", "PM10Atmospheric", 
    "PIR_Status", "tVOC_Concentration", "CO2eq_Concentration", "MQ2_sensor_voltage", 
    "MQ2_Rs_ratio", "MQ2_Rs/R0_Ratio", "MQ3_sensor_voltage", "MQ3_Rs_ratio", 
    "MQ3_Rs/R0_Ratio", "HCHO_ppm", "Air_Quality", "Light_value", "Visible_light", 
    "IR_light", "MQ5_sensor_voltage", "MQ5_Rs_ratio", "MQ5_Rs/R0_Ratio", 
    "MQ9_sensor_voltage", "MQ9_Rs_ratio", "MQ9_Rs/R0_Ratio", "O2_22.10_N2_gas", 
    "C2H5CH_gas", "VOC_gas", "CO_gas", "Co2", "Temperature", "Humidity", "Luminance"
]

units = {
    "UV_light": "UV Index",
    "Loudness": "dB",
    "PM1.0Atmospheric": "µg/m³",
    "PM2.5Atmospheric": "µg/m³",
    "PM10Atmospheric": "µg/m³",
    "PIR_Status": "",  # Assuming it's a status indicator with no specific unit
    "tVOC_Concentration": "ppb",
    "CO2eq_Concentration": "ppm",
    "MQ2_sensor_voltage": "Volts",
    "MQ2_Rs_ratio": "",
    "MQ2_Rs/R0_Ratio": "",
    "MQ3_sensor_voltage": "Volts",
    "MQ3_Rs_ratio": "",
    "MQ3_Rs/R0_Ratio": "",
    "HCHO_ppm": "ppm",
    "Air_Quality": "",  # Assuming it's a qualitative measure with no specific unit
    "Light_value": "Lux",
    "Visible_light": "Lux",
    "IR_light": "Lux",
    "MQ5_sensor_voltage": "Volts",
    "MQ5_Rs_ratio": "",
    "MQ5_Rs/R0_Ratio": "",
    "MQ9_sensor_voltage": "Volts",
    "MQ9_Rs_ratio": "",
    "MQ9_Rs/R0_Ratio": "",
    "O2_22.10_N2_gas": "",  # Assuming it's a gas measurement with no specific unit
    "C2H5CH_gas": "",  # Assuming it's a gas measurement with no specific unit
    "VOC_gas": "",  # Assuming it's a gas measurement with no specific unit
    "CO_gas": "",  # Assuming it's a gas measurement with no specific unit
    "Co2": "",  # Assuming it's a gas measurement with no specific unit
    "Temperature": "°C",
    "Humidity": "%",
    "Luminance": "cd/m²"
}

last_ts = None

url1 = f"https://thingsboard.cs.cf.ac.uk/api/plugins/telemetry/DEVICE/{device_id}/values/timeseries?keys={','.join(keys_to_fetch)}"

headers = {
    'Content-Type': 'application/json',
    'X-Authorization': f'Bearer {access_token}'
}

response = requests.get(url1, headers=headers)

if response.status_code == 200:
    data = response.json()
    
    # Remove the extra brackets and format the data
    formatted_data = {}
    for key in data:
        if key in units:
            try:
                value = float(data[key][0]["value"])
            except ValueError:
                value = data[key][0]["value"]  # If not numeric, keep the original value
            
            formatted_data[key.lower()] = {
                "value": value,
                "units": units[key]
            }
    
     # Check if the current timestamp is different from the last one
    current_ts = data[key][0]["ts"]
    if current_ts != last_ts:
        print("Received data:")
        print(json.dumps(formatted_data, indent=2))
        
        # ... (your code for sending data)
        
        try:
            url2 = f'http://visualiser:80/api/devices/{node_name}/data'
            response = requests.put(url2, headers=headers, data=json.dumps(formatted_data))

            if response.status_code == 200:
                json_data = response.json()
                # Process the JSON data as needed
                print(json_data)
                
                # Update the last timestamp
                last_ts = current_ts
            else:
                print(f"Error: {response.status_code}")
                print(response.text)

        except requests.exceptions.RequestException as e:
            print(f"Request error: {e}")
    else:
        print("Received data with the same timestamp. Skipping...")
else:
    print(f"Failed to get data. Status Code: {response.status_code}")
    print(response.text)
# Out:
# JWT_Token: eyJhbGciOiJIUzUxMiJ9.....yKnhVeGsX1n5FuT6_TuwltBiWtzTSetWsxcoB3Nvaytf-AkQwHRjZLjhMjM0-lgdpgHpH0qwrOUq_h4TyTw7-A
# Received data:
# {
#   "uv_light": {
#     "value": 0.02,
#     "units": "UV Index"
#   },
#   "loudness": {
#     "value": 348.0,
#     "units": "dB"
#   },
#   "pm1.0atmospheric": {
#     "value": 9.0,
#     "units": "\u00b5g/m\u00b3"
#   },
#   "pm2.5atmospheric": {
#     "value": 13.0,
#     "units": "\u00b5g/m\u00b3"
#   },
#   "pm10atmospheric": {
#     "value": 13.0,
#     "units": "\u00b5g/m\u00b3"
#   },
#   "pir_status": {
#     "value": "No Motion Detected",
#     "units": ""
#   },
#   "tvoc_concentration": {
#     "value": 18.0,
#     "units": "ppb"
#   },
#   "co2eq_concentration": {
#     "value": 393.0,
#     "units": "ppm"
#   },
#   "mq2_sensor_voltage": {
#     "value": 0.26,
#     "units": "Volts"
#   },
#   "mq2_rs_ratio": {
#     "value": 15.79,
#     "units": ""
#   },
#   "mq2_rs/r0_ratio": {
#     "value": 157.8,
#     "units": ""
#   },
#   "mq3_sensor_voltage": {
#     "value": 0.32,
#     "units": "Volts"
#   },
#   "mq3_rs_ratio": {
#     "value": 14.29,
#     "units": ""
#   },
#   "mq3_rs/r0_ratio": {
#     "value": 765.78,
#     "units": ""
#   },
#   "hcho_ppm": {
#     "value": 0.01,
#     "units": "ppm"
#   },
#   "air_quality": {
#     "value": "Fresh air",
#     "units": ""
#   },
#   "light_value": {
#     "value": 170.0,
#     "units": "Lux"
#   },
#   "visible_light": {
#     "value": 260.0,
#     "units": "Lux"
#   },
#   "ir_light": {
#     "value": 278.0,
#     "units": "Lux"
#   },
#   "mq5_sensor_voltage": {
#     "value": 0.75,
#     "units": "Volts"
#   },
#   "mq5_rs_ratio": {
#     "value": 6.07,
#     "units": ""
#   },
#   "mq5_rs/r0_ratio": {
#     "value": 40.28,
#     "units": ""
#   },
#   "mq9_sensor_voltage": {
#     "value": 0.36,
#     "units": "Volts"
#   },
#   "mq9_rs_ratio": {
#     "value": 12.72,
#     "units": ""
#   },
#   "mq9_rs/r0_ratio": {
#     "value": 82.22,
#     "units": ""
#   },
#   "o2_22.10_n2_gas": {
#     "value": 192.0,
#     "units": ""
#   },
#   "c2h5ch_gas": {
#     "value": 289.0,
#     "units": ""
#   },
#   "voc_gas": {
#     "value": 246.0,
#     "units": ""
#   },
#   "co_gas": {
#     "value": 180.0,
#     "units": ""
#   },
#   "co2": {
#     "value": 600.0,
#     "units": ""
#   },
#   "temperature": {
#     "value": 31.21,
#     "units": "\u00b0C"
#   },
#   "humidity": {
#     "value": 18.54,
#     "units": "%"
#   },
#   "luminance": {
#     "value": 31.6,
#     "units": "cd/m\u00b2"
#   }
# }
# Error: 202

# %% [markdown]
# ## looping for all devices - FINAL

# %%
import requests
import json
import time
while True:
    url0 = "https://thingsboard.cs.cf.ac.uk/api/auth/login"
    headers = {"Content-Type": "application/json"}

    payload = {
        "username": "SuhasAbacwsLivingLab@cardiff.ac.uk",
        "password": "SuhasDevmane"
    }

    response = requests.post(url0, json=payload, headers=headers)

    if response.status_code == 200:
        # Authentication successful
        token = response.json().get("token")
        print("JWT_Token:", token)
    else:
        print("Authentication failed. Status Code:", response.status_code)
        print("Response:", response.text)

    access_token = token  
    keys_to_fetch = [
        "UV_light", "Loudness", "PM1.0Atmospheric", "PM2.5Atmospheric", "PM10Atmospheric", 
        "PIR_Status", "tVOC_Concentration", "CO2eq_Concentration", "MQ2_sensor_voltage", 
        "MQ2_Rs_ratio", "MQ2_Rs/R0_Ratio", "MQ3_sensor_voltage", "MQ3_Rs_ratio", 
        "MQ3_Rs/R0_Ratio", "HCHO_ppm", "Air_Quality", "Light_value", "Visible_light", 
        "IR_light", "MQ5_sensor_voltage", "MQ5_Rs_ratio", "MQ5_Rs/R0_Ratio", 
        "MQ9_sensor_voltage", "MQ9_Rs_ratio", "MQ9_Rs/R0_Ratio", "O2_22.10_N2_gas", 
        "C2H5CH_gas", "VOC_gas", "CO_gas", "Co2", "Temperature", "Humidity", "Luminance"
    ]

    units = {
        "UV_light": "UV Index",
        "Loudness": "dB",
        "PM1.0Atmospheric": "µg/m³",
        "PM2.5Atmospheric": "µg/m³",
        "PM10Atmospheric": "µg/m³",
        "PIR_Status": "",  # Assuming it's a status indicator with no specific unit
        "tVOC_Concentration": "ppb",
        "CO2eq_Concentration": "ppm",
        "MQ2_sensor_voltage": "Volts",
        "MQ2_Rs_ratio": "",
        "MQ2_Rs/R0_Ratio": "",
        "MQ3_sensor_voltage": "Volts",
        "MQ3_Rs_ratio": "",
        "MQ3_Rs/R0_Ratio": "",
        "HCHO_ppm": "ppm",
        "Air_Quality": "",  # Assuming it's a qualitative measure with no specific unit
        "Light_value": "Lux",
        "Visible_light": "Lux",
        "IR_light": "Lux",
        "MQ5_sensor_voltage": "Volts",
        "MQ5_Rs_ratio": "",
        "MQ5_Rs/R0_Ratio": "",
        "MQ9_sensor_voltage": "Volts",
        "MQ9_Rs_ratio": "",
        "MQ9_Rs/R0_Ratio": "",
        "O2_22.10_N2_gas": "",  # Assuming it's a gas measurement with no specific unit
        "C2H5CH_gas": "",  # Assuming it's a gas measurement with no specific unit
        "VOC_gas": "",  # Assuming it's a gas measurement with no specific unit
        "CO_gas": "",  # Assuming it's a gas measurement with no specific unit
        "Co2": "",  # Assuming it's a gas measurement with no specific unit
        "Temperature": "°C",
        "Humidity": "%",
        "Luminance": "cd/m²"
    }

    pairs = [
            ('70ad22a0-b82c-11ed-b196-bb47e24272bc','node_5.01'),
            ('75d29440-b82c-11ed-b196-bb47e24272bc','node_5.02'),
            ('7b717ba0-b82c-11ed-b196-bb47e24272bc','node_5.03'),
            ('a673eb80-b82c-11ed-b196-bb47e24272bc','node_5.04'),
            ('83456b70-b82c-11ed-b196-bb47e24272bc','node_5.05'),
            ('b96d6720-b82c-11ed-b196-bb47e24272bc','node_5.06'),
            ('be98a520-b82c-11ed-b196-bb47e24272bc','node_5.07'),
            ('c3110de0-b82c-11ed-b196-bb47e24272bc','node_5.08'),
            ('c950f030-b82c-11ed-b196-bb47e24272bc','node_5.09'),
            ('cfddba00-b82c-11ed-b196-bb47e24272bc','node_5.10'),
            ('278505c0-0f7a-11ee-bf90-a16a1a9e1e0a','node_5.11'),
            ('d9576a90-b82c-11ed-b196-bb47e24272bc','node_5.12'),
            ('de18ea40-b82c-11ed-b196-bb47e24272bc','node_5.13'),
            ('f57a1560-7cf3-11ee-94bc-d389020903a3','node_5.14'),
            ('508d1b60-57eb-11ee-8714-19d56ba0c4fd','node_5.15'),
            ('86c63bd0-57f0-11ee-8714-19d56ba0c4fd','node_5.16'),
            ('3efd82d0-7cf4-11ee-94bc-d389020903a3','node_5.17'),
            ('f583bc50-57e6-11ee-8714-19d56ba0c4fd','node_5.18'),
            ('9458c560-0f75-11ee-bf90-a16a1a9e1e0a','node_5.19'),
            ('cbc851c0-57ee-11ee-8714-19d56ba0c4fd','node_5.20'),
            ('2ae959b0-53c6-11ee-8714-19d56ba0c4fd','node_5.21'),
            ('351b0eb0-57ef-11ee-8714-19d56ba0c4fd','node_5.22'),
            ('0f96bed0-b82d-11ed-b196-bb47e24272bc','node_5.23'),
            ('13e642d0-b82d-11ed-b196-bb47e24272bc','node_5.24'),
            ('18a159e0-b82d-11ed-b196-bb47e24272bc','node_5.25'),
            ('fef50770-57f1-11ee-8714-19d56ba0c4fd','node_5.26'),
            ('2a5d9a90-b82d-11ed-b196-bb47e24272bc','node_5.27'),
            ('99c6a3b0-b82b-11ed-b196-bb47e24272bc','node_5.28'),
            ('51f2d170-57e1-11ee-8714-19d56ba0c4fd','node_5.29'),
            ('9c563630-0f75-11ee-bf90-a16a1a9e1e0a','node_5.30'),
            ('391303e0-b82d-11ed-b196-bb47e24272bc','node_5.31'),
            ('3d3a3f60-b82d-11ed-b196-bb47e24272bc','node_5.32'),
            ('a83a46c0-7cf4-11ee-94bc-d389020903a3','node_5.33'),
            ('4665a8e0-b82d-11ed-b196-bb47e24272bc','node_5.34')
        
    ]

    # Keep track of the last received timestamp
    last_ts = None

    # Run the code for each pair
    for device_id, node_name in pairs:
        url1 = f"https://thingsboard.cs.cf.ac.uk/api/plugins/telemetry/DEVICE/{device_id}/values/timeseries?keys={','.join(keys_to_fetch)}"
        headers = {
            'Content-Type': 'application/json',
            'X-Authorization': f'Bearer {access_token}'
        }

        response = requests.get(url1, headers=headers)

        if response.status_code == 200:
            data = response.json()

            # Remove the extra brackets and format the data
            formatted_data = {}
            for key in data:
                if key in units:
                    try:
                        value = float(data[key][0]["value"])
                    except ValueError:
                        value = data[key][0]["value"]  # If not numeric, keep the original value

                    formatted_data[key.lower()] = {
                        "value": value,
                        "units": units[key]
                    }

            # Check if the current timestamp is different from the last one
            current_ts = data[key][0]["ts"]
            if current_ts != last_ts:
                print(f"Received data for {device_id}:{node_name}:")
                print(json.dumps(formatted_data, indent=2))

                # ... (your code for sending data)

                try:
                    # time.sleep(1)
                    url2 = f'http://visualiser:80/api/devices/{node_name}/data'
                    response = requests.put(url2, headers=headers, data=json.dumps(formatted_data))

                    if response.status_code == 200:
                        json_data = response.json()
                        # Process the JSON data as needed
                        print(json_data)

                        # Update the last timestamp
                        last_ts = current_ts
                    else:
                        print(f"Error: {response.status_code}")
                        print(response.text)

                except requests.exceptions.RequestException as e:
                    print(f"Request error: {e}")
            else:
                print(f"Received data with the same timestamp for {device_id}:{node_name}. Skipping...")
        else:
            print(f"Failed to get data for {device_id}:{node_name}. Status Code: {response.status_code}")
            print(response.text)
    time.sleep(10)
# Out:
# JWT_Token: eyJhbGciOiJIUzUxMiJ9.....RD70RWj7_02nGcVa2qgf_2xVUTZXiwBvs7JDiTjpq5UKWbFW9RKGbR3mrdmXb30cEDuijQpF7anKqpHmW_9RFg
# Received data for 70ad22a0-b82c-11ed-b196-bb47e24272bc:node_5.01:
# {
#   "uv_light": {
#     "value": 0.09,
#     "units": "UV Index"
#   },
#   "loudness": {
#     "value": 306.0,
#     "units": "dB"
#   },
#   "pm1.0atmospheric": {
#     "value": 10.0,
#     "units": "\u00b5g/m\u00b3"
#   },
#   "pm2.5atmospheric": {
#     "value": 13.0,
#     "units": "\u00b5g/m\u00b3"
#   },
#   "pm10atmospheric": {
#     "value": 13.0,
#     "units": "\u00b5g/m\u00b3"
#   },
#   "pir_status": {
#     "value": "No Motion Detected",
#     "units": ""
#   },
#   "tvoc_concentration": {
#     "value": 20.0,
#     "units": "ppb"
#   },
#   "co2eq_concentration": {
#     "value": 401.0,
#     "units": "ppm"
#   },
#   "mq2_sensor_voltage": {
#     "value": 0.27,
#     "units": "Volts"
#   },
#   "mq2_rs_ratio": {
#     "value": 15.22,
#     "units": ""
#   },
#   "mq2_rs/r0_ratio": {
#     "value": 150.67,
#     "units": ""
#   },
#   "mq3_sensor_voltage": {
#     "value": 0.33,
#     "units": "Volts"
#   },
#   "mq3_rs_ratio": {
#     "value": 15.91,
#     "units": ""
#   },
#   "mq3_rs/r0_ratio": {
#     "value": 758.82,
#     "units": ""
#   },
#   "hcho_ppm": {
#     "value": 0.0,
#     "units": "ppm"
#   },
#   "air_quality": {
#     "value": "Fresh air",
#     "units": ""
#   },
#   "light_value": {
#     "value": 171.0,
#     "units": "Lux"
#   },
#   "visible_light": {
#     "value": 265.0,
#     "units": "Lux"
#   },
#   "ir_light": {
#     "value": 270.0,
#     "units": "Lux"
#   },
#   "mq5_sensor_voltage": {
#     "value": 0.7,
#     "units": "Volts"
#   },
#   "mq5_rs_ratio": {
#     "value": 5.87,
#     "units": ""
#   },
#   "mq5_rs/r0_ratio": {
#     "value": 40.66,
#     "units": ""
#   },
#   "mq9_sensor_voltage": {
#     "value": 0.36,
#     "units": "Volts"
#   },
#   "mq9_rs_ratio": {
#     "value": 12.55,
#     "units": ""
#   },
#   "mq9_rs/r0_ratio": {
#     "value": 83.09,
#     "units": ""
#   },
#   "o2_22.10_n2_gas": {
#     "value": 196.0,
#     "units": ""
#   },
#   "c2h5ch_gas": {
#     "value": 288.0,
#     "units": ""
#   },
#   "voc_gas": {
#     "value": 250.0,
#     "units": ""
#   },
#   "co_gas": {
#     "value": 177.0,
#     "units": ""
#   },
#   "co2": {
#     "value": 606.0,
#     "units": ""
#   },
#   "temperature": {
#     "value": 31.15,
#     "units": "\u00b0C"
#   },
#   "humidity": {
#     "value": 17.44,
#     "units": "%"
#   },
#   "luminance": {
#     "value": 30.78,
#     "units": "cd/m\u00b2"
#   }
# }
# Error: 202
#
# Received data for 75d29440-b82c-11ed-b196-bb47e24272bc:node_5.02:
# {
#   "uv_light": {
#     "value": 0.06,
#     "units": "UV Index"
#   },
#   "loudness": {
#     "value": 323.0,
#     "units": "dB"
#   },
#   "pm1.0atmospheric": {
#     "value": 8.0,
#     "units": "\u00b5g/m\u00b3"
#   },
#   "pm2.5atmospheric": {
#     "value": 13.0,
#     "units": "\u00b5g/m\u00b3"
#   },
#   "pm10atmospheric": {
#     "value": 13.0,
#     "units": "\u00b5g/m\u00b3"
#   },
#   "pir_status": {
#     "value": "No Motion Detected",
#     "units": ""
#   },
#   "tvoc_concentration": {
#     "value": 20.0,
#     "units": "ppb"
#   },
#   "co2eq_concentration": {
#     "value": 402.0,
#     "units": "ppm"
#   },
#   "mq2_sensor_voltage": {
#     "value": 0.33,
#     "units": "Volts"
#   },
#   "mq2_rs_ratio": {
#     "value": 15.44,
#     "units": ""
#   },
#   "mq2_rs/r0_ratio": {
#     "value": 156.49,
#     "units": ""
#   },
#   "mq3_sensor_voltage": {
#     "value": 0.3,
#     "units": "Volts"
#   },
#   "mq3_rs_ratio": {
#     "value": 14.28,
#     "units": ""
#   },
#   "mq3_rs/r0_ratio": {
#     "value": 753.82,
#     "units": ""
#   },
#   "hcho_ppm": {
#     "value": 0.0,
#     "units": "ppm"
#   },
#   "air_quality": {
#     "value": "Fresh air",
#     "units": ""
#   },
#   "light_value": {
#     "value": 173.0,
#     "units": "Lux"
#   },
#   "visible_light": {
#     "value": 260.0,
#     "units": "Lux"
#   },
#   "ir_light": {
#     "value": 274.0,
#     "units": "Lux"
#   },
#   "mq5_sensor_voltage": {
#     "value": 0.66,
#     "units": "Volts"
#   },
#   "mq5_rs_ratio": {
#     "value": 5.99,
#     "units": ""
#   },
#   "mq5_rs/r0_ratio": {
#     "value": 41.25,
#     "units": ""
#   },
#   "mq9_sensor_voltage": {
#     "value": 0.39,
#     "units": "Volts"
#   },
#   "mq9_rs_ratio": {
#     "value": 12.25,
#     "units": ""
#   },
#   "mq9_rs/r0_ratio": {
#     "value": 83.33,
#     "units": ""
#   },
#   "o2_22.10_n2_gas": {
#     "value": 196.0,
#     "units": ""
#   },
#   "c2h5ch_gas": {
#     "value": 290.0,
#     "units": ""
#   },
#   "voc_gas": {
#     "value": 251.0,
#     "units": ""
#   },
#   "co_gas": {
#     "value": 178.0,
#     "units": ""
#   },
#   "co2": {
#     "value": 604.0,
#     "units": ""
#   },
#   "temperature": {
#     "value": 30.31,
#     "units": "\u00b0C"
#   },
#   "humidity": {
#     "value": 18.24,
#     "units": "%"
#   },
#   "luminance": {
#     "value": 30.03,
#     "units": "cd/m\u00b2"
#   }
# }
# Error: 202
#
# Received data for 7b717ba0-b82c-11ed-b196-bb47e24272bc:node_5.03:
# {
#   "uv_light": {
#     "value": 0.07,
#     "units": "UV Index"
#   },
#   "loudness": {
#     "value": 347.0,
#     "units": "dB"
#   },
#   "pm1.0atmospheric": {
#     "value": 10.0,
#     "units": "\u00b5g/m\u00b3"
#   },
#   "pm2.5atmospheric": {
#     "value": 12.0,
#     "units": "\u00b5g/m\u00b3"
#   },
#   "pm10atmospheric": {
#     "value": 13.0,
#     "units": "\u00b5g/m\u00b3"
#   },
#   "pir_status": {
#     "value": "No Motion Detected",
#     "units": ""
#   },
#   "tvoc_concentration": {
#     "value": 19.0,
#     "units": "ppb"
#   },
#   "co2eq_concentration": {
#     "value": 406.0,
#     "units": "ppm"
#   },
#   "mq2_sensor_voltage": {
#     "value": 0.28,
#     "units": "Volts"
#   },
#   "mq2_rs_ratio": {
#     "value": 15.9,
#     "units": ""
#   },
#   "mq2_rs/r0_ratio": {
#     "value": 157.94,
#     "units": ""
#   },
#   "mq3_sensor_voltage": {
#     "value": 0.3,
#     "units": "Volts"
#   },
#   "mq3_rs_ratio": {
#     "value": 14.16,
#     "units": ""
#   },
#   "mq3_rs/r0_ratio": {
#     "value": 750.72,
#     "units": ""
#   },
#   "hcho_ppm": {
#     "value": 0.01,
#     "units": "ppm"
#   },
#   "air_quality": {
#     "value": "Fresh air",
#     "units": ""
#   },
#   "light_value": {
#     "value": 170.0,
#     "units": "Lux"
#   },
#   "visible_light": {
#     "value": 264.0,
#     "units": "Lux"
#   },
#   "ir_light": {
#     "value": 277.0,
#     "units": "Lux"
#   },
#   "mq5_sensor_voltage": {
#     "value": 0.75,
#     "units": "Volts"
#   },
#   "mq5_rs_ratio": {
#     "value": 6.04,
#     "units": ""
#   },
#   "mq5_rs/r0_ratio": {
#     "value": 40.4,
#     "units": ""
#   },
#   "mq9_sensor_voltage": {
#     "value": 0.36,
#     "units": "Volts"
#   },
#   "mq9_rs_ratio": {
#     "value": 12.88,
#     "units": ""
#   },
#   "mq9_rs/r0_ratio": {
#     "value": 83.16,
#     "units": ""
#   },
#   "o2_22.10_n2_gas": {
#     "value": 196.0,
#     "units": ""
#   },
#   "c2h5ch_gas": {
#     "value": 291.0,
#     "units": ""
#   },
#   "voc_gas": {
#     "value": 246.0,
#     "units": ""
#   },
#   "co_gas": {
#     "value": 178.0,
#     "units": ""
#   },
#   "co2": {
#     "value": 607.0,
#     "units": ""
#   },
#   "temperature": {
#     "value": 30.4,
#     "units": "\u00b0C"
#   },
#   "humidity": {
#     "value": 17.97,
#     "units": "%"
#   },
#   "luminance": {
#     "value": 31.41,
#     "units": "cd/m\u00b2"
#   }
# }
# Error: 202
#
# Received data for a673eb80-b82c-11ed-b196-bb47e24272bc:node_5.04:
# {
#   "uv_light": {
#     "value": 0.0,
#     "units": "UV Index"
#   },
#   "loudness": {
#     "value": 391.0,
#     "units": "dB"
#   },
#   "pm1.0atmospheric": {
#     "value": 8.0,
#     "units": "\u00b5g/m\u00b3"
#   },
#   "pm2.5atmospheric": {
#     "value": 12.0,
#     "units": "\u00b5g/m\u00b3"
#   },
#   "pm10atmospheric": {
#     "value": 12.0,
#     "units": "\u00b5g/m\u00b3"
#   },
#   "pir_status": {
#     "value": "No Motion Detected",
#     "units": ""
#   },
#   "tvoc_concentration": {
#     "value": 18.0,
#     "units": "ppb"
#   },
#   "co2eq_concentration": {
#     "value": 395.0,
#     "units": "ppm"
#   },
#   "mq2_sensor_voltage": {
#     "value": 0.32,
#     "units": "Volts"
#   },
#   "mq2_rs_ratio": {
#     "value": 15.06,
#     "units": ""
#   },
#   "mq2_rs/r0_ratio": {
#     "value": 158.03,
#     "units": ""
#   },
#   "mq3_sensor_voltage": {
#     "value": 0.32,
#     "units": "Volts"
#   },
#   "mq3_rs_ratio": {
#     "value": 14.51,
#     "units": ""
#   },
#   "mq3_rs/r0_ratio": {
#     "value": 759.38,
#     "units": ""
#   },
#   "hcho_ppm": {
#     "value": 0.0,
#     "units": "ppm"
#   },
#   "air_quality": {
#     "value": "Fresh air",
#     "units": ""
#   },
#   "light_value": {
#     "value": 173.0,
#     "units": "Lux"
#   },
#   "visible_light": {
#     "value": 263.0,
#     "units": "Lux"
#   },
#   "ir_light": {
#     "value": 270.0,
#     "units": "Lux"
#   },
#   "mq5_sensor_voltage": {
#     "value": 0.72,
#     "units": "Volts"
#   },
#   "mq5_rs_ratio": {
#     "value": 6.04,
#     "units": ""
#   },
#   "mq5_rs/r0_ratio": {
#     "value": 40.79,
#     "units": ""
#   },
#   "mq9_sensor_voltage": {
#     "value": 0.38,
#     "units": "Volts"
#   },
#   "mq9_rs_ratio": {
#     "value": 12.01,
#     "units": ""
#   },
#   "mq9_rs/r0_ratio": {
#     "value": 82.12,
#     "units": ""
#   },
#   "o2_22.10_n2_gas": {
#     "value": 194.0,
#     "units": ""
#   },
#   "c2h5ch_gas": {
#     "value": 290.0,
#     "units": ""
#   },
#   "voc_gas": {
#     "value": 246.0,
#     "units": ""
#   },
#   "co_gas": {
#     "value": 180.0,
#     "units": ""
#   },
#   "co2": {
#     "value": 605.0,
#     "units": ""
#   },
#   "temperature": {
#     "value": 31.1,
#     "units": "\u00b0C"
#   },
#   "humidity": {
#     "value": 18.88,
#     "units": "%"
#   },
#   "luminance": {
#     "value": 30.62,
#     "units": "cd/m\u00b2"
#   }
# }
# Error: 202
#
# Received data for 83456b70-b82c-11ed-b196-bb47e24272bc:node_5.05:
# {
#   "uv_light": {
#     "value": 0.01,
#     "units": "UV Index"
#   },
#   "loudness": {
#     "value": 333.0,
#     "units": "dB"
#   },
#   "pm1.0atmospheric": {
#     "value": 10.0,
#     "units": "\u00b5g/m\u00b3"
#   },
#   "pm2.5atmospheric": {
#     "value": 13.0,
#     "units": "\u00b5g/m\u00b3"
#   },
#   "pm10atmospheric": {
#     "value": 14.0,
#     "units": "\u00b5g/m\u00b3"
#   },
#   "pir_status": {
#     "value": "No Motion Detected",
#     "units": ""
#   },
#   "tvoc_concentration": {
#     "value": 19.0,
#     "units": "ppb"
#   },
#   "co2eq_concentration": {
#     "value": 402.0,
#     "units": "ppm"
#   },
#   "mq2_sensor_voltage": {
#     "value": 0.29,
#     "units": "Volts"
#   },
#   "mq2_rs_ratio": {
#     "value": 15.9,
#     "units": ""
#   },
#   "mq2_rs/r0_ratio": {
#     "value": 158.44,
#     "units": ""
#   },
#   "mq3_sensor_voltage": {
#     "value": 0.33,
#     "units": "Volts"
#   },
#   "mq3_rs_ratio": {
#     "value": 14.19,
#     "units": ""
#   },
#   "mq3_rs/r0_ratio": {
#     "value": 751.81,
#     "units": ""
#   },
#   "hcho_ppm": {
#     "value": 0.0,
#     "units": "ppm"
#   },
#   "air_quality": {
#     "value": "Fresh air",
#     "units": ""
#   },
#   "light_value": {
#     "value": 172.0,
#     "units": "Lux"
#   },
#   "visible_light": {
#     "value": 264.0,
#     "units": "Lux"
#   },
#   "ir_light": {
#     "value": 273.0,
#     "units": "Lux"
#   },
#   "mq5_sensor_voltage": {
#     "value": 0.72,
#     "units": "Volts"
#   },
#   "mq5_rs_ratio": {
#     "value": 6.09,
#     "units": ""
#   },
#   "mq5_rs/r0_ratio": {
#     "value": 41.56,
#     "units": ""
#   },
#   "mq9_sensor_voltage": {
#     "value": 0.36,
#     "units": "Volts"
#   },
#   "mq9_rs_ratio": {
#     "value": 12.03,
#     "units": ""
#   },
#   "mq9_rs/r0_ratio": {
#     "value": 83.49,
#     "units": ""
#   },
#   "o2_22.10_n2_gas": {
#     "value": 193.0,
#     "units": ""
#   },
#   "c2h5ch_gas": {
#     "value": 291.0,
#     "units": ""
#   },
#   "voc_gas": {
#     "value": 250.0,
#     "units": ""
#   },
#   "co_gas": {
#     "value": 181.0,
#     "units": ""
#   },
#   "co2": {
#     "value": 600.0,
#     "units": ""
#   },
#   "temperature": {
#     "value": 31.6,
#     "units": "\u00b0C"
#   },
#   "humidity": {
#     "value": 17.87,
#     "units": "%"
#   },
#   "luminance": {
#     "value": 30.09,
#     "units": "cd/m\u00b2"
#   }
# }
# Error: 202
#
# Received data for b96d6720-b82c-11ed-b196-bb47e24272bc:node_5.06:
# {
#   "uv_light": {
#     "value": 0.09,
#     "units": "UV Index"
#   },
#   "loudness": {
#     "value": 319.0,
#     "units": "dB"
#   },
#   "pm1.0atmospheric": {
#     "value": 8.0,
#     "units": "\u00b5g/m\u00b3"
#   },
#   "pm2.5atmospheric": {
#     "value": 13.0,
#     "units": "\u00b5g/m\u00b3"
#   },
#   "pm10atmospheric": {
#     "value": 14.0,
#     "units": "\u00b5g/m\u00b3"
#   },
#   "pir_status": {
#     "value": "No Motion Detected",
#     "units": ""
#   },
#   "tvoc_concentration": {
#     "value": 20.0,
#     "units": "ppb"
#   },
#   "co2eq_concentration": {
#     "value": 403.0,
#     "units": "ppm"
#   },
#   "mq2_sensor_voltage": {
#     "value": 0.26,
#     "units": "Volts"
#   },
#   "mq2_rs_ratio": {
#     "value": 15.93,
#     "units": ""
#   },
#   "mq2_rs/r0_ratio": {
#     "value": 151.82,
#     "units": ""
#   },
#   "mq3_sensor_voltage": {
#     "value": 0.35,
#     "units": "Volts"
#   },
#   "mq3_rs_ratio": {
#     "value": 15.21,
#     "units": ""
#   },
#   "mq3_rs/r0_ratio": {
#     "value": 755.1,
#     "units": ""
#   },
#   "hcho_ppm": {
#     "value": 0.0,
#     "units": "ppm"
#   },
#   "air_quality": {
#     "value": "Fresh air",
#     "units": ""
#   },
#   "light_value": {
#     "value": 170.0,
#     "units": "Lux"
#   },
#   "visible_light": {
#     "value": 264.0,
#     "units": "Lux"
#   },
#   "ir_light": {
#     "value": 273.0,
#     "units": "Lux"
#   },
#   "mq5_sensor_voltage": {
#     "value": 0.73,
#     "units": "Volts"
#   },
#   "mq5_rs_ratio": {
#     "value": 6.06,
#     "units": ""
#   },
#   "mq5_rs/r0_ratio": {
#     "value": 40.52,
#     "units": ""
#   },
#   "mq9_sensor_voltage": {
#     "value": 0.4,
#     "units": "Volts"
#   },
#   "mq9_rs_ratio": {
#     "value": 12.38,
#     "units": ""
#   },
#   "mq9_rs/r0_ratio": {
#     "value": 83.31,
#     "units": ""
#   },
#   "o2_22.10_n2_gas": {
#     "value": 193.0,
#     "units": ""
#   },
#   "c2h5ch_gas": {
#     "value": 290.0,
#     "units": ""
#   },
#   "voc_gas": {
#     "value": 247.0,
#     "units": ""
#   },
#   "co_gas": {
#     "value": 176.0,
#     "units": ""
#   },
#   "co2": {
#     "value": 600.0,
#     "units": ""
#   },
#   "temperature": {
#     "value": 31.3,
#     "units": "\u00b0C"
#   },
#   "humidity": {
#     "value": 17.62,
#     "units": "%"
#   },
#   "luminance": {
#     "value": 30.92,
#     "units": "cd/m\u00b2"
#   }
# }
# Error: 202
#
# Received data for be98a520-b82c-11ed-b196-bb47e24272bc:node_5.07:
# {
#   "uv_light": {
#     "value": 0.02,
#     "units": "UV Index"
#   },
#   "loudness": {
#     "value": 323.0,
#     "units": "dB"
#   },
#   "pm1.0atmospheric": {
#     "value": 8.0,
#     "units": "\u00b5g/m\u00b3"
#   },
#   "pm2.5atmospheric": {
#     "value": 13.0,
#     "units": "\u00b5g/m\u00b3"
#   },
#   "pm10atmospheric": {
#     "value": 14.0,
#     "units": "\u00b5g/m\u00b3"
#   },
#   "pir_status": {
#     "value": "No Motion Detected",
#     "units": ""
#   },
#   "tvoc_concentration": {
#     "value": 20.0,
#     "units": "ppb"
#   },
#   "co2eq_concentration": {
#     "value": 397.0,
#     "units": "ppm"
#   },
#   "mq2_sensor_voltage": {
#     "value": 0.26,
#     "units": "Volts"
#   },
#   "mq2_rs_ratio": {
#     "value": 15.66,
#     "units": ""
#   },
#   "mq2_rs/r0_ratio": {
#     "value": 155.13,
#     "units": ""
#   },
#   "mq3_sensor_voltage": {
#     "value": 0.33,
#     "units": "Volts"
#   },
#   "mq3_rs_ratio": {
#     "value": 14.7,
#     "units": ""
#   },
#   "mq3_rs/r0_ratio": {
#     "value": 758.03,
#     "units": ""
#   },
#   "hcho_ppm": {
#     "value": 0.01,
#     "units": "ppm"
#   },
#   "air_quality": {
#     "value": "Fresh air",
#     "units": ""
#   },
#   "light_value": {
#     "value": 174.0,
#     "units": "Lux"
#   },
#   "visible_light": {
#     "value": 264.0,
#     "units": "Lux"
#   },
#   "ir_light": {
#     "value": 272.0,
#     "units": "Lux"
#   },
#   "mq5_sensor_voltage": {
#     "value": 0.75,
#     "units": "Volts"
#   },
#   "mq5_rs_ratio": {
#     "value": 6.02,
#     "units": ""
#   },
#   "mq5_rs/r0_ratio": {
#     "value": 40.79,
#     "units": ""
#   },
#   "mq9_sensor_voltage": {
#     "value": 0.36,
#     "units": "Volts"
#   },
#   "mq9_rs_ratio": {
#     "value": 12.46,
#     "units": ""
#   },
#   "mq9_rs/r0_ratio": {
#     "value": 83.97,
#     "units": ""
#   },
#   "o2_22.10_n2_gas": {
#     "value": 195.0,
#     "units": ""
#   },
#   "c2h5ch_gas": {
#     "value": 290.0,
#     "units": ""
#   },
#   "voc_gas": {
#     "value": 249.0,
#     "units": ""
#   },
#   "co_gas": {
#     "value": 177.0,
#     "units": ""
#   },
#   "co2": {
#     "value": 599.0,
#     "units": ""
#   },
#   "temperature": {
#     "value": 31.19,
#     "units": "\u00b0C"
#   },
#   "humidity": {
#     "value": 17.21,
#     "units": "%"
#   },
#   "luminance": {
#     "value": 31.36,
#     "units": "cd/m\u00b2"
#   }
# }
# Error: 202
#
# Received data for c3110de0-b82c-11ed-b196-bb47e24272bc:node_5.08:
# {
#   "uv_light": {
#     "value": 0.08,
#     "units": "UV Index"
#   },
#   "loudness": {
#     "value": 344.0,
#     "units": "dB"
#   },
#   "pm1.0atmospheric": {
#     "value": 9.0,
#     "units": "\u00b5g/m\u00b3"
#   },
#   "pm2.5atmospheric": {
#     "value": 13.0,
#     "units": "\u00b5g/m\u00b3"
#   },
#   "pm10atmospheric": {
#     "value": 12.0,
#     "units": "\u00b5g/m\u00b3"
#   },
#   "pir_status": {
#     "value": "No Motion Detected",
#     "units": ""
#   },
#   "tvoc_concentration": {
#     "value": 18.0,
#     "units": "ppb"
#   },
#   "co2eq_concentration": {
#     "value": 400.0,
#     "units": "ppm"
#   },
#   "mq2_sensor_voltage": {
#     "value": 0.32,
#     "units": "Volts"
#   },
#   "mq2_rs_ratio": {
#     "value": 15.4,
#     "units": ""
#   },
#   "mq2_rs/r0_ratio": {
#     "value": 157.07,
#     "units": ""
#   },
#   "mq3_sensor_voltage": {
#     "value": 0.35,
#     "units": "Volts"
#   },
#   "mq3_rs_ratio": {
#     "value": 14.71,
#     "units": ""
#   },
#   "mq3_rs/r0_ratio": {
#     "value": 760.04,
#     "units": ""
#   },
#   "hcho_ppm": {
#     "value": 0.0,
#     "units": "ppm"
#   },
#   "air_quality": {
#     "value": "Fresh air",
#     "units": ""
#   },
#   "light_value": {
#     "value": 175.0,
#     "units": "Lux"
#   },
#   "visible_light": {
#     "value": 263.0,
#     "units": "Lux"
#   },
#   "ir_light": {
#     "value": 278.0,
#     "units": "Lux"
#   },
#   "mq5_sensor_voltage": {
#     "value": 0.73,
#     "units": "Volts"
#   },
#   "mq5_rs_ratio": {
#     "value": 6.2,
#     "units": ""
#   },
#   "mq5_rs/r0_ratio": {
#     "value": 41.26,
#     "units": ""
#   },
#   "mq9_sensor_voltage": {
#     "value": 0.39,
#     "units": "Volts"
#   },
#   "mq9_rs_ratio": {
#     "value": 12.5,
#     "units": ""
#   },
#   "mq9_rs/r0_ratio": {
#     "value": 83.98,
#     "units": ""
#   },
#   "o2_22.10_n2_gas": {
#     "value": 192.0,
#     "units": ""
#   },
#   "c2h5ch_gas": {
#     "value": 290.0,
#     "units": ""
#   },
#   "voc_gas": {
#     "value": 245.0,
#     "units": ""
#   },
#   "co_gas": {
#     "value": 179.0,
#     "units": ""
#   },
#   "co2": {
#     "value": 606.0,
#     "units": ""
#   },
#   "temperature": {
#     "value": 31.96,
#     "units": "\u00b0C"
#   },
#   "humidity": {
#     "value": 18.98,
#     "units": "%"
#   },
#   "luminance": {
#     "value": 31.21,
#     "units": "cd/m\u00b2"
#   }
# }
# Error: 202
#
# Received data for c950f030-b82c-11ed-b196-bb47e24272bc:node_5.09:
# {
#   "uv_light": {
#     "value": 0.08,
#     "units": "UV Index"
#   },
#   "loudness": {
#     "value": 400.0,
#     "units": "dB"
#   },
#   "pm1.0atmospheric": {
#     "value": 10.0,
#     "units": "\u00b5g/m\u00b3"
#   },
#   "pm2.5atmospheric": {
#     "value": 12.0,
#     "units": "\u00b5g/m\u00b3"
#   },
#   "pm10atmospheric": {
#     "value": 13.0,
#     "units": "\u00b5g/m\u00b3"
#   },
#   "pir_status": {
#     "value": "No Motion Detected",
#     "units": ""
#   },
#   "tvoc_concentration": {
#     "value": 18.0,
#     "units": "ppb"
#   },
#   "co2eq_concentration": {
#     "value": 402.0,
#     "units": "ppm"
#   },
#   "mq2_sensor_voltage": {
#     "value": 0.27,
#     "units": "Volts"
#   },
#   "mq2_rs_ratio": {
#     "value": 15.86,
#     "units": ""
#   },
#   "mq2_rs/r0_ratio": {
#     "value": 159.98,
#     "units": ""
#   },
#   "mq3_sensor_voltage": {
#     "value": 0.34,
#     "units": "Volts"
#   },
#   "mq3_rs_ratio": {
#     "value": 15.86,
#     "units": ""
#   },
#   "mq3_rs/r0_ratio": {
#     "value": 754.21,
#     "units": ""
#   },
#   "hcho_ppm": {
#     "value": 0.01,
#     "units": "ppm"
#   },
#   "air_quality": {
#     "value": "Fresh air",
#     "units": ""
#   },
#   "light_value": {
#     "value": 172.0,
#     "units": "Lux"
#   },
#   "visible_light": {
#     "value": 260.0,
#     "units": "Lux"
#   },
#   "ir_light": {
#     "value": 273.0,
#     "units": "Lux"
#   },
#   "mq5_sensor_voltage": {
#     "value": 0.71,
#     "units": "Volts"
#   },
#   "mq5_rs_ratio": {
#     "value": 5.89,
#     "units": ""
#   },
#   "mq5_rs/r0_ratio": {
#     "value": 40.27,
#     "units": ""
#   },
#   "mq9_sensor_voltage": {
#     "value": 0.38,
#     "units": "Volts"
#   },
#   "mq9_rs_ratio": {
#     "value": 12.25,
#     "units": ""
#   },
#   "mq9_rs/r0_ratio": {
#     "value": 82.1,
#     "units": ""
#   },
#   "o2_22.10_n2_gas": {
#     "value": 194.0,
#     "units": ""
#   },
#   "c2h5ch_gas": {
#     "value": 289.0,
#     "units": ""
#   },
#   "voc_gas": {
#     "value": 251.0,
#     "units": ""
#   },
#   "co_gas": {
#     "value": 179.0,
#     "units": ""
#   },
#   "co2": {
#     "value": 601.0,
#     "units": ""
#   },
#   "temperature": {
#     "value": 31.52,
#     "units": "\u00b0C"
#   },
#   "humidity": {
#     "value": 18.22,
#     "units": "%"
#   },
#   "luminance": {
#     "value": 30.54,
#     "units": "cd/m\u00b2"
#   }
# }
# Error: 202
#
# Received data for cfddba00-b82c-11ed-b196-bb47e24272bc:node_5.10:
# {
#   "uv_light": {
#     "value": 0.05,
#     "units": "UV Index"
#   },
#   "loudness": {
#     "value": 334.0,
#     "units": "dB"
#   },
#   "pm1.0atmospheric": {
#     "value": 8.0,
#     "units": "\u00b5g/m\u00b3"
#   },
#   "pm2.5atmospheric": {
#     "value": 14.0,
#     "units": "\u00b5g/m\u00b3"
#   },
#   "pm10atmospheric": {
#     "value": 14.0,
#     "units": "\u00b5g/m\u00b3"
#   },
#   "pir_status": {
#     "value": "No Motion Detected",
#     "units": ""
#   },
#   "tvoc_concentration": {
#     "value": 18.0,
#     "units": "ppb"
#   },
#   "co2eq_concentration": {
#     "value": 398.0,
#     "units": "ppm"
#   },
#   "mq2_sensor_voltage": {
#     "value": 0.33,
#     "units": "Volts"
#   },
#   "mq2_rs_ratio": {
#     "value": 15.07,
#     "units": ""
#   },
#   "mq2_rs/r0_ratio": {
#     "value": 154.92,
#     "units": ""
#   },
#   "mq3_sensor_voltage": {
#     "value": 0.32,
#     "units": "Volts"
#   },
#   "mq3_rs_ratio": {
#     "value": 15.34,
#     "units": ""
#   },
#   "mq3_rs/r0_ratio": {
#     "value": 767.58,
#     "units": ""
#   },
#   "hcho_ppm": {
#     "value": 0.01,
#     "units": "ppm"
#   },
#   "air_quality": {
#     "value": "Fresh air",
#     "units": ""
#   },
#   "light_value": {
#     "value": 173.0,
#     "units": "Lux"
#   },
#   "visible_light": {
#     "value": 263.0,
#     "units": "Lux"
#   },
#   "ir_light": {
#     "value": 276.0,
#     "units": "Lux"
#   },
#   "mq5_sensor_voltage": {
#     "value": 0.75,
#     "units": "Volts"
#   },
#   "mq5_rs_ratio": {
#     "value": 6.02,
#     "units": ""
#   },
#   "mq5_rs/r0_ratio": {
#     "value": 40.89,
#     "units": ""
#   },
#   "mq9_sensor_voltage": {
#     "value": 0.38,
#     "units": "Volts"
#   },
#   "mq9_rs_ratio": {
#     "value": 12.71,
#     "units": ""
#   },
#   "mq9_rs/r0_ratio": {
#     "value": 83.75,
#     "units": ""
#   },
#   "o2_22.10_n2_gas": {
#     "value": 192.0,
#     "units": ""
#   },
#   "c2h5ch_gas": {
#     "value": 289.0,
#     "units": ""
#   },
#   "voc_gas": {
#     "value": 248.0,
#     "units": ""
#   },
#   "co_gas": {
#     "value": 180.0,
#     "units": ""
#   },
#   "co2": {
#     "value": 607.0,
#     "units": ""
#   },
#   "temperature": {
#     "value": 30.83,
#     "units": "\u00b0C"
#   },
#   "humidity": {
#     "value": 17.78,
#     "units": "%"
#   },
#   "luminance": {
#     "value": 31.22,
#     "units": "cd/m\u00b2"
#   }
# }
# Error: 202
#
# Received data for 278505c0-0f7a-11ee-bf90-a16a1a9e1e0a:node_5.11:
# {
#   "uv_light": {
#     "value": 0.08,
#     "units": "UV Index"
#   },
#   "loudness": {
#     "value": 354.0,
#     "units": "dB"
#   },
#   "pm1.0atmospheric": {
#     "value": 8.0,
#     "units": "\u00b5g/m\u00b3"
#   },
#   "pm2.5atmospheric": {
#     "value": 13.0,
#     "units": "\u00b5g/m\u00b3"
#   },
#   "pm10atmospheric": {
#     "value": 12.0,
#     "units": "\u00b5g/m\u00b3"
#   },
#   "pir_status": {
#     "value": "No Motion Detected",
#     "units": ""
#   },
#   "tvoc_concentration": {
#     "value": 20.0,
#     "units": "ppb"
#   },
#   "co2eq_concentration": {
#     "value": 400.0,
#     "units": "ppm"
#   },
#   "mq2_sensor_voltage": {
#     "value": 0.25,
#     "units": "Volts"
#   },
#   "mq2_rs_ratio": {
#     "value": 15.08,
#     "units": ""
#   },
#   "mq2_rs/r0_ratio": {
#     "value": 156.55,
#     "units": ""
#   },
#   "mq3_sensor_voltage": {
#     "value": 0.34,
#     "units": "Volts"
#   },
#   "mq3_rs_ratio": {
#     "value": 14.98,
#     "units": ""
#   },
#   "mq3_rs/r0_ratio": {
#     "value": 754.05,
#     "units": ""
#   },
#   "hcho_ppm": {
#     "value": 0.0,
#     "units": "ppm"
#   },
#   "air_quality": {
#     "value": "Fresh air",
#     "units": ""
#   },
#   "light_value": {
#     "value": 170.0,
#     "units": "Lux"
#   },
#   "visible_light": {
#     "value": 263.0,
#     "units": "Lux"
#   },
#   "ir_light": {
#     "value": 273.0,
#     "units": "Lux"
#   },
#   "mq5_sensor_voltage": {
#     "value": 0.75,
#     "units": "Volts"
#   },
#   "mq5_rs_ratio": {
#     "value": 6.03,
#     "units": ""
#   },
#   "mq5_rs/r0_ratio": {
#     "value": 41.97,
#     "units": ""
#   },
#   "mq9_sensor_voltage": {
#     "value": 0.4,
#     "units": "Volts"
#   },
#   "mq9_rs_ratio": {
#     "value": 12.91,
#     "units": ""
#   },
#   "mq9_rs/r0_ratio": {
#     "value": 82.02,
#     "units": ""
#   },
#   "o2_22.10_n2_gas": {
#     "value": 196.0,
#     "units": ""
#   },
#   "c2h5ch_gas": {
#     "value": 289.0,
#     "units": ""
#   },
#   "voc_gas": {
#     "value": 246.0,
#     "units": ""
#   },
#   "co_gas": {
#     "value": 176.0,
#     "units": ""
#   },
#   "co2": {
#     "value": 608.0,
#     "units": ""
#   },
#   "temperature": {
#     "value": 31.37,
#     "units": "\u00b0C"
#   },
#   "humidity": {
#     "value": 17.25,
#     "units": "%"
#   },
#   "luminance": {
#     "value": 30.1,
#     "units": "cd/m\u00b2"
#   }
# }
# Error: 202
#
# Received data for d9576a90-b82c-11ed-b196-bb47e24272bc:node_5.12:
# {
#   "uv_light": {
#     "value": 0.03,
#     "units": "UV Index"
#   },
#   "loudness": {
#     "value": 350.0,
#     "units": "dB"
#   },
#   "pm1.0atmospheric": {
#     "value": 8.0,
#     "units": "\u00b5g/m\u00b3"
#   },
#   "pm2.5atmospheric": {
#     "value": 14.0,
#     "units": "\u00b5g/m\u00b3"
#   },
#   "pm10atmospheric": {
#     "value": 14.0,
#     "units": "\u00b5g/m\u00b3"
#   },
#   "pir_status": {
#     "value": "No Motion Detected",
#     "units": ""
#   },
#   "tvoc_concentration": {
#     "value": 18.0,
#     "units": "ppb"
#   },
#   "co2eq_concentration": {
#     "value": 395.0,
#     "units": "ppm"
#   },
#   "mq2_sensor_voltage": {
#     "value": 0.27,
#     "units": "Volts"
#   },
#   "mq2_rs_ratio": {
#     "value": 15.6,
#     "units": ""
#   },
#   "mq2_rs/r0_ratio": {
#     "value": 157.16,
#     "units": ""
#   },
#   "mq3_sensor_voltage": {
#     "value": 0.35,
#     "units": "Volts"
#   },
#   "mq3_rs_ratio": {
#     "value": 15.16,
#     "units": ""
#   },
#   "mq3_rs/r0_ratio": {
#     "value": 752.6,
#     "units": ""
#   },
#   "hcho_ppm": {
#     "value": 0.01,
#     "units": "ppm"
#   },
#   "air_quality": {
#     "value": "Fresh air",
#     "units": ""
#   },
#   "light_value": {
#     "value": 171.0,
#     "units": "Lux"
#   },
#   "visible_light": {
#     "value": 260.0,
#     "units": "Lux"
#   },
#   "ir_light": {
#     "value": 273.0,
#     "units": "Lux"
#   },
#   "mq5_sensor_voltage": {
#     "value": 0.68,
#     "units": "Volts"
#   },
#   "mq5_rs_ratio": {
#     "value": 5.9,
#     "units": ""
#   },
#   "mq5_rs/r0_ratio": {
#     "value": 41.85,
#     "units": ""
#   },
#   "mq9_sensor_voltage": {
#     "value": 0.39,
#     "units": "Volts"
#   },
#   "mq9_rs_ratio": {
#     "value": 12.25,
#     "units": ""
#   },
#   "mq9_rs/r0_ratio": {
#     "value": 83.22,
#     "units": ""
#   },
#   "o2_22.10_n2_gas": {
#     "value": 194.0,
#     "units": ""
#   },
#   "c2h5ch_gas": {
#     "value": 290.0,
#     "units": ""
#   },
#   "voc_gas": {
#     "value": 246.0,
#     "units": ""
#   },
#   "co_gas": {
#     "value": 179.0,
#     "units": ""
#   },
#   "co2": {
#     "value": 604.0,
#     "units": ""
#   },
#   "temperature": {
#     "value": 31.77,
#     "units": "\u00b0C"
#   },
#   "humidity": {
#     "value": 17.57,
#     "units": "%"
#   },
#   "luminance": {
#     "value": 30.03,
#     "units": "cd/m\u00b2"
#   }
# }
# Error: 202
#
# Received data for de18ea40-b82c-11ed-b196-bb47e24272bc:node_5.13:
# {
#   "uv_light": {
#     "value": 0.01,
#     "units": "UV Index"
#   },
#   "loudness": {
#     "value": 367.0,
#     "units": "dB"
#   },
#   "pm1.0atmospheric": {
#     "value": 8.0,
#     "units": "\u00b5g/m\u00b3"
#   },
#   "pm2.5atmospheric": {
#     "value": 14.0,
#     "units": "\u00b5g/m\u00b3"
#   },
#   "pm10atmospheric": {
#     "value": 13.0,
#     "units": "\u00b5g/m\u00b3"
#   },
#   "pir_status": {
#     "value": "No Motion Detected",
#     "units": ""
#   },
#   "tvoc_concentration": {
#     "value": 18.0,
#     "units": "ppb"
#   },
#   "co2eq_concentration": {
#     "value": 401.0,
#     "units": "ppm"
#   },
#   "mq2_sensor_voltage": {
#     "value": 0.34,
#     "units": "Volts"
#   },
#   "mq2_rs_ratio": {
#     "value": 15.02,
#     "units": ""
#   },
#   "mq2_rs/r0_ratio": {
#     "value": 153.49,
#     "units": ""
#   },
#   "mq3_sensor_voltage": {
#     "value": 0.31,
#     "units": "Volts"
#   },
#   "mq3_rs_ratio": {
#     "value": 14.24,
#     "units": ""
#   },
#   "mq3_rs/r0_ratio": {
#     "value": 760.15,
#     "units": ""
#   },
#   "hcho_ppm": {
#     "value": 0.01,
#     "units": "ppm"
#   },
#   "air_quality": {
#     "value": "Fresh air",
#     "units": ""
#   },
#   "light_value": {
#     "value": 171.0,
#     "units": "Lux"
#   },
#   "visible_light": {
#     "value": 264.0,
#     "units": "Lux"
#   },
#   "ir_light": {
#     "value": 275.0,
#     "units": "Lux"
#   },
#   "mq5_sensor_voltage": {
#     "value": 0.73,
#     "units": "Volts"
#   },
#   "mq5_rs_ratio": {
#     "value": 6.04,
#     "units": ""
#   },
#   "mq5_rs/r0_ratio": {
#     "value": 41.13,
#     "units": ""
#   },
#   "mq9_sensor_voltage": {
#     "value": 0.36,
#     "units": "Volts"
#   },
#   "mq9_rs_ratio": {
#     "value": 12.34,
#     "units": ""
#   },
#   "mq9_rs/r0_ratio": {
#     "value": 82.87,
#     "units": ""
#   },
#   "o2_22.10_n2_gas": {
#     "value": 196.0,
#     "units": ""
#   },
#   "c2h5ch_gas": {
#     "value": 291.0,
#     "units": ""
#   },
#   "voc_gas": {
#     "value": 249.0,
#     "units": ""
#   },
#   "co_gas": {
#     "value": 179.0,
#     "units": ""
#   },
#   "co2": {
#     "value": 598.0,
#     "units": ""
#   },
#   "temperature": {
#     "value": 31.54,
#     "units": "\u00b0C"
#   },
#   "humidity": {
#     "value": 17.42,
#     "units": "%"
#   },
#   "luminance": {
#     "value": 30.42,
#     "units": "cd/m\u00b2"
#   }
# }
# Error: 202
#
# Received data for f57a1560-7cf3-11ee-94bc-d389020903a3:node_5.14:
# {
#   "uv_light": {
#     "value": 0.1,
#     "units": "UV Index"
#   },
#   "loudness": {
#     "value": 341.0,
#     "units": "dB"
#   },
#   "pm1.0atmospheric": {
#     "value": 9.0,
#     "units": "\u00b5g/m\u00b3"
#   },
#   "pm2.5atmospheric": {
#     "value": 14.0,
#     "units": "\u00b5g/m\u00b3"
#   },
#   "pm10atmospheric": {
#     "value": 13.0,
#     "units": "\u00b5g/m\u00b3"
#   },
#   "pir_status": {
#     "value": "No Motion Detected",
#     "units": ""
#   },
#   "tvoc_concentration": {
#     "value": 20.0,
#     "units": "ppb"
#   },
#   "co2eq_concentration": {
#     "value": 402.0,
#     "units": "ppm"
#   },
#   "mq2_sensor_voltage": {
#     "value": 0.3,
#     "units": "Volts"
#   },
#   "mq2_rs_ratio": {
#     "value": 15.29,
#     "units": ""
#   },
#   "mq2_rs/r0_ratio": {
#     "value": 154.07,
#     "units": ""
#   },
#   "mq3_sensor_voltage": {
#     "value": 0.31,
#     "units": "Volts"
#   },
#   "mq3_rs_ratio": {
#     "value": 14.07,
#     "units": ""
#   },
#   "mq3_rs/r0_ratio": {
#     "value": 760.1,
#     "units": ""
#   },
#   "hcho_ppm": {
#     "value": 0.01,
#     "units": "ppm"
#   },
#   "air_quality": {
#     "value": "Fresh air",
#     "units": ""
#   },
#   "light_value": {
#     "value": 172.0,
#     "units": "Lux"
#   },
#   "visible_light": {
#     "value": 262.0,
#     "units": "Lux"
#   },
#   "ir_light": {
#     "value": 270.0,
#     "units": "Lux"
#   },
#   "mq5_sensor_voltage": {
#     "value": 0.68,
#     "units": "Volts"
#   },
#   "mq5_rs_ratio": {
#     "value": 6.04,
#     "units": ""
#   },
#   "mq5_rs/r0_ratio": {
#     "value": 41.37,
#     "units": ""
#   },
#   "mq9_sensor_voltage": {
#     "value": 0.35,
#     "units": "Volts"
#   },
#   "mq9_rs_ratio": {
#     "value": 12.35,
#     "units": ""
#   },
#   "mq9_rs/r0_ratio": {
#     "value": 82.06,
#     "units": ""
#   },
#   "o2_22.10_n2_gas": {
#     "value": 195.0,
#     "units": ""
#   },
#   "c2h5ch_gas": {
#     "value": 291.0,
#     "units": ""
#   },
#   "voc_gas": {
#     "value": 250.0,
#     "units": ""
#   },
#   "co_gas": {
#     "value": 178.0,
#     "units": ""
#   },
#   "co2": {
#     "value": 602.0,
#     "units": ""
#   },
#   "temperature": {
#     "value": 31.63,
#     "units": "\u00b0C"
#   },
#   "humidity": {
#     "value": 17.48,
#     "units": "%"
#   },
#   "luminance": {
#     "value": 31.34,
#     "units": "cd/m\u00b2"
#   }
# }
# Error: 202
#
# Received data for 508d1b60-57eb-11ee-8714-19d56ba0c4fd:node_5.15:
# {
#   "uv_light": {
#     "value": 0.07,
#     "units": "UV Index"
#   },
#   "loudness": {
#     "value": 378.0,
#     "units": "dB"
#   },
#   "pm1.0atmospheric": {
#     "value": 9.0,
#     "units": "\u00b5g/m\u00b3"
#   },
#   "pm2.5atmospheric": {
#     "value": 12.0,
#     "units": "\u00b5g/m\u00b3"
#   },
#   "pm10atmospheric": {
#     "value": 14.0,
#     "units": "\u00b5g/m\u00b3"
#   },
#   "pir_status": {
#     "value": "No Motion Detected",
#     "units": ""
#   },
#   "tvoc_concentration": {
#     "value": 19.0,
#     "units": "ppb"
#   },
#   "co2eq_concentration": {
#     "value": 392.0,
#     "units": "ppm"
#   },
#   "mq2_sensor_voltage": {
#     "value": 0.31,
#     "units": "Volts"
#   },
#   "mq2_rs_ratio": {
#     "value": 15.17,
#     "units": ""
#   },
#   "mq2_rs/r0_ratio": {
#     "value": 151.99,
#     "units": ""
#   },
#   "mq3_sensor_voltage": {
#     "value": 0.32,
#     "units": "Volts"
#   },
#   "mq3_rs_ratio": {
#     "value": 14.04,
#     "units": ""
#   },
#   "mq3_rs/r0_ratio": {
#     "value": 764.87,
#     "units": ""
#   },
#   "hcho_ppm": {
#     "value": 0.01,
#     "units": "ppm"
#   },
#   "air_quality": {
#     "value": "Fresh air",
#     "units": ""
#   },
#   "light_value": {
#     "value": 173.0,
#     "units": "Lux"
#   },
#   "visible_light": {
#     "value": 265.0,
#     "units": "Lux"
#   },
#   "ir_light": {
#     "value": 271.0,
#     "units": "Lux"
#   },
#   "mq5_sensor_voltage": {
#     "value": 0.69,
#     "units": "Volts"
#   },
#   "mq5_rs_ratio": {
#     "value": 5.88,
#     "units": ""
#   },
#   "mq5_rs/r0_ratio": {
#     "value": 40.33,
#     "units": ""
#   },
#   "mq9_sensor_voltage": {
#     "value": 0.38,
#     "units": "Volts"
#   },
#   "mq9_rs_ratio": {
#     "value": 12.48,
#     "units": ""
#   },
#   "mq9_rs/r0_ratio": {
#     "value": 82.68,
#     "units": ""
#   },
#   "o2_22.10_n2_gas": {
#     "value": 196.0,
#     "units": ""
#   },
#   "c2h5ch_gas": {
#     "value": 289.0,
#     "units": ""
#   },
#   "voc_gas": {
#     "value": 250.0,
#     "units": ""
#   },
#   "co_gas": {
#     "value": 182.0,
#     "units": ""
#   },
#   "co2": {
#     "value": 608.0,
#     "units": ""
#   },
#   "temperature": {
#     "value": 30.59,
#     "units": "\u00b0C"
#   },
#   "humidity": {
#     "value": 17.08,
#     "units": "%"
#   },
#   "luminance": {
#     "value": 30.97,
#     "units": "cd/m\u00b2"
#   }
# }
# Error: 202
#
# Received data for 86c63bd0-57f0-11ee-8714-19d56ba0c4fd:node_5.16:
# {
#   "uv_light": {
#     "value": 0.02,
#     "units": "UV Index"
#   },
#   "loudness": {
#     "value": 367.0,
#     "units": "dB"
#   },
#   "pm1.0atmospheric": {
#     "value": 9.0,
#     "units": "\u00b5g/m\u00b3"
#   },
#   "pm2.5atmospheric": {
#     "value": 12.0,
#     "units": "\u00b5g/m\u00b3"
#   },
#   "pm10atmospheric": {
#     "value": 13.0,
#     "units": "\u00b5g/m\u00b3"
#   },
#   "pir_status": {
#     "value": "No Motion Detected",
#     "units": ""
#   },
#   "tvoc_concentration": {
#     "value": 20.0,
#     "units": "ppb"
#   },
#   "co2eq_concentration": {
#     "value": 402.0,
#     "units": "ppm"
#   },
#   "mq2_sensor_voltage": {
#     "value": 0.27,
#     "units": "Volts"
#   },
#   "mq2_rs_ratio": {
#     "value": 15.51,
#     "units": ""
#   },
#   "mq2_rs/r0_ratio": {
#     "value": 156.18,
#     "units": ""
#   },
#   "mq3_sensor_voltage": {
#     "value": 0.3,
#     "units": "Volts"
#   },
#   "mq3_rs_ratio": {
#     "value": 15.14,
#     "units": ""
#   },
#   "mq3_rs/r0_ratio": {
#     "value": 764.13,
#     "units": ""
#   },
#   "hcho_ppm": {
#     "value": 0.01,
#     "units": "ppm"
#   },
#   "air_quality": {
#     "value": "Fresh air",
#     "units": ""
#   },
#   "light_value": {
#     "value": 170.0,
#     "units": "Lux"
#   },
#   "visible_light": {
#     "value": 260.0,
#     "units": "Lux"
#   },
#   "ir_light": {
#     "value": 274.0,
#     "units": "Lux"
#   },
#   "mq5_sensor_voltage": {
#     "value": 0.69,
#     "units": "Volts"
#   },
#   "mq5_rs_ratio": {
#     "value": 5.83,
#     "units": ""
#   },
#   "mq5_rs/r0_ratio": {
#     "value": 41.98,
#     "units": ""
#   },
#   "mq9_sensor_voltage": {
#     "value": 0.38,
#     "units": "Volts"
#   },
#   "mq9_rs_ratio": {
#     "value": 12.5,
#     "units": ""
#   },
#   "mq9_rs/r0_ratio": {
#     "value": 82.66,
#     "units": ""
#   },
#   "o2_22.10_n2_gas": {
#     "value": 196.0,
#     "units": ""
#   },
#   "c2h5ch_gas": {
#     "value": 289.0,
#     "units": ""
#   },
#   "voc_gas": {
#     "value": 251.0,
#     "units": ""
#   },
#   "co_gas": {
#     "value": 182.0,
#     "units": ""
#   },
#   "co2": {
#     "value": 600.0,
#     "units": ""
#   },
#   "temperature": {
#     "value": 30.96,
#     "units": "\u00b0C"
#   },
#   "humidity": {
#     "value": 18.09,
#     "units": "%"
#   },
#   "luminance": {
#     "value": 31.58,
#     "units": "cd/m\u00b2"
#   }
# }
# Error: 202
#
# Received data for 3efd82d0-7cf4-11ee-94bc-d389020903a3:node_5.17:
# {
#   "uv_light": {
#     "value": 0.09,
#     "units": "UV Index"
#   },
#   "loudness": {
#     "value": 302.0,
#     "units": "dB"
#   },
#   "pm1.0atmospheric": {
#     "value": 10.0,
#     "units": "\u00b5g/m\u00b3"
#   },
#   "pm2.5atmospheric": {
#     "value": 14.0,
#     "units": "\u00b5g/m\u00b3"
#   },
#   "pm10atmospheric": {
#     "value": 12.0,
#     "units": "\u00b5g/m\u00b3"
#   },
#   "pir_status": {
#     "value": "No Motion Detected",
#     "units": ""
#   },
#   "tvoc_concentration": {
#     "value": 20.0,
#     "units": "ppb"
#   },
#   "co2eq_concentration": {
#     "value": 406.0,
#     "units": "ppm"
#   },
#   "mq2_sensor_voltage": {
#     "value": 0.26,
#     "units": "Volts"
#   },
#   "mq2_rs_ratio": {
#     "value": 15.79,
#     "units": ""
#   },
#   "mq2_rs/r0_ratio": {
#     "value": 159.56,
#     "units": ""
#   },
#   "mq3_sensor_voltage": {
#     "value": 0.34,
#     "units": "Volts"
#   },
#   "mq3_rs_ratio": {
#     "value": 15.78,
#     "units": ""
#   },
#   "mq3_rs/r0_ratio": {
#     "value": 750.56,
#     "units": ""
#   },
#   "hcho_ppm": {
#     "value": 0.01,
#     "units": "ppm"
#   },
#   "air_quality": {
#     "value": "Fresh air",
#     "units": ""
#   },
#   "light_value": {
#     "value": 171.0,
#     "units": "Lux"
#   },
#   "visible_light": {
#     "value": 260.0,
#     "units": "Lux"
#   },
#   "ir_light": {
#     "value": 272.0,
#     "units": "Lux"
#   },
#   "mq5_sensor_voltage": {
#     "value": 0.74,
#     "units": "Volts"
#   },
#   "mq5_rs_ratio": {
#     "value": 5.95,
#     "units": ""
#   },
#   "mq5_rs/r0_ratio": {
#     "value": 40.53,
#     "units": ""
#   },
#   "mq9_sensor_voltage": {
#     "value": 0.4,
#     "units": "Volts"
#   },
#   "mq9_rs_ratio": {
#     "value": 12.65,
#     "units": ""
#   },
#   "mq9_rs/r0_ratio": {
#     "value": 83.78,
#     "units": ""
#   },
#   "o2_22.10_n2_gas": {
#     "value": 192.0,
#     "units": ""
#   },
#   "c2h5ch_gas": {
#     "value": 291.0,
#     "units": ""
#   },
#   "voc_gas": {
#     "value": 247.0,
#     "units": ""
#   },
#   "co_gas": {
#     "value": 178.0,
#     "units": ""
#   },
#   "co2": {
#     "value": 608.0,
#     "units": ""
#   },
#   "temperature": {
#     "value": 30.14,
#     "units": "\u00b0C"
#   },
#   "humidity": {
#     "value": 17.52,
#     "units": "%"
#   },
#   "luminance": {
#     "value": 30.78,
#     "units": "cd/m\u00b2"
#   }
# }
# Error: 202
#
# Received data for f583bc50-57e6-11ee-8714-19d56ba0c4fd:node_5.18:
# {
#   "uv_light": {
#     "value": 0.05,
#     "units": "UV Index"
#   },
#   "loudness": {
#     "value": 357.0,
#     "units": "dB"
#   },
#   "pm1.0atmospheric": {
#     "value": 9.0,
#     "units": "\u00b5g/m\u00b3"
#   },
#   "pm2.5atmospheric": {
#     "value": 12.0,
#     "units": "\u00b5g/m\u00b3"
#   },
#   "pm10atmospheric": {
#     "value": 14.0,
#     "units": "\u00b5g/m\u00b3"
#   },
#   "pir_status": {
#     "value": "No Motion Detected",
#     "units": ""
#   },
#   "tvoc_concentration": {
#     "value": 19.0,
#     "units": "ppb"
#   },
#   "co2eq_concentration": {
#     "value": 392.0,
#     "units": "ppm"
#   },
#   "mq2_sensor_voltage": {
#     "value": 0.31,
#     "units": "Volts"
#   },
#   "mq2_rs_ratio": {
#     "value": 15.8,
#     "units": ""
#   },
#   "mq2_rs/r0_ratio": {
#     "value": 156.37,
#     "units": ""
#   },
#   "mq3_sensor_voltage": {
#     "value": 0.31,
#     "units": "Volts"
#   },
#   "mq3_rs_ratio": {
#     "value": 14.36,
#     "units": ""
#   },
#   "mq3_rs/r0_ratio": {
#     "value": 766.75,
#     "units": ""
#   },
#   "hcho_ppm": {
#     "value": 0.01,
#     "units": "ppm"
#   },
#   "air_quality": {
#     "value": "Fresh air",
#     "units": ""
#   },
#   "light_value": {
#     "value": 175.0,
#     "units": "Lux"
#   },
#   "visible_light": {
#     "value": 264.0,
#     "units": "Lux"
#   },
#   "ir_light": {
#     "value": 280.0,
#     "units": "Lux"
#   },
#   "mq5_sensor_voltage": {
#     "value": 0.75,
#     "units": "Volts"
#   },
#   "mq5_rs_ratio": {
#     "value": 6.15,
#     "units": ""
#   },
#   "mq5_rs/r0_ratio": {
#     "value": 40.92,
#     "units": ""
#   },
#   "mq9_sensor_voltage": {
#     "value": 0.4,
#     "units": "Volts"
#   },
#   "mq9_rs_ratio": {
#     "value": 12.88,
#     "units": ""
#   },
#   "mq9_rs/r0_ratio": {
#     "value": 82.9,
#     "units": ""
#   },
#   "o2_22.10_n2_gas": {
#     "value": 193.0,
#     "units": ""
#   },
#   "c2h5ch_gas": {
#     "value": 289.0,
#     "units": ""
#   },
#   "voc_gas": {
#     "value": 246.0,
#     "units": ""
#   },
#   "co_gas": {
#     "value": 176.0,
#     "units": ""
#   },
#   "co2": {
#     "value": 606.0,
#     "units": ""
#   },
#   "temperature": {
#     "value": 31.31,
#     "units": "\u00b0C"
#   },
#   "humidity": {
#     "value": 17.21,
#     "units": "%"
#   },
#   "luminance": {
#     "value": 31.31,
#     "units": "cd/m\u00b2"
#   }
# }
# Error: 202
#
# Received data for 9458c560-0f75-11ee-bf90-a16a1a9e1e0a:node_5.19:
# {
#   "uv_light": {
#     "value": 0.04,
#     "units": "UV Index"
#   },
#   "loudness": {
#     "value": 323.0,
#     "units": "dB"
#   },
#   "pm1.0atmospheric": {
#     "value": 8.0,
#     "units": "\u00b5g/m\u00b3"
#   },
#   "pm2.5atmospheric": {
#     "value": 12.0,
#     "units": "\u00b5g/m\u00b3"
#   },
#   "pm10atmospheric": {
#     "value": 14.0,
#     "units": "\u00b5g/m\u00b3"
#   },
#   "pir_status": {
#     "value": "No Motion Detected",
#     "units": ""
#   },
#   "tvoc_concentration": {
#     "value": 18.0,
#     "units": "ppb"
#   },
#   "co2eq_concentration": {
#     "value": 404.0,
#     "units": "ppm"
#   },
#   "mq2_sensor_voltage": {
#     "value": 0.28,
#     "units": "Volts"
#   },
#   "mq2_rs_ratio": {
#     "value": 15.21,
#     "units": ""
#   },
#   "mq2_rs/r0_ratio": {
#     "value": 153.97,
#     "units": ""
#   },
#   "mq3_sensor_voltage": {
#     "value": 0.32,
#     "units": "Volts"
#   },
#   "mq3_rs_ratio": {
#     "value": 15.35,
#     "units": ""
#   },
#   "mq3_rs/r0_ratio": {
#     "value": 754.06,
#     "units": ""
#   },
#   "hcho_ppm": {
#     "value": 0.0,
#     "units": "ppm"
#   },
#   "air_quality": {
#     "value": "Fresh air",
#     "units": ""
#   },
#   "light_value": {
#     "value": 170.0,
#     "units": "Lux"
#   },
#   "visible_light": {
#     "value": 265.0,
#     "units": "Lux"
#   },
#   "ir_light": {
#     "value": 271.0,
#     "units": "Lux"
#   },
#   "mq5_sensor_voltage": {
#     "value": 0.67,
#     "units": "Volts"
#   },
#   "mq5_rs_ratio": {
#     "value": 6.2,
#     "units": ""
#   },
#   "mq5_rs/r0_ratio": {
#     "value": 41.6,
#     "units": ""
#   },
#   "mq9_sensor_voltage": {
#     "value": 0.37,
#     "units": "Volts"
#   },
#   "mq9_rs_ratio": {
#     "value": 12.53,
#     "units": ""
#   },
#   "mq9_rs/r0_ratio": {
#     "value": 82.13,
#     "units": ""
#   },
#   "o2_22.10_n2_gas": {
#     "value": 195.0,
#     "units": ""
#   },
#   "c2h5ch_gas": {
#     "value": 290.0,
#     "units": ""
#   },
#   "voc_gas": {
#     "value": 249.0,
#     "units": ""
#   },
#   "co_gas": {
#     "value": 181.0,
#     "units": ""
#   },
#   "co2": {
#     "value": 600.0,
#     "units": ""
#   },
#   "temperature": {
#     "value": 31.91,
#     "units": "\u00b0C"
#   },
#   "humidity": {
#     "value": 17.3,
#     "units": "%"
#   },
#   "luminance": {
#     "value": 31.96,
#     "units": "cd/m\u00b2"
#   }
# }
# Error: 202
#
# Received data for cbc851c0-57ee-11ee-8714-19d56ba0c4fd:node_5.20:
# {
#   "uv_light": {
#     "value": 0.04,
#     "units": "UV Index"
#   },
#   "loudness": {
#     "value": 380.0,
#     "units": "dB"
#   },
#   "pm1.0atmospheric": {
#     "value": 10.0,
#     "units": "\u00b5g/m\u00b3"
#   },
#   "pm2.5atmospheric": {
#     "value": 13.0,
#     "units": "\u00b5g/m\u00b3"
#   },
#   "pm10atmospheric": {
#     "value": 12.0,
#     "units": "\u00b5g/m\u00b3"
#   },
#   "pir_status": {
#     "value": "No Motion Detected",
#     "units": ""
#   },
#   "tvoc_concentration": {
#     "value": 20.0,
#     "units": "ppb"
#   },
#   "co2eq_concentration": {
#     "value": 399.0,
#     "units": "ppm"
#   },
#   "mq2_sensor_voltage": {
#     "value": 0.29,
#     "units": "Volts"
#   },
#   "mq2_rs_ratio": {
#     "value": 15.55,
#     "units": ""
#   },
#   "mq2_rs/r0_ratio": {
#     "value": 159.12,
#     "units": ""
#   },
#   "mq3_sensor_voltage": {
#     "value": 0.35,
#     "units": "Volts"
#   },
#   "mq3_rs_ratio": {
#     "value": 14.65,
#     "units": ""
#   },
#   "mq3_rs/r0_ratio": {
#     "value": 751.18,
#     "units": ""
#   },
#   "hcho_ppm": {
#     "value": 0.01,
#     "units": "ppm"
#   },
#   "air_quality": {
#     "value": "Fresh air",
#     "units": ""
#   },
#   "light_value": {
#     "value": 172.0,
#     "units": "Lux"
#   },
#   "visible_light": {
#     "value": 263.0,
#     "units": "Lux"
#   },
#   "ir_light": {
#     "value": 270.0,
#     "units": "Lux"
#   },
#   "mq5_sensor_voltage": {
#     "value": 0.67,
#     "units": "Volts"
#   },
#   "mq5_rs_ratio": {
#     "value": 5.85,
#     "units": ""
#   },
#   "mq5_rs/r0_ratio": {
#     "value": 41.85,
#     "units": ""
#   },
#   "mq9_sensor_voltage": {
#     "value": 0.36,
#     "units": "Volts"
#   },
#   "mq9_rs_ratio": {
#     "value": 12.83,
#     "units": ""
#   },
#   "mq9_rs/r0_ratio": {
#     "value": 83.12,
#     "units": ""
#   },
#   "o2_22.10_n2_gas": {
#     "value": 196.0,
#     "units": ""
#   },
#   "c2h5ch_gas": {
#     "value": 289.0,
#     "units": ""
#   },
#   "voc_gas": {
#     "value": 246.0,
#     "units": ""
#   },
#   "co_gas": {
#     "value": 181.0,
#     "units": ""
#   },
#   "co2": {
#     "value": 608.0,
#     "units": ""
#   },
#   "temperature": {
#     "value": 30.27,
#     "units": "\u00b0C"
#   },
#   "humidity": {
#     "value": 18.5,
#     "units": "%"
#   },
#   "luminance": {
#     "value": 30.36,
#     "units": "cd/m\u00b2"
#   }
# }
# Error: 202
#
# Received data for 2ae959b0-53c6-11ee-8714-19d56ba0c4fd:node_5.21:
# {
#   "uv_light": {
#     "value": 0.06,
#     "units": "UV Index"
#   },
#   "loudness": {
#     "value": 336.0,
#     "units": "dB"
#   },
#   "pm1.0atmospheric": {
#     "value": 8.0,
#     "units": "\u00b5g/m\u00b3"
#   },
#   "pm2.5atmospheric": {
#     "value": 13.0,
#     "units": "\u00b5g/m\u00b3"
#   },
#   "pm10atmospheric": {
#     "value": 14.0,
#     "units": "\u00b5g/m\u00b3"
#   },
#   "pir_status": {
#     "value": "No Motion Detected",
#     "units": ""
#   },
#   "tvoc_concentration": {
#     "value": 20.0,
#     "units": "ppb"
#   },
#   "co2eq_concentration": {
#     "value": 405.0,
#     "units": "ppm"
#   },
#   "mq2_sensor_voltage": {
#     "value": 0.29,
#     "units": "Volts"
#   },
#   "mq2_rs_ratio": {
#     "value": 15.9,
#     "units": ""
#   },
#   "mq2_rs/r0_ratio": {
#     "value": 153.3,
#     "units": ""
#   },
#   "mq3_sensor_voltage": {
#     "value": 0.34,
#     "units": "Volts"
#   },
#   "mq3_rs_ratio": {
#     "value": 15.99,
#     "units": ""
#   },
#   "mq3_rs/r0_ratio": {
#     "value": 751.5,
#     "units": ""
#   },
#   "hcho_ppm": {
#     "value": 0.01,
#     "units": "ppm"
#   },
#   "air_quality": {
#     "value": "Fresh air",
#     "units": ""
#   },
#   "light_value": {
#     "value": 173.0,
#     "units": "Lux"
#   },
#   "visible_light": {
#     "value": 262.0,
#     "units": "Lux"
#   },
#   "ir_light": {
#     "value": 275.0,
#     "units": "Lux"
#   },
#   "mq5_sensor_voltage": {
#     "value": 0.73,
#     "units": "Volts"
#   },
#   "mq5_rs_ratio": {
#     "value": 6.15,
#     "units": ""
#   },
#   "mq5_rs/r0_ratio": {
#     "value": 41.38,
#     "units": ""
#   },
#   "mq9_sensor_voltage": {
#     "value": 0.37,
#     "units": "Volts"
#   },
#   "mq9_rs_ratio": {
#     "value": 12.07,
#     "units": ""
#   },
#   "mq9_rs/r0_ratio": {
#     "value": 82.54,
#     "units": ""
#   },
#   "o2_22.10_n2_gas": {
#     "value": 194.0,
#     "units": ""
#   },
#   "c2h5ch_gas": {
#     "value": 287.0,
#     "units": ""
#   },
#   "voc_gas": {
#     "value": 250.0,
#     "units": ""
#   },
#   "co_gas": {
#     "value": 181.0,
#     "units": ""
#   },
#   "co2": {
#     "value": 607.0,
#     "units": ""
#   },
#   "temperature": {
#     "value": 31.9,
#     "units": "\u00b0C"
#   },
#   "humidity": {
#     "value": 18.73,
#     "units": "%"
#   },
#   "luminance": {
#     "value": 31.47,
#     "units": "cd/m\u00b2"
#   }
# }
# Error: 202
#
# Received data for 351b0eb0-57ef-11ee-8714-19d56ba0c4fd:node_5.22:
# {
#   "uv_light": {
#     "value": 0.07,
#     "units": "UV Index"
#   },
#   "loudness": {
#     "value": 356.0,
#     "units": "dB"
#   },
#   "pm1.0atmospheric": {
#     "value": 9.0,
#     "units": "\u00b5g/m\u00b3"
#   },
#   "pm2.5atmospheric": {
#     "value": 14.0,
#     "units": "\u00b5g/m\u00b3"
#   },
#   "pm10atmospheric": {
#     "value": 13.0,
#     "units": "\u00b5g/m\u00b3"
#   },
#   "pir_status": {
#     "value": "No Motion Detected",
#     "units": ""
#   },
#   "tvoc_concentration": {
#     "value": 19.0,
#     "units": "ppb"
#   },
#   "co2eq_concentration": {
#     "value": 403.0,
#     "units": "ppm"
#   },
#   "mq2_sensor_voltage": {
#     "value": 0.26,
#     "units": "Volts"
#   },
#   "mq2_rs_ratio": {
#     "value": 15.47,
#     "units": ""
#   },
#   "mq2_rs/r0_ratio": {
#     "value": 154.4,
#     "units": ""
#   },
#   "mq3_sensor_voltage": {
#     "value": 0.31,
#     "units": "Volts"
#   },
#   "mq3_rs_ratio": {
#     "value": 14.98,
#     "units": ""
#   },
#   "mq3_rs/r0_ratio": {
#     "value": 758.84,
#     "units": ""
#   },
#   "hcho_ppm": {
#     "value": 0.0,
#     "units": "ppm"
# ...
#     "units": ""
#   },
#   "voc_gas": {
#     "value": 245.0,
#     "units": ""
#   },
#   "co_gas": {
#     "value": 182.0,
#     "units": ""
#   },
#   "co2": {
#     "value": 598.0,
#     "units": ""
#   },
#   "temperature": {
#     "value": 30.36,
#     "units": "\u00b0C"
#   },
#   "humidity": {
#     "value": 18.68,
#     "units": "%"
#   },
#   "luminance": {
#     "value": 31.39,
#     "units": "cd/m\u00b2"
#   }
# }
# Error: 202
#
# Received data for cbc851c0-57ee-11ee-8714-19d56ba0c4fd:node_5.20:
# {
#   "uv_light": {
#     "value": 0.06,
#     "units": "UV Index"
#   },
#   "loudness": {
#     "value": 330.0,
#     "units": "dB"
#   },
#   "pm1.0atmospheric": {
#     "value": 8.0,
#     "units": "\u00b5g/m\u00b3"
#   },
#   "pm2.5atmospheric": {
#     "value": 14.0,
#     "units": "\u00b5g/m\u00b3"
#   },
#   "pm10atmospheric": {
#     "value": 12.0,
#     "units": "\u00b5g/m\u00b3"
#   },
#   "pir_status": {
#     "value": "No Motion Detected",
#     "units": ""
#   },
#   "tvoc_concentration": {
#     "value": 18.0,
#     "units": "ppb"
#   },
#   "co2eq_concentration": {
#     "value": 393.0,
#     "units": "ppm"
#   },
#   "mq2_sensor_voltage": {
#     "value": 0.34,
#     "units": "Volts"
#   },
#   "mq2_rs_ratio": {
#     "value": 15.85,
#     "units": ""
#   },
#   "mq2_rs/r0_ratio": {
#     "value": 152.09,
#     "units": ""
#   },
#   "mq3_sensor_voltage": {
#     "value": 0.3,
#     "units": "Volts"
#   },
#   "mq3_rs_ratio": {
#     "value": 15.07,
#     "units": ""
#   },
#   "mq3_rs/r0_ratio": {
#     "value": 757.0,
#     "units": ""
#   },
#   "hcho_ppm": {
#     "value": 0.0,
#     "units": "ppm"
#   },
#   "air_quality": {
#     "value": "Fresh air",
#     "units": ""
#   },
#   "light_value": {
#     "value": 170.0,
#     "units": "Lux"
#   },
#   "visible_light": {
#     "value": 262.0,
#     "units": "Lux"
#   },
#   "ir_light": {
#     "value": 275.0,
#     "units": "Lux"
#   },
#   "mq5_sensor_voltage": {
#     "value": 0.66,
#     "units": "Volts"
#   },
#   "mq5_rs_ratio": {
#     "value": 6.16,
#     "units": ""
#   },
#   "mq5_rs/r0_ratio": {
#     "value": 40.8,
#     "units": ""
#   },
#   "mq9_sensor_voltage": {
#     "value": 0.37,
#     "units": "Volts"
#   },
#   "mq9_rs_ratio": {
#     "value": 12.73,
#     "units": ""
#   },
#   "mq9_rs/r0_ratio": {
#     "value": 82.39,
#     "units": ""
#   },
#   "o2_22.10_n2_gas": {
#     "value": 193.0,
#     "units": ""
#   },
#   "c2h5ch_gas": {
#     "value": 288.0,
#     "units": ""
#   },
#   "voc_gas": {
#     "value": 246.0,
#     "units": ""
#   },
#   "co_gas": {
#     "value": 179.0,
#     "units": ""
#   },
#   "co2": {
#     "value": 598.0,
#     "units": ""
#   },
#   "temperature": {
#     "value": 30.56,
#     "units": "\u00b0C"
#   },
#   "humidity": {
#     "value": 17.34,
#     "units": "%"
#   },
#   "luminance": {
#     "value": 31.3,
#     "units": "cd/m\u00b2"
#   }
# }
# Error: 202
#
# Received data for 2ae959b0-53c6-11ee-8714-19d56ba0c4fd:node_5.21:
# {
#   "uv_light": {
#     "value": 0.03,
#     "units": "UV Index"
#   },
#   "loudness": {
#     "value": 389.0,
#     "units": "dB"
#   },
#   "pm1.0atmospheric": {
#     "value": 9.0,
#     "units": "\u00b5g/m\u00b3"
#   },
#   "pm2.5atmospheric": {
#     "value": 14.0,
#     "units": "\u00b5g/m\u00b3"
#   },
#   "pm10atmospheric": {
#     "value": 14.0,
#     "units": "\u00b5g/m\u00b3"
#   },
#   "pir_status": {
#     "value": "No Motion Detected",
#     "units": ""
#   },
#   "tvoc_concentration": {
#     "value": 19.0,
#     "units": "ppb"
#   },
#   "co2eq_concentration": {
#     "value": 399.0,
#     "units": "ppm"
#   },
#   "mq2_sensor_voltage": {
#     "value": 0.27,
#     "units": "Volts"
#   },
#   "mq2_rs_ratio": {
#     "value": 15.71,
#     "units": ""
#   },
#   "mq2_rs/r0_ratio": {
#     "value": 156.86,
#     "units": ""
#   },
#   "mq3_sensor_voltage": {
#     "value": 0.32,
#     "units": "Volts"
#   },
#   "mq3_rs_ratio": {
#     "value": 15.62,
#     "units": ""
#   },
#   "mq3_rs/r0_ratio": {
#     "value": 758.36,
#     "units": ""
#   },
#   "hcho_ppm": {
#     "value": 0.0,
#     "units": "ppm"
#   },
#   "air_quality": {
#     "value": "Fresh air",
#     "units": ""
#   },
#   "light_value": {
#     "value": 171.0,
#     "units": "Lux"
#   },
#   "visible_light": {
#     "value": 260.0,
#     "units": "Lux"
#   },
#   "ir_light": {
#     "value": 279.0,
#     "units": "Lux"
#   },
#   "mq5_sensor_voltage": {
#     "value": 0.71,
#     "units": "Volts"
#   },
#   "mq5_rs_ratio": {
#     "value": 5.86,
#     "units": ""
#   },
#   "mq5_rs/r0_ratio": {
#     "value": 41.85,
#     "units": ""
#   },
#   "mq9_sensor_voltage": {
#     "value": 0.36,
#     "units": "Volts"
#   },
#   "mq9_rs_ratio": {
#     "value": 12.33,
#     "units": ""
#   },
#   "mq9_rs/r0_ratio": {
#     "value": 82.42,
#     "units": ""
#   },
#   "o2_22.10_n2_gas": {
#     "value": 192.0,
#     "units": ""
#   },
#   "c2h5ch_gas": {
#     "value": 289.0,
#     "units": ""
#   },
#   "voc_gas": {
#     "value": 249.0,
#     "units": ""
#   },
#   "co_gas": {
#     "value": 182.0,
#     "units": ""
#   },
#   "co2": {
#     "value": 601.0,
#     "units": ""
#   },
#   "temperature": {
#     "value": 31.98,
#     "units": "\u00b0C"
#   },
#   "humidity": {
#     "value": 18.91,
#     "units": "%"
#   },
#   "luminance": {
#     "value": 30.8,
#     "units": "cd/m\u00b2"
#   }
# }
# Error: 202
#
# Received data for 351b0eb0-57ef-11ee-8714-19d56ba0c4fd:node_5.22:
# {
#   "uv_light": {
#     "value": 0.04,
#     "units": "UV Index"
#   },
#   "loudness": {
#     "value": 301.0,
#     "units": "dB"
#   },
#   "pm1.0atmospheric": {
#     "value": 8.0,
#     "units": "\u00b5g/m\u00b3"
#   },
#   "pm2.5atmospheric": {
#     "value": 13.0,
#     "units": "\u00b5g/m\u00b3"
#   },
#   "pm10atmospheric": {
#     "value": 12.0,
#     "units": "\u00b5g/m\u00b3"
#   },
#   "pir_status": {
#     "value": "No Motion Detected",
#     "units": ""
#   },
#   "tvoc_concentration": {
#     "value": 19.0,
#     "units": "ppb"
#   },
#   "co2eq_concentration": {
#     "value": 404.0,
#     "units": "ppm"
#   },
#   "mq2_sensor_voltage": {
#     "value": 0.33,
#     "units": "Volts"
#   },
#   "mq2_rs_ratio": {
#     "value": 15.48,
#     "units": ""
#   },
#   "mq2_rs/r0_ratio": {
#     "value": 157.54,
#     "units": ""
#   },
#   "mq3_sensor_voltage": {
#     "value": 0.31,
#     "units": "Volts"
#   },
#   "mq3_rs_ratio": {
#     "value": 15.89,
#     "units": ""
#   },
#   "mq3_rs/r0_ratio": {
#     "value": 763.62,
#     "units": ""
#   },
#   "hcho_ppm": {
#     "value": 0.01,
#     "units": "ppm"
#   },
#   "air_quality": {
#     "value": "Fresh air",
#     "units": ""
#   },
#   "light_value": {
#     "value": 175.0,
#     "units": "Lux"
#   },
#   "visible_light": {
#     "value": 263.0,
#     "units": "Lux"
#   },
#   "ir_light": {
#     "value": 271.0,
#     "units": "Lux"
#   },
#   "mq5_sensor_voltage": {
#     "value": 0.74,
#     "units": "Volts"
#   },
#   "mq5_rs_ratio": {
#     "value": 5.93,
#     "units": ""
#   },
#   "mq5_rs/r0_ratio": {
#     "value": 41.49,
#     "units": ""
#   },
#   "mq9_sensor_voltage": {
#     "value": 0.38,
#     "units": "Volts"
#   },
#   "mq9_rs_ratio": {
#     "value": 12.97,
#     "units": ""
#   },
#   "mq9_rs/r0_ratio": {
#     "value": 82.65,
#     "units": ""
#   },
#   "o2_22.10_n2_gas": {
#     "value": 196.0,
#     "units": ""
#   },
#   "c2h5ch_gas": {
#     "value": 289.0,
#     "units": ""
#   },
#   "voc_gas": {
#     "value": 247.0,
#     "units": ""
#   },
#   "co_gas": {
#     "value": 176.0,
#     "units": ""
#   },
#   "co2": {
#     "value": 600.0,
#     "units": ""
#   },
#   "temperature": {
#     "value": 30.01,
#     "units": "\u00b0C"
#   },
#   "humidity": {
#     "value": 17.86,
#     "units": "%"
#   },
#   "luminance": {
#     "value": 30.93,
#     "units": "cd/m\u00b2"
#   }
# }
# Error: 202
#
# Received data for 0f96bed0-b82d-11ed-b196-bb47e24272bc:node_5.23:
# {
#   "uv_light": {
#     "value": 0.0,
#     "units": "UV Index"
#   },
#   "loudness": {
#     "value": 365.0,
#     "units": "dB"
#   },
#   "pm1.0atmospheric": {
#     "value": 9.0,
#     "units": "\u00b5g/m\u00b3"
#   },
#   "pm2.5atmospheric": {
#     "value": 14.0,
#     "units": "\u00b5g/m\u00b3"
#   },
#   "pm10atmospheric": {
#     "value": 12.0,
#     "units": "\u00b5g/m\u00b3"
#   },
#   "pir_status": {
#     "value": "No Motion Detected",
#     "units": ""
#   },
#   "tvoc_concentration": {
#     "value": 20.0,
#     "units": "ppb"
#   },
#   "co2eq_concentration": {
#     "value": 409.0,
#     "units": "ppm"
#   },
#   "mq2_sensor_voltage": {
#     "value": 0.33,
#     "units": "Volts"
#   },
#   "mq2_rs_ratio": {
#     "value": 15.71,
#     "units": ""
#   },
#   "mq2_rs/r0_ratio": {
#     "value": 154.0,
#     "units": ""
#   },
#   "mq3_sensor_voltage": {
#     "value": 0.32,
#     "units": "Volts"
#   },
#   "mq3_rs_ratio": {
#     "value": 15.45,
#     "units": ""
#   },
#   "mq3_rs/r0_ratio": {
#     "value": 767.65,
#     "units": ""
#   },
#   "hcho_ppm": {
#     "value": 0.01,
#     "units": "ppm"
#   },
#   "air_quality": {
#     "value": "Fresh air",
#     "units": ""
#   },
#   "light_value": {
#     "value": 175.0,
#     "units": "Lux"
#   },
#   "visible_light": {
#     "value": 261.0,
#     "units": "Lux"
#   },
#   "ir_light": {
#     "value": 272.0,
#     "units": "Lux"
#   },
#   "mq5_sensor_voltage": {
#     "value": 0.68,
#     "units": "Volts"
#   },
#   "mq5_rs_ratio": {
#     "value": 6.0,
#     "units": ""
#   },
#   "mq5_rs/r0_ratio": {
#     "value": 40.08,
#     "units": ""
#   },
#   "mq9_sensor_voltage": {
#     "value": 0.38,
#     "units": "Volts"
#   },
#   "mq9_rs_ratio": {
#     "value": 12.58,
#     "units": ""
#   },
#   "mq9_rs/r0_ratio": {
#     "value": 83.35,
#     "units": ""
#   },
#   "o2_22.10_n2_gas": {
#     "value": 196.0,
#     "units": ""
#   },
#   "c2h5ch_gas": {
#     "value": 290.0,
#     "units": ""
#   },
#   "voc_gas": {
#     "value": 246.0,
#     "units": ""
#   },
#   "co_gas": {
#     "value": 180.0,
#     "units": ""
#   },
#   "co2": {
#     "value": 601.0,
#     "units": ""
#   },
#   "temperature": {
#     "value": 30.66,
#     "units": "\u00b0C"
#   },
#   "humidity": {
#     "value": 17.79,
#     "units": "%"
#   },
#   "luminance": {
#     "value": 30.05,
#     "units": "cd/m\u00b2"
#   }
# }
# Error: 202
#
# Received data for 13e642d0-b82d-11ed-b196-bb47e24272bc:node_5.24:
# {
#   "uv_light": {
#     "value": 0.05,
#     "units": "UV Index"
#   },
#   "loudness": {
#     "value": 378.0,
#     "units": "dB"
#   },
#   "pm1.0atmospheric": {
#     "value": 9.0,
#     "units": "\u00b5g/m\u00b3"
#   },
#   "pm2.5atmospheric": {
#     "value": 13.0,
#     "units": "\u00b5g/m\u00b3"
#   },
#   "pm10atmospheric": {
#     "value": 12.0,
#     "units": "\u00b5g/m\u00b3"
#   },
#   "pir_status": {
#     "value": "No Motion Detected",
#     "units": ""
#   },
#   "tvoc_concentration": {
#     "value": 18.0,
#     "units": "ppb"
#   },
#   "co2eq_concentration": {
#     "value": 403.0,
#     "units": "ppm"
#   },
#   "mq2_sensor_voltage": {
#     "value": 0.32,
#     "units": "Volts"
#   },
#   "mq2_rs_ratio": {
#     "value": 15.52,
#     "units": ""
#   },
#   "mq2_rs/r0_ratio": {
#     "value": 153.06,
#     "units": ""
#   },
#   "mq3_sensor_voltage": {
#     "value": 0.32,
#     "units": "Volts"
#   },
#   "mq3_rs_ratio": {
#     "value": 14.74,
#     "units": ""
#   },
#   "mq3_rs/r0_ratio": {
#     "value": 755.04,
#     "units": ""
#   },
#   "hcho_ppm": {
#     "value": 0.01,
#     "units": "ppm"
#   },
#   "air_quality": {
#     "value": "Fresh air",
#     "units": ""
#   },
#   "light_value": {
#     "value": 172.0,
#     "units": "Lux"
#   },
#   "visible_light": {
#     "value": 263.0,
#     "units": "Lux"
#   },
#   "ir_light": {
#     "value": 279.0,
#     "units": "Lux"
#   },
#   "mq5_sensor_voltage": {
#     "value": 0.66,
#     "units": "Volts"
#   },
#   "mq5_rs_ratio": {
#     "value": 6.16,
#     "units": ""
#   },
#   "mq5_rs/r0_ratio": {
#     "value": 41.02,
#     "units": ""
#   },
#   "mq9_sensor_voltage": {
#     "value": 0.38,
#     "units": "Volts"
#   },
#   "mq9_rs_ratio": {
#     "value": 12.39,
#     "units": ""
#   },
#   "mq9_rs/r0_ratio": {
#     "value": 83.4,
#     "units": ""
#   },
#   "o2_22.10_n2_gas": {
#     "value": 194.0,
#     "units": ""
#   },
#   "c2h5ch_gas": {
#     "value": 287.0,
#     "units": ""
#   },
#   "voc_gas": {
#     "value": 248.0,
#     "units": ""
#   },
#   "co_gas": {
#     "value": 182.0,
#     "units": ""
#   },
#   "co2": {
#     "value": 604.0,
#     "units": ""
#   },
#   "temperature": {
#     "value": 30.42,
#     "units": "\u00b0C"
#   },
#   "humidity": {
#     "value": 17.29,
#     "units": "%"
#   },
#   "luminance": {
#     "value": 30.31,
#     "units": "cd/m\u00b2"
#   }
# }
# Error: 202
#
# Received data for 18a159e0-b82d-11ed-b196-bb47e24272bc:node_5.25:
# {
#   "uv_light": {
#     "value": 0.07,
#     "units": "UV Index"
#   },
#   "loudness": {
#     "value": 382.0,
#     "units": "dB"
#   },
#   "pm1.0atmospheric": {
#     "value": 9.0,
#     "units": "\u00b5g/m\u00b3"
#   },
#   "pm2.5atmospheric": {
#     "value": 13.0,
#     "units": "\u00b5g/m\u00b3"
#   },
#   "pm10atmospheric": {
#     "value": 12.0,
#     "units": "\u00b5g/m\u00b3"
#   },
#   "pir_status": {
#     "value": "No Motion Detected",
#     "units": ""
#   },
#   "tvoc_concentration": {
#     "value": 19.0,
#     "units": "ppb"
#   },
#   "co2eq_concentration": {
#     "value": 397.0,
#     "units": "ppm"
#   },
#   "mq2_sensor_voltage": {
#     "value": 0.32,
#     "units": "Volts"
#   },
#   "mq2_rs_ratio": {
#     "value": 15.62,
#     "units": ""
#   },
#   "mq2_rs/r0_ratio": {
#     "value": 150.4,
#     "units": ""
#   },
#   "mq3_sensor_voltage": {
#     "value": 0.33,
#     "units": "Volts"
#   },
#   "mq3_rs_ratio": {
#     "value": 14.51,
#     "units": ""
#   },
#   "mq3_rs/r0_ratio": {
#     "value": 759.98,
#     "units": ""
#   },
#   "hcho_ppm": {
#     "value": 0.01,
#     "units": "ppm"
#   },
#   "air_quality": {
#     "value": "Fresh air",
#     "units": ""
#   },
#   "light_value": {
#     "value": 171.0,
#     "units": "Lux"
#   },
#   "visible_light": {
#     "value": 265.0,
#     "units": "Lux"
#   },
#   "ir_light": {
#     "value": 272.0,
#     "units": "Lux"
#   },
#   "mq5_sensor_voltage": {
#     "value": 0.74,
#     "units": "Volts"
#   },
#   "mq5_rs_ratio": {
#     "value": 5.99,
#     "units": ""
#   },
#   "mq5_rs/r0_ratio": {
#     "value": 41.77,
#     "units": ""
#   },
#   "mq9_sensor_voltage": {
#     "value": 0.4,
#     "units": "Volts"
#   },
#   "mq9_rs_ratio": {
#     "value": 12.05,
#     "units": ""
#   },
#   "mq9_rs/r0_ratio": {
#     "value": 83.71,
#     "units": ""
#   },
#   "o2_22.10_n2_gas": {
#     "value": 195.0,
#     "units": ""
#   },
#   "c2h5ch_gas": {
#     "value": 287.0,
#     "units": ""
#   },
#   "voc_gas": {
#     "value": 246.0,
#     "units": ""
#   },
#   "co_gas": {
#     "value": 181.0,
#     "units": ""
#   },
#   "co2": {
#     "value": 607.0,
#     "units": ""
#   },
#   "temperature": {
#     "value": 30.4,
#     "units": "\u00b0C"
#   },
#   "humidity": {
#     "value": 17.74,
#     "units": "%"
#   },
#   "luminance": {
#     "value": 31.0,
#     "units": "cd/m\u00b2"
#   }
# }
# Error: 202
#
# Received data for fef50770-57f1-11ee-8714-19d56ba0c4fd:node_5.26:
# {
#   "uv_light": {
#     "value": 0.0,
#     "units": "UV Index"
#   },
#   "loudness": {
#     "value": 300.0,
#     "units": "dB"
#   },
#   "pm1.0atmospheric": {
#     "value": 10.0,
#     "units": "\u00b5g/m\u00b3"
#   },
#   "pm2.5atmospheric": {
#     "value": 12.0,
#     "units": "\u00b5g/m\u00b3"
#   },
#   "pm10atmospheric": {
#     "value": 13.0,
#     "units": "\u00b5g/m\u00b3"
#   },
#   "pir_status": {
#     "value": "No Motion Detected",
#     "units": ""
#   },
#   "tvoc_concentration": {
#     "value": 20.0,
#     "units": "ppb"
#   },
#   "co2eq_concentration": {
#     "value": 398.0,
#     "units": "ppm"
#   },
#   "mq2_sensor_voltage": {
#     "value": 0.32,
#     "units": "Volts"
#   },
#   "mq2_rs_ratio": {
#     "value": 15.26,
#     "units": ""
#   },
#   "mq2_rs/r0_ratio": {
#     "value": 151.32,
#     "units": ""
#   },
#   "mq3_sensor_voltage": {
#     "value": 0.33,
#     "units": "Volts"
#   },
#   "mq3_rs_ratio": {
#     "value": 14.42,
#     "units": ""
#   },
#   "mq3_rs/r0_ratio": {
#     "value": 759.31,
#     "units": ""
#   },
#   "hcho_ppm": {
#     "value": 0.0,
#     "units": "ppm"
#   },
#   "air_quality": {
#     "value": "Fresh air",
#     "units": ""
#   },
#   "light_value": {
#     "value": 173.0,
#     "units": "Lux"
#   },
#   "visible_light": {
#     "value": 264.0,
#     "units": "Lux"
#   },
#   "ir_light": {
#     "value": 273.0,
#     "units": "Lux"
#   },
#   "mq5_sensor_voltage": {
#     "value": 0.72,
#     "units": "Volts"
#   },
#   "mq5_rs_ratio": {
#     "value": 5.87,
#     "units": ""
#   },
#   "mq5_rs/r0_ratio": {
#     "value": 41.86,
#     "units": ""
#   },
#   "mq9_sensor_voltage": {
#     "value": 0.38,
#     "units": "Volts"
#   },
#   "mq9_rs_ratio": {
#     "value": 12.46,
#     "units": ""
#   },
#   "mq9_rs/r0_ratio": {
#     "value": 83.13,
#     "units": ""
#   },
#   "o2_22.10_n2_gas": {
#     "value": 193.0,
#     "units": ""
#   },
#   "c2h5ch_gas": {
#     "value": 287.0,
#     "units": ""
#   },
#   "voc_gas": {
#     "value": 249.0,
#     "units": ""
#   },
#   "co_gas": {
#     "value": 176.0,
#     "units": ""
#   },
#   "co2": {
#     "value": 604.0,
#     "units": ""
#   },
#   "temperature": {
#     "value": 31.72,
#     "units": "\u00b0C"
#   },
#   "humidity": {
#     "value": 18.74,
#     "units": "%"
#   },
#   "luminance": {
#     "value": 30.22,
#     "units": "cd/m\u00b2"
#   }
# }
# Error: 202

# %% [markdown]
# ### GET device data from cardiff tb

# %%
import requests

url = "https://thingsboard.cs.cf.ac.uk/api/auth/login"
headers = {"Content-Type": "application/json"}

payload = {
    "username": "SuhasAbacwsLivingLab@cardiff.ac.uk",
    "password": "SuhasDevmane"
}

response = requests.post(url, json=payload, headers=headers)

if response.status_code == 200:
    # Authentication successful
    token = response.json().get("token")
    print("JWT_Token:", token)
else:
    print("Authentication failed. Status Code:", response.status_code)
    print("Response:", response.text)
# Out:
# JWT_Token: eyJhbGciOiJIUzUxMiJ9.....sMeSIo4Q3f8DV8CtE78TQu75dItyNcvAr2FMUzMEw9kYk89bZVPeR3V6xajzhtmOHqeRn0VduvTUZj5iWXUzKw

# %% [markdown]
# to get jwt = curl -X POST --header "Content-Type: application/json" -d "{\"username\":\"SuhasAbacwsLivingLab@cardiff.ac.uk\", \"password\":\"SuhasDevmane\"}" "https://thingsboard.cs.cf.ac.uk/api/auth/login"

# %% [markdown]
# ### get the device info from a 3d api

# %%
import requests

url = 'http://visualiser:80/api/devices/node_5.05'
headers = {'accept': 'application/json'}

try:
    response = requests.get(url, headers=headers)

    if response.status_code == 200:
        json_data = response.json()
        # Process the JSON data as needed
        print(json_data)
    else:
        print(f"Error: {response.status_code}")
        print(response.text)

except requests.exceptions.RequestException as e:
    print(f"Request error: {e}")
# Out:
# {'name': 'node_5.05', 'type': 'Corridor', 'floor': 5, 'position': {'x': 162.304, 'y': 70, 'z': -96.273}}

# %% [markdown]
# ## this code sends data to the 3D api

# %%
import requests
import json

url = 'http://visualiser:80/api/devices/node_5.14/data'  # Replace with the actual service name
headers = {
    'accept': '*/*',
    'Content-Type': 'application/json'
}

data = {
    "temperature": {
        "value": 25,
        "units": "°C"
    },
    "humidity": {
        "value": 50,
        "units": "%"
    },
    "air_quality": {
        "value": 150,
        "units": "ppm"
    },
    "pressure": {
        "value": 1010,
        "units": "hPa"
    },
    "light_intensity": {
        "value": 500,
        "units": "lux"
    },
    "wind_speed": {
        "value": 10,
        "units": "m/s"
    },
    "rainfall": {
        "value": 5,
        "units": "mm"
    }
}

try:
    response = requests.put(url, headers=headers, data=json.dumps(data))

    if response.status_code == 200:
        json_data = response.json()
        # Process the JSON data as needed
        print(json_data)
    else:
        print(f"Error: {response.status_code}")
        print(response.text)

except requests.exceptions.RequestException as e:
    print(f"Request error: {e}")
# Out:
# Error: 202

# %% [markdown]
# # GET TB Postgress Data And Send to Mongo API

# %%
import requests

url = "https://thingsboard.cs.cf.ac.uk/api/auth/login"
headers = {"Content-Type": "application/json"}

payload = {
    "username": "SuhasAbacwsLivingLab@cardiff.ac.uk",
    "password": "SuhasDevmane"
}

response = requests.post(url, json=payload, headers=headers)

if response.status_code == 200:
    # Authentication successful
    token = response.json().get("token")
    print("JWT_Token:", token)
else:
    print("Authentication failed. Status Code:", response.status_code)
    print("Response:", response.text)

# %%
import requests
import json

url = "https://thingsboard.cs.cf.ac.uk/api/auth/login"
headers = {"Content-Type": "application/json"}

payload = {
    "username": "SuhasAbacwsLivingLab@cardiff.ac.uk",
    "password": "SuhasDevmane"
}

response = requests.post(url, json=payload, headers=headers)

if response.status_code == 200:
    # Authentication successful
    token = response.json().get("token")
    print("JWT_Token:", token)
else:
    print("Authentication failed. Status Code:", response.status_code)
    print("Response:", response.text)

access_token = token  

device_ids = [
"70ad22a0-b82c-11ed-b196-bb47e24272bc",
"75d29440-b82c-11ed-b196-bb47e24272bc",
"7b717ba0-b82c-11ed-b196-bb47e24272bc",
"a673eb80-b82c-11ed-b196-bb47e24272bc",
"83456b70-b82c-11ed-b196-bb47e24272bc",
"b96d6720-b82c-11ed-b196-bb47e24272bc",
"be98a520-b82c-11ed-b196-bb47e24272bc",
"c3110de0-b82c-11ed-b196-bb47e24272bc",
"c950f030-b82c-11ed-b196-bb47e24272bc",
"cfddba00-b82c-11ed-b196-bb47e24272bc",
"278505c0-0f7a-11ee-bf90-a16a1a9e1e0a",
"d9576a90-b82c-11ed-b196-bb47e24272bc",
"de18ea40-b82c-11ed-b196-bb47e24272bc",
"f57a1560-7cf3-11ee-94bc-d389020903a3",
"508d1b60-57eb-11ee-8714-19d56ba0c4fd",
"86c63bd0-57f0-11ee-8714-19d56ba0c4fd",
"3efd82d0-7cf4-11ee-94bc-d389020903a3",
"f583bc50-57e6-11ee-8714-19d56ba0c4fd",
"9458c560-0f75-11ee-bf90-a16a1a9e1e0a",
"cbc851c0-57ee-11ee-8714-19d56ba0c4fd",
"2ae959b0-53c6-11ee-8714-19d56ba0c4fd",
"351b0eb0-57ef-11ee-8714-19d56ba0c4fd",
"0f96bed0-b82d-11ed-b196-bb47e24272bc",
"13e642d0-b82d-11ed-b196-bb47e24272bc",
"18a159e0-b82d-11ed-b196-bb47e24272bc",
"fef50770-57f1-11ee-8714-19d56ba0c4fd",
"2a5d9a90-b82d-11ed-b196-bb47e24272bc",
"99c6a3b0-b82b-11ed-b196-bb47e24272bc",
"51f2d170-57e1-11ee-8714-19d56ba0c4fd",
"9c563630-0f75-11ee-bf90-a16a1a9e1e0a",
"391303e0-b82d-11ed-b196-bb47e24272bc",
"3d3a3f60-b82d-11ed-b196-bb47e24272bc",
"a83a46c0-7cf4-11ee-94bc-d389020903a3",
"4665a8e0-b82d-11ed-b196-bb47e24272bc"
]

keys_to_fetch = [
    "UV_light", "Loudness", "PM1.0Atmospheric", "PM2.5Atmospheric", "PM10Atmospheric", 
    "PIR_Status", "tVOC_Concentration", "CO2eq_Concentration", "MQ2_sensor_voltage", 
    "MQ2_Rs_ratio", "MQ2_Rs/R0_Ratio", "MQ3_sensor_voltage", "MQ3_Rs_ratio", 
    "MQ3_Rs/R0_Ratio", "HCHO_ppm", "Air_Quality", "Light_value", "Visible_light", 
    "IR_light", "MQ5_sensor_voltage", "MQ5_Rs_ratio", "MQ5_Rs/R0_Ratio", 
    "MQ9_sensor_voltage", "MQ9_Rs_ratio", "MQ9_Rs/R0_Ratio", "O2_22.10_N2_gas", 
    "C2H5CH_gas", "VOC_gas", "CO_gas", "Co2", "Temperature", "Humidity", "Luminance"
]

mongo_db_url = 'http://visualiser:80/api/devices/node_5.05/data'  

for device_id in device_ids:
    url = f"https://thingsboard.cs.cf.ac.uk/api/plugins/telemetry/DEVICE/{device_id}/values/timeseries?keys={','.join(keys_to_fetch)}"
    headers = {
        'Content-Type': 'application/json',
        'X-Authorization': f'Bearer {access_token}'
    }

    response = requests.get(url, headers=headers)

    if response.status_code == 200:
        data = response.json()
        print(f"Received data from Device ID {device_id}:")
        print(json.dumps(data, indent=2))

        # Send data to MongoDB API
        try:
            response_mongo = requests.put(mongo_db_url, headers={'Content-Type': 'application/json'}, data=json.dumps(data))

            if response_mongo.status_code == 200:
                print("Data sent to MongoDB successfully.")
            else:
                print(f"Error sending data to MongoDB. Status Code: {response_mongo.status_code}")
                print(response_mongo.text)

        except requests.exceptions.RequestException as e:
            print(f"Request error to MongoDB: {e}")

    else:
        print(f"Failed to get data from Device ID {device_id}. Status Code: {response.status_code}")
        print(response.text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 4
#       1 import requests
#       2 import json
# ----> 4 access_token = token
#       6 device_ids = [
#       7 "70ad22a0-b82c-11ed-b196-bb47e24272bc",
#       8 "75d29440-b82c-11ed-b196-bb47e24272bc",
#    (...)
#      40 "4665a8e0-b82d-11ed-b196-bb47e24272bc"
#      41 ]
#      43 keys_to_fetch = [
#      44     "UV_light", "Loudness", "PM1.0Atmospheric", "PM2.5Atmospheric", "PM10Atmospheric",
#      45     "PIR_Status", "tVOC_Concentration", "CO2eq_Concentration", "MQ2_sensor_voltage",
#    (...)
#      50     "C2H5CH_gas", "VOC_gas", "CO_gas", "Co2", "Temperature", "Humidity", "Luminance"
#      51 ]
#
# NameError: name 'token' is not defined

# %% [markdown]
# ### Avoid duplicates

# %%
import requests
import json

access_token = "your_access_token"  # Replace with the actual access token

device_ids = [
    "70ad22a0-b82c-11ed-b196-bb47e24272bc",
    "75d29440-b82c-11ed-b196-bb47e24272bc",
    "7b717ba0-b82c-11ed-b196-bb47e24272bc",
    # Add other device IDs
]

keys_to_fetch = [
    "UV_light", "Loudness", "PM1.0Atmospheric", "PM2.5Atmospheric", "PM10Atmospheric", 
    "PIR_Status", "tVOC_Concentration", "CO2eq_Concentration", "MQ2_sensor_voltage", 
    "MQ2_Rs_ratio", "MQ2_Rs/R0_Ratio", "MQ3_sensor_voltage", "MQ3_Rs_ratio", 
    "MQ3_Rs/R0_Ratio", "HCHO_ppm", "Air_Quality", "Light_value", "Visible_light", 
    "IR_light", "MQ5_sensor_voltage", "MQ5_Rs_ratio", "MQ5_Rs/R0_Ratio", 
    "MQ9_sensor_voltage", "MQ9_Rs_ratio", "MQ9_Rs/R0_Ratio", "O2_22.10_N2_gas", 
    "C2H5CH_gas", "VOC_gas", "CO_gas", "Co2", "Temperature", "Humidity", "Luminance"
]

mongo_db_url = 'http://visualiser:80/api/devices/node_5.05/data'  # Replace with the actual service name

unique_data_set = set()

for device_id in device_ids:
    url = f"https://thingsboard.cs.cf.ac.uk/api/plugins/telemetry/DEVICE/{device_id}/values/timeseries?keys={','.join(keys_to_fetch)}"
    headers = {
        'Content-Type': 'application/json',
        'X-Authorization': f'Bearer {access_token}'
    }

    response = requests.get(url, headers=headers)

    if response.status_code == 200:
        data = response.json()
        print(f"Received data from Device ID {device_id}:")
        print(json.dumps(data, indent=2))

        # Check if the data is not in the set (not a duplicate)
        if json.dumps(data) not in unique_data_set:
            unique_data_set.add(json.dumps(data))

            # Send data to MongoDB API
            try:
                response_mongo = requests.put(mongo_db_url, headers={'Content-Type': 'application/json'}, data=json.dumps(data))

                if response_mongo.status_code == 200:
                    print("Data sent to MongoDB successfully.")
                else:
                    print(f"Error sending data to MongoDB. Status Code: {response_mongo.status_code}")
                    print(response_mongo.text)

            except requests.exceptions.RequestException as e:
                print(f"Request error to MongoDB: {e}")

        else:
            print("Duplicate data, not sending to MongoDB.")

    else:
        print(f"Failed to get data from Device ID {device_id}. Status Code: {response.status_code}")
        print(response.text)
