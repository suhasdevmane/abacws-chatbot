# %%
from SPARQLWrapper import SPARQLWrapper, JSON

sparql_query = f"""
PREFIX bldg: <http://abacwsbuilding.cardiff.ac.uk/abacws#>
PREFIX brick: <https://brickschema.org/schema/Brick#>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX sh: <http://www.w3.org/ns/shacl#>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
SELECT ?type
WHERE {{
  <http://abacwsbuilding.cardiff.ac.uk/abacws/airq5.01> rdf:type ?type .
}}
"""
endpoint_url = "http://localhost:3030/abacws-sensor-network/sparql"


def execute_sparql_query(sparql_query, endpoint_url):
    sparql = SPARQLWrapper(endpoint_url)
    sparql.setQuery(sparql_query)
    sparql.setReturnFormat("json")
    results = sparql.query().convert()
    return results


results = execute_sparql_query(sparql_query, endpoint_url)
results
# Out:
# {'head': {'vars': ['type']},
#  'results': {'bindings': [{'type': {'type': 'uri',
#      'value': 'https://brickschema.org/schema/Brick/Sensor'}}]}}

# %%
from SPARQLWrapper import SPARQLWrapper, JSON

sparql_query = """
PREFIX bldg: <http://abacwsbuilding.cardiff.ac.uk/abacws#>
PREFIX brick: <https://brickschema.org/schema/Brick#>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>

SELECT ?value ?timestamp
WHERE {
  bldg:notwo5.01 rdf:type brick:Sensor ;
                 brick:hasValue ?value ;
                 brick:hasTimestamp ?timestamp .
}

"""

endpoint_url = "http://localhost:3030/abacws-sensor-network/sparql"


def execute_sparql_query(sparql_query, endpoint_url):
    sparql = SPARQLWrapper(endpoint_url)
    sparql.setQuery(sparql_query)
    sparql.setReturnFormat(JSON)
    results = sparql.query().convert()
    return results


results = execute_sparql_query(sparql_query, endpoint_url)

if results:
    for result in results["results"]["bindings"]:
        value = result["value"]["value"]
        timestamp = result["timestamp"]["value"]
        print(f"Sensor Value: {value}, Timestamp: {timestamp}")
else:
    print("No results found.")

# %% [markdown]
# Query to receive latest sensor value for any location

# %%
from SPARQLWrapper import SPARQLWrapper, JSON


# Specify the variables for sensor_name and sensor_location
sensor_name = "notwo"  # Change this to the desired sensor name
sensor_location = "5.02"  # Change this to the desired sensor location

# Build the sensor_subject with variables
sensor_subject = f"bldg:{sensor_name}{sensor_location}"

sparql_query = f"""
PREFIX bldg: <http://abacwsbuilding.cardiff.ac.uk/abacws#>
PREFIX brick: <https://brickschema.org/schema/Brick#>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>

SELECT ?value ?timestamp
WHERE {{
  {sensor_subject} rdf:type brick:Sensor ;
                 brick:hasValue ?value ;
                 brick:hasTimestamp ?timestamp .
}}
ORDER BY DESC(?timestamp)
LIMIT 1
"""

endpoint_url = "http://localhost:3030/abacws-sensor-network/sparql"


def execute_sparql_query(sparql_query, endpoint_url):
    sparql = SPARQLWrapper(endpoint_url)
    sparql.setQuery(sparql_query)
    sparql.setReturnFormat(JSON)
    results = sparql.query().convert()
    return results


results = execute_sparql_query(sparql_query, endpoint_url)

if results:
    latest_result = results["results"]["bindings"][0]
    value = latest_result["value"]["value"]
    timestamp = latest_result["timestamp"]["value"]
    print(f"Latest Sensor Value: {value}, Timestamp: {timestamp}")
else:
    print("No results found.")
# Out:
# Latest Sensor Value: None, Timestamp: 2023-11-17T17:05:14

# %%
from SPARQLWrapper import SPARQLWrapper, JSON

# List of available devices and locations
available_devices = [
    "notwo",
    "airq",
    "c2h5ch",
    "cotwo",
    "co",
    "dust",
    "hcho",
    "hum",
    "light",
    "mqfive",
    "mqnine",
    "mqthree",
    "mqtwo",
    "notwo",
    "oxy",
    "pir",
    "sound",
    "temp",
    "voc",
]  # Add more devices as needed
available_locations = [
    f"5.{i:02}" for i in range(1, 35)
]  # Add more locations as needed


# User input for sensor_name and sensor_location
sensor_name = input(f"Choose sensor name ({', '.join(available_devices)}): ")
sensor_location = input(f"Choose sensor location ({', '.join(available_locations)}): ")

# Build the sensor_subject with variables
sensor_subject = f"bldg:{sensor_name}{sensor_location}"

sparql_query = f"""
PREFIX bldg: <http://abacwsbuilding.cardiff.ac.uk/abacws#>
PREFIX brick: <https://brickschema.org/schema/Brick#>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>

SELECT ?value ?timestamp
WHERE {{
  {sensor_subject} rdf:type brick:Sensor ;
                 brick:hasValue ?value ;
                 brick:hasTimestamp ?timestamp .
}}
ORDER BY DESC(?timestamp)
LIMIT 1
"""

endpoint_url = "http://localhost:3030/abacws-sensor-network/sparql"


def execute_sparql_query(sparql_query, endpoint_url):
    sparql = SPARQLWrapper(endpoint_url)
    sparql.setQuery(sparql_query)
    sparql.setReturnFormat(JSON)
    results = sparql.query().convert()
    return results


results = execute_sparql_query(sparql_query, endpoint_url)

if results:
    latest_result = results["results"]["bindings"][0]
    value = latest_result["value"]["value"]
    timestamp = latest_result["timestamp"]["value"]
    print(f"Latest Sensor Value: {value}, Timestamp: {timestamp}")
else:
    print("No results found.")
# Out:
# Latest Sensor Value: 497, Timestamp: 2023-11-17T19:14:56

# %%
from SPARQLWrapper import SPARQLWrapper, JSON


# Specify the variables for sensor_name and sensor_location
sensor_name = "notwo"  # Change this to the desired sensor name
sensor_location = "5.02"  # Change this to the desired sensor location

# Build the sensor_subject with variables
sensor_subject = f"bldg:{sensor_name}{sensor_location}"

sparql_query = f"""
    PREFIX bldg: <http://abacwsbuilding.cardiff.ac.uk/abacws#>
    PREFIX brick: <https://brickschema.org/schema/Brick#>
    PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
    PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>

    SELECT ?value ?timestamp
    WHERE {{
      {sensor_subject} rdf:type brick:Sensor ;
                     brick:hasValue ?value ;
                     brick:hasTimestamp ?timestamp .
      FILTER (?timestamp >= "{start_datetime}"^^xsd:dateTime && ?timestamp <= "{end_datetime}"^^xsd:dateTime)
    }}
    ORDER BY DESC(?timestamp)
    LIMIT 1
    """

endpoint_url = "http://localhost:3030/abacws-sensor-network/sparql"


def execute_sparql_query(sparql_query, endpoint_url):
    sparql = SPARQLWrapper(endpoint_url)
    sparql.setQuery(sparql_query)
    sparql.setReturnFormat(JSON)
    results = sparql.query().convert()
    return results


results = execute_sparql_query(sparql_query, endpoint_url)

if results:
    latest_result = results["results"]["bindings"][0]
    value = latest_result["value"]["value"]
    timestamp = latest_result["timestamp"]["value"]
    print(f"Latest Sensor Value: {value}, Timestamp: {timestamp}")
else:
    print("No results found.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\_PHD_\Github\abacws-chatbot\notebooks\15.talk-2-building-using-jena.ipynb Cell 6 line 2
#       <a href='vscode-notebook-cell:/c%3A/_PHD_/Github/abacws-chatbot/notebooks/15.talk-2-building-using-jena.ipynb#W6sZmlsZQ%3D%3D?line=7'>8</a> # Build the sensor_subject with variables
#       <a href='vscode-notebook-cell:/c%3A/_PHD_/Github/abacws-chatbot/notebooks/15.talk-2-building-using-jena.ipynb#W6sZmlsZQ%3D%3D?line=8'>9</a> sensor_subject = f"bldg:{sensor_name}{sensor_location}"
#      <a href='vscode-notebook-cell:/c%3A/_PHD_/Github/abacws-chatbot/notebooks/15.talk-2-building-using-jena.ipynb#W6sZmlsZQ%3D%3D?line=10'>11</a> sparql_query = f"""
# ...
